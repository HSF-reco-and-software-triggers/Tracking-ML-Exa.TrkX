# %% [markdown]
# # Example of Metric Learning in Embedded Space

# %%
# %load_ext autoreload
# %autoreload 2

# %%
# System imports
import os
import sys
import yaml

# External imports
import matplotlib.pyplot as plt
import scipy as sp
from sklearn.decomposition import PCA
from sklearn.metrics import auc
import numpy as np
import pandas as pd
import seaborn as sns
import torch
from pytorch_lightning import Trainer

sys.path.append('..')
device = "cuda" if torch.cuda.is_available() else "cpu"

# %% [markdown]
# Example notebook for running GNN on connected TrackML hits
#
# - [ ] Load PyLightning model
# - [ ] Explain connected dataset
# - [ ] Plot an event graph
# - [ ] Explain GNN concept
# - [ ] Start by training GCN, 3 steps, no residuals
# - [ ] Examine performance
# - [ ] Loop over 1, 5, 8 steps also
# - [ ] Plot different performance metrics
# - [ ] Explain attention mechanism
# - [ ] Train AGNN on 1, 3, 5, 8 steps
# - [ ] Explain residuals
# - [ ] Train ResAGNN on 8 steps
# - [ ] Explain Connected Components
# - [ ] Visualise performance, including TrackML score
# - [ ] Explain problem with mislabelled edges and how the impact score
# - [ ] Visualise performance vs. num mislabelled edges
# - [ ] Explain goal with metric learning

# %% [markdown]
# ## Pytorch Lightning Model

# %% [markdown]
# As in the case of metric learning, we store all of the model logic in Pytorch Lightning modules. We import this class.

# %%
from LightningModules.GNN.Models.gcn import VanillaGCN

# %% [markdown]
# ### Construct PyLightning model

# %% [markdown]
# An ML model typically has many knobs to turn, as well as locations of data, some training preferences, and so on. For convenience, let's put all of these parameters into a YAML file and load it.

# %%
with open("example_gnn.yaml") as f:
        hparams = yaml.load(f, Loader=yaml.FullLoader)

# %% [markdown]
# We plug these parameters into a constructor of the `LayerlessEmbedding` Lightning Module. This doesn't **do** anything yet - merely creates the object.

# %%
model = VanillaGCN(hparams)

# %% [markdown]
# ## The Dataset

# %% [markdown]
# NOTE: This may take a minute or two, since the data is being trimmed to particles above a certain momentum threshold.

# %%
model.setup(stage="fit")

# %% [markdown]
# Let's visualise this data. It is generated from a trained embedding model. That is, it takes hits from (x,y,z)-space, runs them through an MLP, and returns some 8-dimensional co-ordinates. We hope that in this higher-dimensional space, hits from the same track can be found close together. To produce a graph from this embedded data, we simply find all neighbors of each hit within a certain radius `r`, and connect the center hit with each of those neighbors. This is the graph that accompanies each event in the dataset. Specifically, it is a "COO"-type graph, also called an edge list. It is a (2 x N) array, where each pair of indices points from one hit to another. It is a memory-efficient way to store a graph.

# %% [markdown]
# ### Visualise graph

# %% [markdown]
# Let's visualise the graph that has been constructed

# %%
trainset = model.trainset

# %%
example_data = trainset[0]
r, phi, z = example_data.x.T

# %%
x, y = r*np.cos(phi*np.pi), r*np.sin(phi*np.pi)

# %%
plt.figure(figsize=(8,8))
plt.scatter(x, y, s=2)
plt.title("Azimuthal View of Detector", fontsize=24), plt.xlabel("x", fontsize=18), plt.ylabel("y", fontsize=18)
# Out:
# (Text(0.5, 1.0, 'Azimuthal View of Detector'),
#  Text(0.5, 0, 'x'),
#  Text(0, 0.5, 'y'))

# %% [markdown]
# This looks the same as before, which is good - we haven't lost any information in the pipeline. Let's draw an edge connected every hit that the embedding thought was close in the latent space. We'll start with all TRUE edges (i.e. edges that connect two hits from the same track, as defined by the particle ID `pid`) plotted in black. For FAKE edges, we'll plot it in red, and just plot around 20% of them, since there's so many.

# %%
e = example_data.edge_index
pid = example_data.pid
true_edges = pid[e[0]] == pid[e[1]]

# %%
plt.figure(figsize=(16,16))
# plt.plot(x[e[:, ~true_edges]], y[e[:, ~true_edges]], c="r")
plt.plot(x[e[:, true_edges]], y[e[:, true_edges]], c="k")
plt.scatter(x, y, s=5)
plt.title("Azimuthal View of Detector", fontsize=24), plt.xlabel("x", fontsize=18), plt.ylabel("y", fontsize=18)
# Out:
# (Text(0.5, 1.0, 'Azimuthal View of Detector'),
#  Text(0.5, 0, 'x'),
#  Text(0, 0.5, 'y'))

# %%
plt.figure(figsize=(16,16))
plt.plot(x[e[:, (~true_edges)][:, 0:-1:5]], y[e[:, (~true_edges)][:, 0:-1:5]], c="r")
plt.scatter(x, y, s=5)
plt.title("Azimuthal View of Detector", fontsize=24), plt.xlabel("x", fontsize=18), plt.ylabel("y", fontsize=18)
# Out:
# (Text(0.5, 1.0, 'Azimuthal View of Detector'),
#  Text(0.5, 0, 'x'),
#  Text(0, 0.5, 'y'))

# %% [markdown]
# These graphs are constructed from a 2xN list of hits:

# %%
e
# Out:
# tensor([[    0,     0,   543,  ..., 15195, 15195, 15196],
#         [  111,   283,     0,  ..., 15196, 15197, 15197]])

# %% [markdown]
# This is a *directed* graph, since each edge goes only in one direction. This is to simply save space! We will want it to be undirected when we train the graph, and we'll see that soon.

# %% [markdown]
# ### Visualise distributions

# %% [markdown]
# Let's look at how many edges there are per node. This will give an idea about how "connected" the graph is.

# %%
_, node_counts = np.unique(e.numpy(), return_counts = True)

# %%
plt.figure(figsize=(12,8))
sns.histplot(node_counts, binwidth=1)
plt.title("Distribution of Edges per Node", fontsize=24), plt.xlabel("Hits", fontsize=18), plt.ylabel("Count", fontsize=18)
# Out:
# (Text(0.5, 1.0, 'Distribution of Edges per Node'),
#  Text(0.5, 0, 'Hits'),
#  Text(0, 0.5, 'Count'))

# %% [markdown]
# This gives an idea about how long each particle track is. We can see that most particle tracks leave > 10 hits, which will be useful for our graph neural networks down the track. In general, shorter tracks are harder to detect, and less useful for doing meaningful physics.

# %% [markdown]
# ## Vanilla Graph Neural Network

# %% [markdown]
# A GNN is *exactly* like a CNN, but we ease the restriction of only convolving over a gridlike structure. For example, a CNN applied to a picture of a cat will associate pixels in a grid around its eye to understand what an "eye" is. A GNN does this same "averaging" or "smoothing" behavior but across any edges connected to each node.

# %% [markdown]
# <img src="https://miro.medium.com/max/2324/1*oSQyFjtUkI7_u7lJXWU68Q.gif" width="800" height="400">

# %% [markdown]
# ### Train GNN

# %% [markdown]
# We train in exactly the same way as we trained the metric learning model. The only difference is that this trainer may take a little longer, since it is spreading information through a graph N times in each training step.

# %%
trainer = Trainer(gpus=1, max_epochs=1)
trainer.fit(model)
# Out:
# GPU available: True, used: True
# TPU available: None, using: 0 TPU cores
# Set SLURM handle signals.
#
#   | Name         | Type       | Params
# --------------------------------------------
# 0 | node_encoder | Sequential | 9.0 K
# 1 | edge_network | Sequential | 17.0 K
# 2 | node_network | Sequential | 17.0 K
# --------------------------------------------
# 42.9 K    Trainable params
# 0         Non-trainable params
# 42.9 K    Total params
# 0.172     Total estimated model params size (MB)
# /global/homes/d/danieltm/.conda/envs/exatrkx-test/lib/python3.7/site-packages/pytorch_lightning/utilities/distributed.py:50: UserWarning: The dataloader, val dataloader 0, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 80 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
#   warnings.warn(*args, **kwargs)
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validation sanity check', layout=Layout…
# /global/homes/d/danieltm/.conda/envs/exatrkx-test/lib/python3.7/site-packages/torch/nn/functional.py:1639: UserWarning: nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.
#   warnings.warn("nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.")
# ../LightningModules/GNN/gnn_base.py:119: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   eff = torch.tensor(edge_true_positive/edge_true)
# ../LightningModules/GNN/gnn_base.py:120: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   pur = torch.tensor(edge_true_positive/edge_positive)
# /global/homes/d/danieltm/.conda/envs/exatrkx-test/lib/python3.7/site-packages/pytorch_lightning/utilities/distributed.py:50: UserWarning: The dataloader, train dataloader, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 80 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
#   warnings.warn(*args, **kwargs)
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Training', layout=Layout(flex='2'), max…
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validating', layout=Layout(flex='2'), m…
# 1

# %% [markdown]
# ### Test GNN

# %%
trainer.test()
# Out:
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Testing', layout=Layout(flex='2'), max=…
# ../LightningModules/GNN/gnn_base.py:119: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   eff = torch.tensor(edge_true_positive/edge_true)
# ../LightningModules/GNN/gnn_base.py:120: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   pur = torch.tensor(edge_true_positive/edge_positive)
# Step: {'loss': tensor(0.9131, device='cuda:0'), 'preds': array([ True,  True,  True, ...,  True,  True,  True]), 'truth': array([0., 1., 0., ..., 1., 1., 1.], dtype=float32)}
# Step: {'loss': tensor(0.9241, device='cuda:0'), 'preds': array([ True,  True,  True, ...,  True,  True,  True]), 'truth': array([0., 1., 1., ..., 1., 1., 0.], dtype=float32)}
# Step: {'loss': tensor(0.9089, device='cuda:0'), 'preds': array([ True,  True,  True, ...,  True,  True,  True]), 'truth': array([0., 0., 0., ..., 1., 0., 0.], dtype=float32)}
# Step: {'loss': tensor(0.9481, device='cuda:0'), 'preds': array([ True,  True,  True, ...,  True,  True,  True]), 'truth': array([1., 1., 0., ..., 1., 0., 0.], dtype=float32)}
# Step: {'loss': tensor(0.9113, device='cuda:0'), 'preds': array([ True,  True,  True, ...,  True,  True,  True]), 'truth': array([0., 0., 0., ..., 1., 0., 0.], dtype=float32)}
# Step: {'loss': tensor(0.9163, device='cuda:0'), 'preds': array([ True,  True,  True, ...,  True,  True,  True]), 'truth': array([0., 1., 0., ..., 1., 0., 0.], dtype=float32)}
# Step: {'loss': tensor(0.9214, device='cuda:0'), 'preds': array([ True,  True,  True, ...,  True,  True,  True]), 'truth': array([0., 0., 0., ..., 0., 0., 1.], dtype=float32)}
# Step: {'loss': tensor(0.9567, device='cuda:0'), 'preds': array([ True,  True,  True, ...,  True,  True,  True]), 'truth': array([1., 1., 0., ..., 1., 1., 1.], dtype=float32)}
# Step: {'loss': tensor(0.9095, device='cuda:0'), 'preds': array([ True,  True,  True, ...,  True,  True,  True]), 'truth': array([0., 0., 0., ..., 1., 1., 1.], dtype=float32)}
# Step: {'loss': tensor(0.9345, device='cuda:0'), 'preds': array([ True,  True,  True, ...,  True,  True,  True]), 'truth': array([1., 0., 0., ..., 0., 0., 0.], dtype=float32)}
# Step: {'loss': tensor(0.9109, device='cuda:0'), 'preds': array([ True,  True,  True, ...,  True,  True,  True]), 'truth': array([0., 0., 0., ..., 0., 0., 0.], dtype=float32)}
# Step: {'loss': tensor(0.9035, device='cuda:0'), 'preds': array([ True,  True,  True, ...,  True,  True,  True]), 'truth': array([1., 0., 0., ..., 1., 0., 0.], dtype=float32)}
# Step: {'loss': tensor(0.9098, device='cuda:0'), 'preds': array([ True,  True,  True, ...,  True,  True,  True]), 'truth': array([1., 1., 1., ..., 0., 1., 0.], dtype=float32)}
# Step: {'loss': tensor(0.9381, device='cuda:0'), 'preds': array([ True,  True,  True, ...,  True,  True,  True]), 'truth': array([0., 0., 0., ..., 1., 1., 1.], dtype=float32)}
# Step: {'loss': tensor(0.8998, device='cuda:0'), 'preds': array([ True,  True,  True, ...,  True,  True,  True]), 'truth': array([0., 0., 1., ..., 1., 0., 1.], dtype=float32)}
# Step: {'loss': tensor(0.9157, device='cuda:0'), 'preds': array([ True,  True,  True, ...,  True,  True,  True]), 'truth': array([1., 1., 0., ..., 1., 0., 1.], dtype=float32)}
# Step: {'loss': tensor(0.9163, device='cuda:0'), 'preds': array([ True,  True,  True, ...,  True,  True,  True]), 'truth': array([0., 1., 0., ..., 0., 0., 1.], dtype=float32)}
# Step: {'loss': tensor(0.9134, device='cuda:0'), 'preds': array([ True,  True,  True, ...,  True,  True,  True]), 'truth': array([1., 0., 0., ..., 1., 0., 1.], dtype=float32)}
# Step: {'loss': tensor(0.9315, device='cuda:0'), 'preds': array([ True,  True,  True, ...,  True,  True,  True]), 'truth': array([0., 0., 0., ..., 0., 1., 1.], dtype=float32)}
# Step: {'loss': tensor(0.9271, device='cuda:0'), 'preds': array([ True,  True,  True, ...,  True,  True,  True]), 'truth': array([0., 1., 0., ..., 0., 1., 1.], dtype=float32)}
# Epoch: []
#
# --------------------------------------------------------------------------------
# DATALOADER:0 TEST RESULTS
# {'current_lr': 3.9999998989515007e-05,
#  'eff': 1.0,
#  'loss': 0.9270515441894531,
#  'preds': array([ True,  True,  True, ...,  True,  True,  True]),
#  'pur': 0.36627092957496643,
#  'truth': array([0., 1., 0., ..., 0., 1., 1.], dtype=float32),
#  'val_loss': 0.9204956293106079}
# --------------------------------------------------------------------------------
# [{'val_loss': 0.9204956293106079,
#   'eff': 1.0,
#   'pur': 0.36627092957496643,
#   'current_lr': 3.9999998989515007e-05,
#   'loss': 0.9270515441894531,
#   'preds': array([ True,  True,  True, ...,  True,  True,  True]),
#   'truth': array([0., 1., 0., ..., 0., 1., 1.], dtype=float32)}]

# %%
test_results = trainer.test(ckpt_path=None)
# Out:
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Testing', layout=Layout(flex='2'), max=…
# ../LightningModules/GNN/gnn_base.py:119: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   eff = torch.tensor(edge_true_positive/edge_true)
# ../LightningModules/GNN/gnn_base.py:120: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   pur = torch.tensor(edge_true_positive/edge_positive)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-20-fc0daab7624d> in <module>
# ----> 1 test_results = trainer.test(ckpt_path=None)
#
# ~/.conda/envs/exatrkx-test/lib/python3.7/site-packages/pytorch_lightning/trainer/trainer.py in test(self, model, test_dataloaders, ckpt_path, verbose, datamodule)
#     922             results = self.__test_given_model(model, test_dataloaders)
#     923         else:
# --> 924             results = self.__test_using_best_weights(ckpt_path, test_dataloaders)
#     925
#     926         self.teardown('test')
#
# ~/.conda/envs/exatrkx-test/lib/python3.7/site-packages/pytorch_lightning/trainer/trainer.py in __test_using_best_weights(self, ckpt_path, test_dataloaders)
#     961         # run tests
#     962         self.tested_ckpt_path = ckpt_path
# --> 963         results = self.fit(model)
#     964
#     965         # teardown
#
# ~/.conda/envs/exatrkx-test/lib/python3.7/site-packages/pytorch_lightning/trainer/trainer.py in fit(self, model, train_dataloader, val_dataloaders, datamodule)
#     511
#     512         # dispath `start_training` or `start_testing` or `start_predicting`
# --> 513         self.dispatch()
#     514
#     515         # plugin will finalized fitting (e.g. ddp_spawn will load trained model)
#
# ~/.conda/envs/exatrkx-test/lib/python3.7/site-packages/pytorch_lightning/trainer/trainer.py in dispatch(self)
#     545     def dispatch(self):
#     546         if self.testing:
# --> 547             self.accelerator.start_testing(self)
#     548
#     549         elif self.predicting:
#
# ~/.conda/envs/exatrkx-test/lib/python3.7/site-packages/pytorch_lightning/accelerators/accelerator.py in start_testing(self, trainer)
#      75
#      76     def start_testing(self, trainer):
# ---> 77         self.training_type_plugin.start_testing(trainer)
#      78
#      79     def start_predicting(self, trainer):
#
# ~/.conda/envs/exatrkx-test/lib/python3.7/site-packages/pytorch_lightning/plugins/training_type/training_type_plugin.py in start_testing(self, trainer)
#     113     def start_testing(self, trainer: 'Trainer') -> None:
#     114         # double dispatch to initiate the test loop
# --> 115         self._results = trainer.run_test()
#     116
#     117     def start_predicting(self, trainer: 'Trainer') -> None:
#
# ~/.conda/envs/exatrkx-test/lib/python3.7/site-packages/pytorch_lightning/trainer/trainer.py in run_test(self)
#     791         # self.reset_test_dataloader(ref_model)
#     792         with self.profiler.profile("run_test_evaluation"):
# --> 793             eval_loop_results, _ = self.run_evaluation()
#     794
#     795         if len(eval_loop_results) == 0:
#
# ~/.conda/envs/exatrkx-test/lib/python3.7/site-packages/pytorch_lightning/trainer/trainer.py in run_evaluation(self, max_batches, on_epoch)
#     737
#     738                 # log batch metrics
# --> 739                 self.evaluation_loop.log_evaluation_step_metrics(output, batch_idx)
#     740
#     741                 # track epoch level outputs
#
# ~/.conda/envs/exatrkx-test/lib/python3.7/site-packages/pytorch_lightning/trainer/evaluation_loop.py in log_evaluation_step_metrics(self, output, batch_idx)
#     328         step_pbar_metrics = {}
#     329
# --> 330         self.__log_result_step_metrics(step_log_metrics, step_pbar_metrics, batch_idx)
#     331
#     332     def __log_result_step_metrics(self, step_log_metrics, step_pbar_metrics, batch_idx):
#
# ~/.conda/envs/exatrkx-test/lib/python3.7/site-packages/pytorch_lightning/trainer/evaluation_loop.py in __log_result_step_metrics(self, step_log_metrics, step_pbar_metrics, batch_idx)
#     332     def __log_result_step_metrics(self, step_log_metrics, step_pbar_metrics, batch_idx):
#     333         cached_results = self.trainer.logger_connector.cached_results
# --> 334         cached_batch_pbar_metrics, cached_batch_log_metrics = cached_results.update_logger_connector()
#     335
#     336         step_log_metrics.update(cached_batch_log_metrics)
#
# ~/.conda/envs/exatrkx-test/lib/python3.7/site-packages/pytorch_lightning/trainer/connectors/logger_connector/epoch_result_store.py in update_logger_connector(self)
#     341
#     342         if not is_train and self.trainer.testing:
# --> 343             logger_connector.evaluation_callback_metrics.update(callback_metrics)
#     344
#     345         # update callback_metrics
#
# ~/.conda/envs/exatrkx-test/lib/python3.7/site-packages/pytorch_lightning/trainer/connectors/logger_connector/logger_connector.py in evaluation_callback_metrics(self)
#      55     @property
#      56     def evaluation_callback_metrics(self) -> Dict:
# ---> 57         return self.get_metrics("evaluation_callback_metrics")
#      58
#      59     @evaluation_callback_metrics.setter
#
# ~/.conda/envs/exatrkx-test/lib/python3.7/site-packages/pytorch_lightning/trainer/connectors/logger_connector/logger_connector.py in get_metrics(self, key)
#      86         metrics_holder.convert(
#      87             self.trainer._device_type == DeviceType.TPU,
# ---> 88             model_ref.device if model_ref is not None else model_ref,
#      89         )
#      90         return metrics_holder.metrics
#
# ~/.conda/envs/exatrkx-test/lib/python3.7/site-packages/pytorch_lightning/trainer/connectors/logger_connector/metrics_holder.py in convert(self, use_tpu, device)
#      43     def convert(self, use_tpu: bool, device: torch.device):
#      44         for key, value in self.metrics.items():
# ---> 45             self.metrics[key] = self._convert(value, use_tpu, device)
#      46
#      47     def _convert(self, current: Any, use_tpu: bool, device: torch.device):
#
# ~/.conda/envs/exatrkx-test/lib/python3.7/site-packages/pytorch_lightning/trainer/connectors/logger_connector/metrics_holder.py in _convert(self, current, use_tpu, device)
#      47     def _convert(self, current: Any, use_tpu: bool, device: torch.device):
#      48         if self._to_float:
# ---> 49             return self._convert_to_float(current, use_tpu, device)
#      50         return self._convert_to_tensor(current, use_tpu, device)
#      51
#
# ~/.conda/envs/exatrkx-test/lib/python3.7/site-packages/pytorch_lightning/trainer/connectors/logger_connector/metrics_holder.py in _convert_to_float(self, current, use_tpu, device)
#      55
#      56         if isinstance(current, torch.Tensor):
# ---> 57             current = float(current.item())
#      58
#      59         elif isinstance(current, int):
#
# ValueError: only one element tensors can be converted to Python scalars

# %%
len(test_results[0]["preds"])
# Out:
# 90067

# %%
model.testset
# Out:
# [Data(cell_data=[14284, 9], edge_index=[2, 106078], event_file="/global/cscratch1/sd/danieltm/ExaTrkX/trackml-codalab/train_all/event000021010", hid=[14284], layerless_true_edges=[2, 16923], layers=[14284], pid=[14284], pt=[14284], true_weights=[16923], weights=[16923], x=[14284, 3], y=[106078]),
#  Data(cell_data=[12920, 9], edge_index=[2, 86785], event_file="/global/cscratch1/sd/danieltm/ExaTrkX/trackml-codalab/train_all/event000021024", hid=[12920], layerless_true_edges=[2, 15591], layers=[12920], pid=[12920], pt=[12920], true_weights=[15591], weights=[15591], x=[12920, 3], y=[86785]),
#  Data(cell_data=[16663, 9], edge_index=[2, 126892], event_file="/global/cscratch1/sd/danieltm/ExaTrkX/trackml-codalab/train_all/event000021038", hid=[16663], layerless_true_edges=[2, 19950], layers=[16663], pid=[16663], pt=[16663], true_weights=[19950], weights=[19950], x=[16663, 3], y=[126892]),
#  Data(cell_data=[10067, 9], edge_index=[2, 57077], event_file="/global/cscratch1/sd/danieltm/ExaTrkX/trackml-codalab/train_all/event000021082", hid=[10067], layerless_true_edges=[2, 12194], layers=[10067], pid=[10067], pt=[10067], true_weights=[12194], weights=[12194], x=[10067, 3], y=[57077]),
#  Data(cell_data=[14296, 9], edge_index=[2, 104660], event_file="/global/cscratch1/sd/danieltm/ExaTrkX/trackml-codalab/train_all/event000021135", hid=[14296], layerless_true_edges=[2, 16773], layers=[14296], pid=[14296], pt=[14296], true_weights=[16773], weights=[16773], x=[14296, 3], y=[104660]),
#  Data(cell_data=[14165, 9], edge_index=[2, 106443], event_file="/global/cscratch1/sd/danieltm/ExaTrkX/trackml-codalab/train_all/event000021157", hid=[14165], layerless_true_edges=[2, 17198], layers=[14165], pid=[14165], pt=[14165], true_weights=[17198], weights=[17198], x=[14165, 3], y=[106443]),
#  Data(cell_data=[11234, 9], edge_index=[2, 74477], event_file="/global/cscratch1/sd/danieltm/ExaTrkX/trackml-codalab/train_all/event000021170", hid=[11234], layerless_true_edges=[2, 13217], layers=[11234], pid=[11234], pt=[11234], true_weights=[13217], weights=[13217], x=[11234, 3], y=[74477]),
#  Data(cell_data=[9304, 9], edge_index=[2, 51395], event_file="/global/cscratch1/sd/danieltm/ExaTrkX/trackml-codalab/train_all/event000021213", hid=[9304], layerless_true_edges=[2, 11410], layers=[9304], pid=[9304], pt=[9304], true_weights=[11410], weights=[11410], x=[9304, 3], y=[51395]),
#  Data(cell_data=[16484, 9], edge_index=[2, 129142], event_file="/global/cscratch1/sd/danieltm/ExaTrkX/trackml-codalab/train_all/event000021237", hid=[16484], layerless_true_edges=[2, 19720], layers=[16484], pid=[16484], pt=[16484], true_weights=[19720], weights=[19720], x=[16484, 3], y=[129142]),
#  Data(cell_data=[11749, 9], edge_index=[2, 76147], event_file="/global/cscratch1/sd/danieltm/ExaTrkX/trackml-codalab/train_all/event000021255", hid=[11749], layerless_true_edges=[2, 14053], layers=[11749], pid=[11749], pt=[11749], true_weights=[14053], weights=[14053], x=[11749, 3], y=[76147]),
#  Data(cell_data=[15528, 9], edge_index=[2, 119233], event_file="/global/cscratch1/sd/danieltm/ExaTrkX/trackml-codalab/train_all/event000021274", hid=[15528], layerless_true_edges=[2, 18547], layers=[15528], pid=[15528], pt=[15528], true_weights=[18547], weights=[18547], x=[15528, 3], y=[119233]),
#  Data(cell_data=[15109, 9], edge_index=[2, 117265], event_file="/global/cscratch1/sd/danieltm/ExaTrkX/trackml-codalab/train_all/event000021338", hid=[15109], layerless_true_edges=[2, 17927], layers=[15109], pid=[15109], pt=[15109], true_weights=[17927], weights=[17927], x=[15109, 3], y=[117265]),
#  Data(cell_data=[15324, 9], edge_index=[2, 113160], event_file="/global/cscratch1/sd/danieltm/ExaTrkX/trackml-codalab/train_all/event000021342", hid=[15324], layerless_true_edges=[2, 18225], layers=[15324], pid=[15324], pt=[15324], true_weights=[18225], weights=[18225], x=[15324, 3], y=[113160]),
#  Data(cell_data=[10985, 9], edge_index=[2, 67260], event_file="/global/cscratch1/sd/danieltm/ExaTrkX/trackml-codalab/train_all/event000021348", hid=[10985], layerless_true_edges=[2, 13290], layers=[10985], pid=[10985], pt=[10985], true_weights=[13290], weights=[13290], x=[10985, 3], y=[67260]),
#  Data(cell_data=[14486, 9], edge_index=[2, 114692], event_file="/global/cscratch1/sd/danieltm/ExaTrkX/trackml-codalab/train_all/event000021373", hid=[14486], layerless_true_edges=[2, 17206], layers=[14486], pid=[14486], pt=[14486], true_weights=[17206], weights=[17206], x=[14486, 3], y=[114692]),
#  Data(cell_data=[15541, 9], edge_index=[2, 114179], event_file="/global/cscratch1/sd/danieltm/ExaTrkX/trackml-codalab/train_all/event000021452", hid=[15541], layerless_true_edges=[2, 18672], layers=[15541], pid=[15541], pt=[15541], true_weights=[18672], weights=[18672], x=[15541, 3], y=[114179]),
#  Data(cell_data=[15329, 9], edge_index=[2, 115669], event_file="/global/cscratch1/sd/danieltm/ExaTrkX/trackml-codalab/train_all/event000021508", hid=[15329], layerless_true_edges=[2, 18722], layers=[15329], pid=[15329], pt=[15329], true_weights=[18722], weights=[18722], x=[15329, 3], y=[115669]),
#  Data(cell_data=[14920, 9], edge_index=[2, 110636], event_file="/global/cscratch1/sd/danieltm/ExaTrkX/trackml-codalab/train_all/event000021541", hid=[14920], layerless_true_edges=[2, 17963], layers=[14920], pid=[14920], pt=[14920], true_weights=[17963], weights=[17963], x=[14920, 3], y=[110636]),
#  Data(cell_data=[10068, 9], edge_index=[2, 62905], event_file="/global/cscratch1/sd/danieltm/ExaTrkX/trackml-codalab/train_all/event000021575", hid=[10068], layerless_true_edges=[2, 12039], layers=[10068], pid=[10068], pt=[10068], true_weights=[12039], weights=[12039], x=[10068, 3], y=[62905]),
#  Data(cell_data=[13259, 9], edge_index=[2, 90067], event_file="/global/cscratch1/sd/danieltm/ExaTrkX/trackml-codalab/train_all/event000021579", hid=[13259], layerless_true_edges=[2, 16036], layers=[13259], pid=[13259], pt=[13259], true_weights=[16036], weights=[16036], x=[13259, 3], y=[90067])]

# %% [markdown]
# ## Performance

# %%
from LightningModules.GNN.utils import get_metrics

# %% [markdown]
# Let's see how well the model learned to classify edges. One thing to note about this performance: The GNN is doing a *harder job* than the embedding. The embedding was trying to learn the nearest neighbors in the graph of true tracks, but the GNN is learning to classify whether edges connect nodes in the same track. For many edges, these two things are the same thing, but some edges will connect hits at other points along the track.

# %%
model.eval();

# %%
get_metrics(test_results)
# Out:
# (0.71941876, 0.610730857589802)

# %% [markdown]
# ### Test metrics

# %%
all_efficiencies, all_purities = [], []
all_cuts = np.linspace(0., 1., 11)

with torch.no_grad():
    for cut in all_cuts:

        model.hparams.edge_cut = cut
        test_results = trainer.test(ckpt_path=None)

        mean_efficiency, mean_purity = get_metrics(test_results)

        all_efficiencies.append(mean_efficiency)
        all_purities.append(mean_purity)
# Out:
# Set SLURM handle signals.
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Testing', layout=Layout(flex='2'), max=…
# --------------------------------------------------------------------------------
# DATALOADER:0 TEST RESULTS
# {'current_lr': tensor(0.0010),
#  'eff': tensor(1., device='cuda:0'),
#  'loss': tensor(0.4618, device='cuda:0'),
#  'preds': array([False, False, False, ..., False,  True,  True]),
#  'pur': tensor(0.3663, device='cuda:0'),
#  'train_loss': tensor(0.4520, device='cuda:0'),
#  'truth': array([0., 1., 0., ..., 0., 1., 1.], dtype=float32),
#  'val_loss': tensor(0.4526, device='cuda:0')}
# --------------------------------------------------------------------------------
# DATALOADER:1 TEST RESULTS
# {'loss': tensor(0.4638, device='cuda:0'),
#  'preds': array([ True,  True,  True, ...,  True,  True,  True]),
#  'truth': array([0., 1., 0., ..., 1., 1., 1.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:2 TEST RESULTS
# {'loss': tensor(0.4726, device='cuda:0'),
#  'preds': array([ True,  True,  True, ...,  True,  True,  True]),
#  'truth': array([0., 1., 1., ..., 1., 1., 0.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:3 TEST RESULTS
# {'loss': tensor(0.4659, device='cuda:0'),
#  'preds': array([ True,  True,  True, ...,  True,  True,  True]),
#  'truth': array([0., 0., 0., ..., 1., 0., 0.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:4 TEST RESULTS
# {'loss': tensor(0.4344, device='cuda:0'),
#  'preds': array([ True,  True,  True, ...,  True,  True,  True]),
#  'truth': array([1., 1., 0., ..., 1., 0., 0.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:5 TEST RESULTS
# {'loss': tensor(0.4513, device='cuda:0'),
#  'preds': array([ True,  True,  True, ...,  True,  True,  True]),
#  'truth': array([0., 0., 0., ..., 1., 0., 0.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:6 TEST RESULTS
# {'loss': tensor(0.4248, device='cuda:0'),
#  'preds': array([ True,  True,  True, ...,  True,  True,  True]),
#  'truth': array([0., 1., 0., ..., 1., 0., 0.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:7 TEST RESULTS
# {'loss': tensor(0.4596, device='cuda:0'),
#  'preds': array([ True,  True,  True, ...,  True,  True,  True]),
#  'truth': array([0., 0., 0., ..., 0., 0., 1.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:8 TEST RESULTS
# {'loss': tensor(0.4244, device='cuda:0'),
#  'preds': array([ True,  True,  True, ...,  True,  True,  True]),
#  'truth': array([1., 1., 0., ..., 1., 1., 1.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:9 TEST RESULTS
# {'loss': tensor(0.4612, device='cuda:0'),
#  'preds': array([ True,  True,  True, ...,  True,  True,  True]),
#  'truth': array([0., 0., 0., ..., 1., 1., 1.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:10 TEST RESULTS
# {'loss': tensor(0.4615, device='cuda:0'),
#  'preds': array([ True,  True,  True, ...,  True,  True,  True]),
#  'truth': array([1., 0., 0., ..., 0., 0., 0.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:11 TEST RESULTS
# {'loss': tensor(0.4555, device='cuda:0'),
#  'preds': array([ True,  True,  True, ...,  True,  True,  True]),
#  'truth': array([0., 0., 0., ..., 0., 0., 0.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:12 TEST RESULTS
# {'loss': tensor(0.4426, device='cuda:0'),
#  'preds': array([ True,  True,  True, ...,  True,  True,  True]),
#  'truth': array([1., 0., 0., ..., 1., 0., 0.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:13 TEST RESULTS
# {'loss': tensor(0.4629, device='cuda:0'),
#  'preds': array([ True,  True,  True, ...,  True,  True,  True]),
#  'truth': array([1., 1., 1., ..., 0., 1., 0.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:14 TEST RESULTS
# {'loss': tensor(0.4558, device='cuda:0'),
#  'preds': array([ True,  True,  True, ...,  True,  True,  True]),
#  'truth': array([0., 0., 0., ..., 1., 1., 1.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:15 TEST RESULTS
# {'loss': tensor(0.4580, device='cuda:0'),
#  'preds': array([ True,  True,  True, ...,  True,  True,  True]),
#  'truth': array([0., 0., 1., ..., 1., 0., 1.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:16 TEST RESULTS
# {'loss': tensor(0.4575, device='cuda:0'),
#  'preds': array([ True,  True,  True, ...,  True,  True,  True]),
#  'truth': array([1., 1., 0., ..., 1., 0., 1.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:17 TEST RESULTS
# {'loss': tensor(0.4596, device='cuda:0'),
#  'preds': array([ True,  True,  True, ...,  True,  True,  True]),
#  'truth': array([0., 1., 0., ..., 0., 0., 1.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:18 TEST RESULTS
# {'loss': tensor(0.4463, device='cuda:0'),
#  'preds': array([ True,  True,  True, ...,  True,  True,  True]),
#  'truth': array([1., 0., 0., ..., 1., 0., 1.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:19 TEST RESULTS
# {'loss': tensor(0.4336, device='cuda:0'),
#  'preds': array([ True,  True,  True, ...,  True,  True,  True]),
#  'truth': array([0., 0., 0., ..., 0., 1., 1.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:20 TEST RESULTS
# {'loss': tensor(0.4618, device='cuda:0'),
#  'preds': array([ True,  True,  True, ...,  True,  True,  True]),
#  'truth': array([0., 1., 0., ..., 0., 1., 1.], dtype=float32)}
# --------------------------------------------------------------------------------
# Set SLURM handle signals.
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Testing', layout=Layout(flex='2'), max=…
# --------------------------------------------------------------------------------
# DATALOADER:0 TEST RESULTS
# {'current_lr': tensor(0.0010),
#  'eff': tensor(0.9915, device='cuda:0'),
#  'loss': tensor(0.4618, device='cuda:0'),
#  'preds': array([ True,  True,  True, ...,  True,  True,  True]),
#  'pur': tensor(0.4965, device='cuda:0'),
#  'train_loss': tensor(0.4520, device='cuda:0'),
#  'truth': array([0., 1., 0., ..., 0., 1., 1.], dtype=float32),
#  'val_loss': tensor(0.4526, device='cuda:0')}
# --------------------------------------------------------------------------------
# DATALOADER:1 TEST RESULTS
# {'loss': tensor(0.4638, device='cuda:0'),
#  'preds': array([ True,  True, False, ...,  True,  True,  True]),
#  'truth': array([0., 1., 0., ..., 1., 1., 1.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:2 TEST RESULTS
# {'loss': tensor(0.4726, device='cuda:0'),
#  'preds': array([ True,  True,  True, ...,  True,  True, False]),
#  'truth': array([0., 1., 1., ..., 1., 1., 0.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:3 TEST RESULTS
# {'loss': tensor(0.4659, device='cuda:0'),
#  'preds': array([False, False, False, ...,  True, False, False]),
#  'truth': array([0., 0., 0., ..., 1., 0., 0.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:4 TEST RESULTS
# {'loss': tensor(0.4344, device='cuda:0'),
#  'preds': array([ True,  True,  True, ...,  True, False,  True]),
#  'truth': array([1., 1., 0., ..., 1., 0., 0.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:5 TEST RESULTS
# {'loss': tensor(0.4513, device='cuda:0'),
#  'preds': array([False, False, False, ...,  True, False, False]),
#  'truth': array([0., 0., 0., ..., 1., 0., 0.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:6 TEST RESULTS
# {'loss': tensor(0.4248, device='cuda:0'),
#  'preds': array([ True,  True,  True, ...,  True,  True,  True]),
#  'truth': array([0., 1., 0., ..., 1., 0., 0.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:7 TEST RESULTS
# {'loss': tensor(0.4596, device='cuda:0'),
#  'preds': array([ True,  True, False, ...,  True,  True,  True]),
#  'truth': array([0., 0., 0., ..., 0., 0., 1.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:8 TEST RESULTS
# {'loss': tensor(0.4244, device='cuda:0'),
#  'preds': array([ True,  True, False, ...,  True,  True,  True]),
#  'truth': array([1., 1., 0., ..., 1., 1., 1.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:9 TEST RESULTS
# {'loss': tensor(0.4612, device='cuda:0'),
#  'preds': array([False, False, False, ...,  True,  True,  True]),
#  'truth': array([0., 0., 0., ..., 1., 1., 1.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:10 TEST RESULTS
# {'loss': tensor(0.4615, device='cuda:0'),
#  'preds': array([ True, False, False, ..., False, False, False]),
#  'truth': array([1., 0., 0., ..., 0., 0., 0.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:11 TEST RESULTS
# {'loss': tensor(0.4555, device='cuda:0'),
#  'preds': array([ True,  True, False, ..., False, False, False]),
#  'truth': array([0., 0., 0., ..., 0., 0., 0.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:12 TEST RESULTS
# {'loss': tensor(0.4426, device='cuda:0'),
#  'preds': array([ True,  True, False, ...,  True, False, False]),
#  'truth': array([1., 0., 0., ..., 1., 0., 0.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:13 TEST RESULTS
# {'loss': tensor(0.4629, device='cuda:0'),
#  'preds': array([ True,  True,  True, ..., False,  True, False]),
#  'truth': array([1., 1., 1., ..., 0., 1., 0.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:14 TEST RESULTS
# {'loss': tensor(0.4558, device='cuda:0'),
#  'preds': array([False, False,  True, ...,  True,  True,  True]),
#  'truth': array([0., 0., 0., ..., 1., 1., 1.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:15 TEST RESULTS
# {'loss': tensor(0.4580, device='cuda:0'),
#  'preds': array([False, False,  True, ...,  True, False,  True]),
#  'truth': array([0., 0., 1., ..., 1., 0., 1.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:16 TEST RESULTS
# {'loss': tensor(0.4575, device='cuda:0'),
#  'preds': array([ True,  True, False, ...,  True,  True,  True]),
#  'truth': array([1., 1., 0., ..., 1., 0., 1.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:17 TEST RESULTS
# {'loss': tensor(0.4596, device='cuda:0'),
#  'preds': array([False,  True, False, ..., False, False,  True]),
#  'truth': array([0., 1., 0., ..., 0., 0., 1.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:18 TEST RESULTS
# {'loss': tensor(0.4463, device='cuda:0'),
#  'preds': array([ True, False, False, ...,  True, False,  True]),
#  'truth': array([1., 0., 0., ..., 1., 0., 1.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:19 TEST RESULTS
# {'loss': tensor(0.4336, device='cuda:0'),
#  'preds': array([False, False, False, ..., False,  True,  True]),
#  'truth': array([0., 0., 0., ..., 0., 1., 1.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:20 TEST RESULTS
# {'loss': tensor(0.4618, device='cuda:0'),
#  'preds': array([False, False, False, ...,  True,  True,  True]),
#  'truth': array([0., 1., 0., ..., 0., 1., 1.], dtype=float32)}
# --------------------------------------------------------------------------------
# Set SLURM handle signals.
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Testing', layout=Layout(flex='2'), max=…
# --------------------------------------------------------------------------------
# DATALOADER:0 TEST RESULTS
# {'current_lr': tensor(0.0010),
#  'eff': tensor(0.9713, device='cuda:0'),
#  'loss': tensor(0.4618, device='cuda:0'),
#  'preds': array([False, False, False, ...,  True,  True,  True]),
#  'pur': tensor(0.5526, device='cuda:0'),
#  'train_loss': tensor(0.4520, device='cuda:0'),
#  'truth': array([0., 1., 0., ..., 0., 1., 1.], dtype=float32),
#  'val_loss': tensor(0.4526, device='cuda:0')}
# --------------------------------------------------------------------------------
# DATALOADER:1 TEST RESULTS
# {'loss': tensor(0.4638, device='cuda:0'),
#  'preds': array([ True,  True, False, ...,  True,  True,  True]),
#  'truth': array([0., 1., 0., ..., 1., 1., 1.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:2 TEST RESULTS
# {'loss': tensor(0.4726, device='cuda:0'),
#  'preds': array([ True, False,  True, ...,  True,  True, False]),
#  'truth': array([0., 1., 1., ..., 1., 1., 0.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:3 TEST RESULTS
# {'loss': tensor(0.4659, device='cuda:0'),
#  'preds': array([False, False, False, ...,  True, False, False]),
#  'truth': array([0., 0., 0., ..., 1., 0., 0.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:4 TEST RESULTS
# {'loss': tensor(0.4344, device='cuda:0'),
#  'preds': array([ True,  True, False, ...,  True, False,  True]),
#  'truth': array([1., 1., 0., ..., 1., 0., 0.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:5 TEST RESULTS
# {'loss': tensor(0.4513, device='cuda:0'),
#  'preds': array([False, False, False, ...,  True, False, False]),
#  'truth': array([0., 0., 0., ..., 1., 0., 0.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:6 TEST RESULTS
# {'loss': tensor(0.4248, device='cuda:0'),
#  'preds': array([ True,  True,  True, ...,  True, False,  True]),
#  'truth': array([0., 1., 0., ..., 1., 0., 0.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:7 TEST RESULTS
# {'loss': tensor(0.4596, device='cuda:0'),
#  'preds': array([ True,  True, False, ..., False, False,  True]),
#  'truth': array([0., 0., 0., ..., 0., 0., 1.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:8 TEST RESULTS
# {'loss': tensor(0.4244, device='cuda:0'),
#  'preds': array([ True,  True, False, ...,  True,  True,  True]),
#  'truth': array([1., 1., 0., ..., 1., 1., 1.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:9 TEST RESULTS
# {'loss': tensor(0.4612, device='cuda:0'),
#  'preds': array([False, False, False, ...,  True,  True,  True]),
#  'truth': array([0., 0., 0., ..., 1., 1., 1.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:10 TEST RESULTS
# {'loss': tensor(0.4615, device='cuda:0'),
#  'preds': array([ True, False, False, ..., False, False, False]),
#  'truth': array([1., 0., 0., ..., 0., 0., 0.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:11 TEST RESULTS
# {'loss': tensor(0.4555, device='cuda:0'),
#  'preds': array([False,  True, False, ..., False, False, False]),
#  'truth': array([0., 0., 0., ..., 0., 0., 0.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:12 TEST RESULTS
# {'loss': tensor(0.4426, device='cuda:0'),
#  'preds': array([ True,  True, False, ...,  True, False, False]),
#  'truth': array([1., 0., 0., ..., 1., 0., 0.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:13 TEST RESULTS
# {'loss': tensor(0.4629, device='cuda:0'),
#  'preds': array([ True,  True,  True, ..., False,  True, False]),
#  'truth': array([1., 1., 1., ..., 0., 1., 0.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:14 TEST RESULTS
# {'loss': tensor(0.4558, device='cuda:0'),
#  'preds': array([False, False, False, ...,  True,  True,  True]),
#  'truth': array([0., 0., 0., ..., 1., 1., 1.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:15 TEST RESULTS
# {'loss': tensor(0.4580, device='cuda:0'),
#  'preds': array([False, False, False, ...,  True, False,  True]),
#  'truth': array([0., 0., 1., ..., 1., 0., 1.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:16 TEST RESULTS
# {'loss': tensor(0.4575, device='cuda:0'),
#  'preds': array([ True,  True, False, ...,  True,  True,  True]),
#  'truth': array([1., 1., 0., ..., 1., 0., 1.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:17 TEST RESULTS
# {'loss': tensor(0.4596, device='cuda:0'),
#  'preds': array([False,  True, False, ..., False, False,  True]),
#  'truth': array([0., 1., 0., ..., 0., 0., 1.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:18 TEST RESULTS
# {'loss': tensor(0.4463, device='cuda:0'),
#  'preds': array([False, False, False, ...,  True, False,  True]),
#  'truth': array([1., 0., 0., ..., 1., 0., 1.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:19 TEST RESULTS
# {'loss': tensor(0.4336, device='cuda:0'),
#  'preds': array([False, False, False, ..., False,  True,  True]),
#  'truth': array([0., 0., 0., ..., 0., 1., 1.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:20 TEST RESULTS
# {'loss': tensor(0.4618, device='cuda:0'),
#  'preds': array([False, False, False, ...,  True,  True,  True]),
#  'truth': array([0., 1., 0., ..., 0., 1., 1.], dtype=float32)}
# --------------------------------------------------------------------------------
# Set SLURM handle signals.
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Testing', layout=Layout(flex='2'), max=…
# --------------------------------------------------------------------------------
# DATALOADER:0 TEST RESULTS
# {'current_lr': tensor(0.0010),
#  'eff': tensor(0.9359, device='cuda:0'),
#  'loss': tensor(0.4618, device='cuda:0'),
#  'preds': array([False, False, False, ...,  True,  True,  True]),
#  'pur': tensor(0.6178, device='cuda:0'),
#  'train_loss': tensor(0.4520, device='cuda:0'),
#  'truth': array([0., 1., 0., ..., 0., 1., 1.], dtype=float32),
#  'val_loss': tensor(0.4526, device='cuda:0')}
# --------------------------------------------------------------------------------
# DATALOADER:1 TEST RESULTS
# {'loss': tensor(0.4638, device='cuda:0'),
#  'preds': array([ True, False, False, ...,  True,  True,  True]),
#  'truth': array([0., 1., 0., ..., 1., 1., 1.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:2 TEST RESULTS
# {'loss': tensor(0.4726, device='cuda:0'),
#  'preds': array([False, False,  True, ...,  True,  True, False]),
#  'truth': array([0., 1., 1., ..., 1., 1., 0.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:3 TEST RESULTS
# {'loss': tensor(0.4659, device='cuda:0'),
#  'preds': array([False, False, False, ...,  True, False, False]),
#  'truth': array([0., 0., 0., ..., 1., 0., 0.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:4 TEST RESULTS
# {'loss': tensor(0.4344, device='cuda:0'),
#  'preds': array([ True,  True, False, ...,  True, False,  True]),
#  'truth': array([1., 1., 0., ..., 1., 0., 0.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:5 TEST RESULTS
# {'loss': tensor(0.4513, device='cuda:0'),
#  'preds': array([False, False, False, ...,  True, False, False]),
#  'truth': array([0., 0., 0., ..., 1., 0., 0.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:6 TEST RESULTS
# {'loss': tensor(0.4248, device='cuda:0'),
#  'preds': array([ True, False,  True, ...,  True, False, False]),
#  'truth': array([0., 1., 0., ..., 1., 0., 0.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:7 TEST RESULTS
# {'loss': tensor(0.4596, device='cuda:0'),
#  'preds': array([ True,  True, False, ..., False, False,  True]),
#  'truth': array([0., 0., 0., ..., 0., 0., 1.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:8 TEST RESULTS
# {'loss': tensor(0.4244, device='cuda:0'),
#  'preds': array([ True,  True, False, ...,  True,  True,  True]),
#  'truth': array([1., 1., 0., ..., 1., 1., 1.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:9 TEST RESULTS
# {'loss': tensor(0.4612, device='cuda:0'),
#  'preds': array([False, False, False, ...,  True,  True,  True]),
#  'truth': array([0., 0., 0., ..., 1., 1., 1.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:10 TEST RESULTS
# {'loss': tensor(0.4615, device='cuda:0'),
#  'preds': array([ True, False, False, ..., False, False, False]),
#  'truth': array([1., 0., 0., ..., 0., 0., 0.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:11 TEST RESULTS
# {'loss': tensor(0.4555, device='cuda:0'),
#  'preds': array([False,  True, False, ..., False, False, False]),
#  'truth': array([0., 0., 0., ..., 0., 0., 0.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:12 TEST RESULTS
# {'loss': tensor(0.4426, device='cuda:0'),
#  'preds': array([ True,  True, False, ...,  True, False, False]),
#  'truth': array([1., 0., 0., ..., 1., 0., 0.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:13 TEST RESULTS
# {'loss': tensor(0.4629, device='cuda:0'),
#  'preds': array([ True,  True,  True, ..., False,  True, False]),
#  'truth': array([1., 1., 1., ..., 0., 1., 0.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:14 TEST RESULTS
# {'loss': tensor(0.4558, device='cuda:0'),
#  'preds': array([False, False, False, ...,  True,  True,  True]),
#  'truth': array([0., 0., 0., ..., 1., 1., 1.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:15 TEST RESULTS
# {'loss': tensor(0.4580, device='cuda:0'),
#  'preds': array([False, False, False, ...,  True, False,  True]),
#  'truth': array([0., 0., 1., ..., 1., 0., 1.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:16 TEST RESULTS
# {'loss': tensor(0.4575, device='cuda:0'),
#  'preds': array([ True,  True, False, ...,  True,  True,  True]),
#  'truth': array([1., 1., 0., ..., 1., 0., 1.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:17 TEST RESULTS
# {'loss': tensor(0.4596, device='cuda:0'),
#  'preds': array([False, False, False, ..., False, False,  True]),
#  'truth': array([0., 1., 0., ..., 0., 0., 1.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:18 TEST RESULTS
# {'loss': tensor(0.4463, device='cuda:0'),
#  'preds': array([False, False, False, ...,  True, False,  True]),
#  'truth': array([1., 0., 0., ..., 1., 0., 1.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:19 TEST RESULTS
# {'loss': tensor(0.4336, device='cuda:0'),
#  'preds': array([False, False, False, ..., False,  True,  True]),
#  'truth': array([0., 0., 0., ..., 0., 1., 1.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:20 TEST RESULTS
# {'loss': tensor(0.4618, device='cuda:0'),
#  'preds': array([False, False, False, ..., False,  True,  True]),
#  'truth': array([0., 1., 0., ..., 0., 1., 1.], dtype=float32)}
# --------------------------------------------------------------------------------
# Set SLURM handle signals.
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Testing', layout=Layout(flex='2'), max=…
# --------------------------------------------------------------------------------
# DATALOADER:0 TEST RESULTS
# {'current_lr': tensor(0.0010),
#  'eff': tensor(0.8917, device='cuda:0'),
#  'loss': tensor(0.4618, device='cuda:0'),
#  'preds': array([False, False, False, ..., False,  True,  True]),
#  'pur': tensor(0.6820, device='cuda:0'),
#  'train_loss': tensor(0.4520, device='cuda:0'),
#  'truth': array([0., 1., 0., ..., 0., 1., 1.], dtype=float32),
#  'val_loss': tensor(0.4526, device='cuda:0')}
# --------------------------------------------------------------------------------
# DATALOADER:1 TEST RESULTS
# {'loss': tensor(0.4638, device='cuda:0'),
#  'preds': array([ True, False, False, ...,  True,  True,  True]),
#  'truth': array([0., 1., 0., ..., 1., 1., 1.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:2 TEST RESULTS
# {'loss': tensor(0.4726, device='cuda:0'),
#  'preds': array([False, False, False, ...,  True,  True, False]),
#  'truth': array([0., 1., 1., ..., 1., 1., 0.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:3 TEST RESULTS
# {'loss': tensor(0.4659, device='cuda:0'),
#  'preds': array([False, False, False, ...,  True, False, False]),
#  'truth': array([0., 0., 0., ..., 1., 0., 0.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:4 TEST RESULTS
# {'loss': tensor(0.4344, device='cuda:0'),
#  'preds': array([ True,  True, False, ...,  True, False, False]),
#  'truth': array([1., 1., 0., ..., 1., 0., 0.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:5 TEST RESULTS
# {'loss': tensor(0.4513, device='cuda:0'),
#  'preds': array([False, False, False, ...,  True, False, False]),
#  'truth': array([0., 0., 0., ..., 1., 0., 0.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:6 TEST RESULTS
# {'loss': tensor(0.4248, device='cuda:0'),
#  'preds': array([ True, False, False, ...,  True, False, False]),
#  'truth': array([0., 1., 0., ..., 1., 0., 0.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:7 TEST RESULTS
# {'loss': tensor(0.4596, device='cuda:0'),
#  'preds': array([ True,  True, False, ..., False, False,  True]),
#  'truth': array([0., 0., 0., ..., 0., 0., 1.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:8 TEST RESULTS
# {'loss': tensor(0.4244, device='cuda:0'),
#  'preds': array([ True,  True, False, ...,  True,  True,  True]),
#  'truth': array([1., 1., 0., ..., 1., 1., 1.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:9 TEST RESULTS
# {'loss': tensor(0.4612, device='cuda:0'),
#  'preds': array([False, False, False, ...,  True,  True,  True]),
#  'truth': array([0., 0., 0., ..., 1., 1., 1.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:10 TEST RESULTS
# {'loss': tensor(0.4615, device='cuda:0'),
#  'preds': array([ True, False, False, ..., False, False, False]),
#  'truth': array([1., 0., 0., ..., 0., 0., 0.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:11 TEST RESULTS
# {'loss': tensor(0.4555, device='cuda:0'),
#  'preds': array([False,  True, False, ..., False, False, False]),
#  'truth': array([0., 0., 0., ..., 0., 0., 0.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:12 TEST RESULTS
# {'loss': tensor(0.4426, device='cuda:0'),
#  'preds': array([ True,  True, False, ...,  True, False, False]),
#  'truth': array([1., 0., 0., ..., 1., 0., 0.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:13 TEST RESULTS
# {'loss': tensor(0.4629, device='cuda:0'),
#  'preds': array([ True,  True,  True, ..., False,  True, False]),
#  'truth': array([1., 1., 1., ..., 0., 1., 0.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:14 TEST RESULTS
# {'loss': tensor(0.4558, device='cuda:0'),
#  'preds': array([False, False, False, ...,  True,  True,  True]),
#  'truth': array([0., 0., 0., ..., 1., 1., 1.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:15 TEST RESULTS
# {'loss': tensor(0.4580, device='cuda:0'),
#  'preds': array([False, False, False, ...,  True, False,  True]),
#  'truth': array([0., 0., 1., ..., 1., 0., 1.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:16 TEST RESULTS
# {'loss': tensor(0.4575, device='cuda:0'),
#  'preds': array([ True,  True, False, ...,  True,  True,  True]),
#  'truth': array([1., 1., 0., ..., 1., 0., 1.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:17 TEST RESULTS
# {'loss': tensor(0.4596, device='cuda:0'),
#  'preds': array([False, False, False, ..., False, False,  True]),
#  'truth': array([0., 1., 0., ..., 0., 0., 1.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:18 TEST RESULTS
# {'loss': tensor(0.4463, device='cuda:0'),
#  'preds': array([False, False, False, ...,  True, False,  True]),
#  'truth': array([1., 0., 0., ..., 1., 0., 1.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:19 TEST RESULTS
# {'loss': tensor(0.4336, device='cuda:0'),
#  'preds': array([False, False, False, ..., False,  True,  True]),
#  'truth': array([0., 0., 0., ..., 0., 1., 1.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:20 TEST RESULTS
# {'loss': tensor(0.4618, device='cuda:0'),
#  'preds': array([False, False, False, ..., False,  True,  True]),
#  'truth': array([0., 1., 0., ..., 0., 1., 1.], dtype=float32)}
# --------------------------------------------------------------------------------
# Set SLURM handle signals.
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Testing', layout=Layout(flex='2'), max=…
# --------------------------------------------------------------------------------
# DATALOADER:0 TEST RESULTS
# {'current_lr': tensor(0.0010),
#  'eff': tensor(0.8414, device='cuda:0'),
#  'loss': tensor(0.4618, device='cuda:0'),
#  'preds': array([False, False, False, ..., False,  True,  True]),
#  'pur': tensor(0.7424, device='cuda:0'),
#  'train_loss': tensor(0.4520, device='cuda:0'),
#  'truth': array([0., 1., 0., ..., 0., 1., 1.], dtype=float32),
#  'val_loss': tensor(0.4526, device='cuda:0')}
# --------------------------------------------------------------------------------
# DATALOADER:1 TEST RESULTS
# {'loss': tensor(0.4638, device='cuda:0'),
#  'preds': array([ True, False, False, ...,  True,  True,  True]),
#  'truth': array([0., 1., 0., ..., 1., 1., 1.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:2 TEST RESULTS
# {'loss': tensor(0.4726, device='cuda:0'),
#  'preds': array([False, False, False, ...,  True,  True, False]),
#  'truth': array([0., 1., 1., ..., 1., 1., 0.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:3 TEST RESULTS
# {'loss': tensor(0.4659, device='cuda:0'),
#  'preds': array([False, False, False, ...,  True, False, False]),
#  'truth': array([0., 0., 0., ..., 1., 0., 0.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:4 TEST RESULTS
# {'loss': tensor(0.4344, device='cuda:0'),
#  'preds': array([ True,  True, False, ...,  True, False, False]),
#  'truth': array([1., 1., 0., ..., 1., 0., 0.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:5 TEST RESULTS
# {'loss': tensor(0.4513, device='cuda:0'),
#  'preds': array([False, False, False, ...,  True, False, False]),
#  'truth': array([0., 0., 0., ..., 1., 0., 0.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:6 TEST RESULTS
# {'loss': tensor(0.4248, device='cuda:0'),
#  'preds': array([ True, False, False, ...,  True, False, False]),
#  'truth': array([0., 1., 0., ..., 1., 0., 0.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:7 TEST RESULTS
# {'loss': tensor(0.4596, device='cuda:0'),
#  'preds': array([ True,  True, False, ..., False, False,  True]),
#  'truth': array([0., 0., 0., ..., 0., 0., 1.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:8 TEST RESULTS
# {'loss': tensor(0.4244, device='cuda:0'),
#  'preds': array([ True,  True, False, ...,  True,  True,  True]),
#  'truth': array([1., 1., 0., ..., 1., 1., 1.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:9 TEST RESULTS
# {'loss': tensor(0.4612, device='cuda:0'),
#  'preds': array([False, False, False, ...,  True,  True,  True]),
#  'truth': array([0., 0., 0., ..., 1., 1., 1.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:10 TEST RESULTS
# {'loss': tensor(0.4615, device='cuda:0'),
#  'preds': array([ True, False, False, ..., False, False, False]),
#  'truth': array([1., 0., 0., ..., 0., 0., 0.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:11 TEST RESULTS
# {'loss': tensor(0.4555, device='cuda:0'),
#  'preds': array([False,  True, False, ..., False, False, False]),
#  'truth': array([0., 0., 0., ..., 0., 0., 0.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:12 TEST RESULTS
# {'loss': tensor(0.4426, device='cuda:0'),
#  'preds': array([ True,  True, False, ...,  True, False, False]),
#  'truth': array([1., 0., 0., ..., 1., 0., 0.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:13 TEST RESULTS
# {'loss': tensor(0.4629, device='cuda:0'),
#  'preds': array([ True,  True,  True, ..., False,  True, False]),
#  'truth': array([1., 1., 1., ..., 0., 1., 0.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:14 TEST RESULTS
# {'loss': tensor(0.4558, device='cuda:0'),
#  'preds': array([False, False, False, ...,  True,  True,  True]),
#  'truth': array([0., 0., 0., ..., 1., 1., 1.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:15 TEST RESULTS
# {'loss': tensor(0.4580, device='cuda:0'),
#  'preds': array([False, False, False, ...,  True, False,  True]),
#  'truth': array([0., 0., 1., ..., 1., 0., 1.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:16 TEST RESULTS
# {'loss': tensor(0.4575, device='cuda:0'),
#  'preds': array([ True,  True, False, ...,  True,  True,  True]),
#  'truth': array([1., 1., 0., ..., 1., 0., 1.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:17 TEST RESULTS
# {'loss': tensor(0.4596, device='cuda:0'),
#  'preds': array([False, False, False, ..., False, False,  True]),
#  'truth': array([0., 1., 0., ..., 0., 0., 1.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:18 TEST RESULTS
# {'loss': tensor(0.4463, device='cuda:0'),
#  'preds': array([False, False, False, ...,  True, False,  True]),
#  'truth': array([1., 0., 0., ..., 1., 0., 1.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:19 TEST RESULTS
# {'loss': tensor(0.4336, device='cuda:0'),
#  'preds': array([False, False, False, ..., False,  True,  True]),
#  'truth': array([0., 0., 0., ..., 0., 1., 1.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:20 TEST RESULTS
# {'loss': tensor(0.4618, device='cuda:0'),
#  'preds': array([False, False, False, ..., False,  True,  True]),
#  'truth': array([0., 1., 0., ..., 0., 1., 1.], dtype=float32)}
# --------------------------------------------------------------------------------
# Set SLURM handle signals.
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Testing', layout=Layout(flex='2'), max=…
# --------------------------------------------------------------------------------
# DATALOADER:0 TEST RESULTS
# {'current_lr': tensor(0.0010),
#  'eff': tensor(0.7819, device='cuda:0'),
#  'loss': tensor(0.4618, device='cuda:0'),
#  'preds': array([False, False, False, ..., False,  True,  True]),
#  'pur': tensor(0.8015, device='cuda:0'),
#  'train_loss': tensor(0.4520, device='cuda:0'),
#  'truth': array([0., 1., 0., ..., 0., 1., 1.], dtype=float32),
#  'val_loss': tensor(0.4526, device='cuda:0')}
# --------------------------------------------------------------------------------
# DATALOADER:1 TEST RESULTS
# {'loss': tensor(0.4638, device='cuda:0'),
#  'preds': array([ True, False, False, ...,  True,  True,  True]),
#  'truth': array([0., 1., 0., ..., 1., 1., 1.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:2 TEST RESULTS
# {'loss': tensor(0.4726, device='cuda:0'),
#  'preds': array([False, False, False, ...,  True,  True, False]),
#  'truth': array([0., 1., 1., ..., 1., 1., 0.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:3 TEST RESULTS
# {'loss': tensor(0.4659, device='cuda:0'),
#  'preds': array([False, False, False, ...,  True, False, False]),
#  'truth': array([0., 0., 0., ..., 1., 0., 0.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:4 TEST RESULTS
# {'loss': tensor(0.4344, device='cuda:0'),
#  'preds': array([ True,  True, False, ...,  True, False, False]),
#  'truth': array([1., 1., 0., ..., 1., 0., 0.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:5 TEST RESULTS
# {'loss': tensor(0.4513, device='cuda:0'),
#  'preds': array([False, False, False, ...,  True, False, False]),
#  'truth': array([0., 0., 0., ..., 1., 0., 0.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:6 TEST RESULTS
# {'loss': tensor(0.4248, device='cuda:0'),
#  'preds': array([ True, False, False, ...,  True, False, False]),
#  'truth': array([0., 1., 0., ..., 1., 0., 0.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:7 TEST RESULTS
# {'loss': tensor(0.4596, device='cuda:0'),
#  'preds': array([ True,  True, False, ..., False, False,  True]),
#  'truth': array([0., 0., 0., ..., 0., 0., 1.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:8 TEST RESULTS
# {'loss': tensor(0.4244, device='cuda:0'),
#  'preds': array([ True, False, False, ...,  True,  True,  True]),
#  'truth': array([1., 1., 0., ..., 1., 1., 1.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:9 TEST RESULTS
# {'loss': tensor(0.4612, device='cuda:0'),
#  'preds': array([False, False, False, ...,  True,  True,  True]),
#  'truth': array([0., 0., 0., ..., 1., 1., 1.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:10 TEST RESULTS
# {'loss': tensor(0.4615, device='cuda:0'),
#  'preds': array([False, False, False, ..., False, False, False]),
#  'truth': array([1., 0., 0., ..., 0., 0., 0.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:11 TEST RESULTS
# {'loss': tensor(0.4555, device='cuda:0'),
#  'preds': array([False, False, False, ..., False, False, False]),
#  'truth': array([0., 0., 0., ..., 0., 0., 0.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:12 TEST RESULTS
# {'loss': tensor(0.4426, device='cuda:0'),
#  'preds': array([ True,  True, False, ...,  True, False, False]),
#  'truth': array([1., 0., 0., ..., 1., 0., 0.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:13 TEST RESULTS
# {'loss': tensor(0.4629, device='cuda:0'),
#  'preds': array([ True,  True,  True, ..., False,  True, False]),
#  'truth': array([1., 1., 1., ..., 0., 1., 0.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:14 TEST RESULTS
# {'loss': tensor(0.4558, device='cuda:0'),
#  'preds': array([False, False, False, ...,  True,  True,  True]),
#  'truth': array([0., 0., 0., ..., 1., 1., 1.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:15 TEST RESULTS
# {'loss': tensor(0.4580, device='cuda:0'),
#  'preds': array([False, False, False, ...,  True, False,  True]),
#  'truth': array([0., 0., 1., ..., 1., 0., 1.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:16 TEST RESULTS
# {'loss': tensor(0.4575, device='cuda:0'),
#  'preds': array([ True,  True, False, ...,  True,  True,  True]),
#  'truth': array([1., 1., 0., ..., 1., 0., 1.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:17 TEST RESULTS
# {'loss': tensor(0.4596, device='cuda:0'),
#  'preds': array([False, False, False, ..., False, False,  True]),
#  'truth': array([0., 1., 0., ..., 0., 0., 1.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:18 TEST RESULTS
# {'loss': tensor(0.4463, device='cuda:0'),
#  'preds': array([False, False, False, ...,  True, False,  True]),
#  'truth': array([1., 0., 0., ..., 1., 0., 1.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:19 TEST RESULTS
# {'loss': tensor(0.4336, device='cuda:0'),
#  'preds': array([False, False, False, ..., False,  True,  True]),
#  'truth': array([0., 0., 0., ..., 0., 1., 1.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:20 TEST RESULTS
# {'loss': tensor(0.4618, device='cuda:0'),
#  'preds': array([False, False, False, ..., False,  True,  True]),
#  'truth': array([0., 1., 0., ..., 0., 1., 1.], dtype=float32)}
# --------------------------------------------------------------------------------
# Set SLURM handle signals.
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Testing', layout=Layout(flex='2'), max=…
# --------------------------------------------------------------------------------
# DATALOADER:0 TEST RESULTS
# {'current_lr': tensor(0.0010),
#  'eff': tensor(0.7096, device='cuda:0'),
#  'loss': tensor(0.4618, device='cuda:0'),
#  'preds': array([False, False, False, ..., False,  True,  True]),
#  'pur': tensor(0.8621, device='cuda:0'),
#  'train_loss': tensor(0.4520, device='cuda:0'),
#  'truth': array([0., 1., 0., ..., 0., 1., 1.], dtype=float32),
#  'val_loss': tensor(0.4526, device='cuda:0')}
# --------------------------------------------------------------------------------
# DATALOADER:1 TEST RESULTS
# {'loss': tensor(0.4638, device='cuda:0'),
#  'preds': array([ True, False, False, ...,  True,  True,  True]),
#  'truth': array([0., 1., 0., ..., 1., 1., 1.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:2 TEST RESULTS
# {'loss': tensor(0.4726, device='cuda:0'),
#  'preds': array([False, False, False, ...,  True,  True, False]),
#  'truth': array([0., 1., 1., ..., 1., 1., 0.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:3 TEST RESULTS
# {'loss': tensor(0.4659, device='cuda:0'),
#  'preds': array([False, False, False, ...,  True, False, False]),
#  'truth': array([0., 0., 0., ..., 1., 0., 0.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:4 TEST RESULTS
# {'loss': tensor(0.4344, device='cuda:0'),
#  'preds': array([False, False, False, ...,  True, False, False]),
#  'truth': array([1., 1., 0., ..., 1., 0., 0.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:5 TEST RESULTS
# {'loss': tensor(0.4513, device='cuda:0'),
#  'preds': array([False, False, False, ...,  True, False, False]),
#  'truth': array([0., 0., 0., ..., 1., 0., 0.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:6 TEST RESULTS
# {'loss': tensor(0.4248, device='cuda:0'),
#  'preds': array([ True, False, False, ...,  True, False, False]),
#  'truth': array([0., 1., 0., ..., 1., 0., 0.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:7 TEST RESULTS
# {'loss': tensor(0.4596, device='cuda:0'),
#  'preds': array([ True,  True, False, ..., False, False,  True]),
#  'truth': array([0., 0., 0., ..., 0., 0., 1.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:8 TEST RESULTS
# {'loss': tensor(0.4244, device='cuda:0'),
#  'preds': array([ True, False, False, ...,  True,  True,  True]),
#  'truth': array([1., 1., 0., ..., 1., 1., 1.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:9 TEST RESULTS
# {'loss': tensor(0.4612, device='cuda:0'),
#  'preds': array([False, False, False, ...,  True,  True,  True]),
#  'truth': array([0., 0., 0., ..., 1., 1., 1.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:10 TEST RESULTS
# {'loss': tensor(0.4615, device='cuda:0'),
#  'preds': array([False, False, False, ..., False, False, False]),
#  'truth': array([1., 0., 0., ..., 0., 0., 0.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:11 TEST RESULTS
# {'loss': tensor(0.4555, device='cuda:0'),
#  'preds': array([False, False, False, ..., False, False, False]),
#  'truth': array([0., 0., 0., ..., 0., 0., 0.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:12 TEST RESULTS
# {'loss': tensor(0.4426, device='cuda:0'),
#  'preds': array([False,  True, False, ...,  True, False, False]),
#  'truth': array([1., 0., 0., ..., 1., 0., 0.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:13 TEST RESULTS
# ...
#  'preds': array([False, False, False, ...,  True,  True,  True]),
#  'truth': array([0., 0., 0., ..., 1., 1., 1.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:10 TEST RESULTS
# {'loss': tensor(0.4615, device='cuda:0'),
#  'preds': array([False, False, False, ..., False, False, False]),
#  'truth': array([1., 0., 0., ..., 0., 0., 0.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:11 TEST RESULTS
# {'loss': tensor(0.4555, device='cuda:0'),
#  'preds': array([False, False, False, ..., False, False, False]),
#  'truth': array([0., 0., 0., ..., 0., 0., 0.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:12 TEST RESULTS
# {'loss': tensor(0.4426, device='cuda:0'),
#  'preds': array([False,  True, False, ...,  True, False, False]),
#  'truth': array([1., 0., 0., ..., 1., 0., 0.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:13 TEST RESULTS
# {'loss': tensor(0.4629, device='cuda:0'),
#  'preds': array([ True,  True,  True, ..., False,  True, False]),
#  'truth': array([1., 1., 1., ..., 0., 1., 0.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:14 TEST RESULTS
# {'loss': tensor(0.4558, device='cuda:0'),
#  'preds': array([False, False, False, ...,  True,  True,  True]),
#  'truth': array([0., 0., 0., ..., 1., 1., 1.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:15 TEST RESULTS
# {'loss': tensor(0.4580, device='cuda:0'),
#  'preds': array([False, False, False, ...,  True, False,  True]),
#  'truth': array([0., 0., 1., ..., 1., 0., 1.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:16 TEST RESULTS
# {'loss': tensor(0.4575, device='cuda:0'),
#  'preds': array([False,  True, False, ...,  True,  True,  True]),
#  'truth': array([1., 1., 0., ..., 1., 0., 1.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:17 TEST RESULTS
# {'loss': tensor(0.4596, device='cuda:0'),
#  'preds': array([False, False, False, ..., False, False,  True]),
#  'truth': array([0., 1., 0., ..., 0., 0., 1.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:18 TEST RESULTS
# {'loss': tensor(0.4463, device='cuda:0'),
#  'preds': array([False, False, False, ...,  True, False,  True]),
#  'truth': array([1., 0., 0., ..., 1., 0., 1.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:19 TEST RESULTS
# {'loss': tensor(0.4336, device='cuda:0'),
#  'preds': array([False, False, False, ..., False,  True,  True]),
#  'truth': array([0., 0., 0., ..., 0., 1., 1.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:20 TEST RESULTS
# {'loss': tensor(0.4618, device='cuda:0'),
#  'preds': array([False, False, False, ..., False,  True,  True]),
#  'truth': array([0., 1., 0., ..., 0., 1., 1.], dtype=float32)}
# --------------------------------------------------------------------------------
# Set SLURM handle signals.
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Testing', layout=Layout(flex='2'), max=…
# --------------------------------------------------------------------------------
# DATALOADER:0 TEST RESULTS
# {'current_lr': tensor(0.0010),
#  'eff': tensor(0.5331, device='cuda:0'),
#  'loss': tensor(0.4618, device='cuda:0'),
#  'preds': array([False, False, False, ..., False,  True,  True]),
#  'pur': tensor(0.9641, device='cuda:0'),
#  'train_loss': tensor(0.4520, device='cuda:0'),
#  'truth': array([0., 1., 0., ..., 0., 1., 1.], dtype=float32),
#  'val_loss': tensor(0.4526, device='cuda:0')}
# --------------------------------------------------------------------------------
# DATALOADER:1 TEST RESULTS
# {'loss': tensor(0.4638, device='cuda:0'),
#  'preds': array([ True, False, False, ...,  True,  True,  True]),
#  'truth': array([0., 1., 0., ..., 1., 1., 1.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:2 TEST RESULTS
# {'loss': tensor(0.4726, device='cuda:0'),
#  'preds': array([False, False, False, ..., False,  True, False]),
#  'truth': array([0., 1., 1., ..., 1., 1., 0.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:3 TEST RESULTS
# {'loss': tensor(0.4659, device='cuda:0'),
#  'preds': array([False, False, False, ...,  True, False, False]),
#  'truth': array([0., 0., 0., ..., 1., 0., 0.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:4 TEST RESULTS
# {'loss': tensor(0.4344, device='cuda:0'),
#  'preds': array([False, False, False, ...,  True, False, False]),
#  'truth': array([1., 1., 0., ..., 1., 0., 0.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:5 TEST RESULTS
# {'loss': tensor(0.4513, device='cuda:0'),
#  'preds': array([False, False, False, ..., False, False, False]),
#  'truth': array([0., 0., 0., ..., 1., 0., 0.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:6 TEST RESULTS
# {'loss': tensor(0.4248, device='cuda:0'),
#  'preds': array([False, False, False, ..., False, False, False]),
#  'truth': array([0., 1., 0., ..., 1., 0., 0.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:7 TEST RESULTS
# {'loss': tensor(0.4596, device='cuda:0'),
#  'preds': array([ True,  True, False, ..., False, False,  True]),
#  'truth': array([0., 0., 0., ..., 0., 0., 1.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:8 TEST RESULTS
# {'loss': tensor(0.4244, device='cuda:0'),
#  'preds': array([ True, False, False, ...,  True,  True, False]),
#  'truth': array([1., 1., 0., ..., 1., 1., 1.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:9 TEST RESULTS
# {'loss': tensor(0.4612, device='cuda:0'),
#  'preds': array([False, False, False, ...,  True, False,  True]),
#  'truth': array([0., 0., 0., ..., 1., 1., 1.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:10 TEST RESULTS
# {'loss': tensor(0.4615, device='cuda:0'),
#  'preds': array([False, False, False, ..., False, False, False]),
#  'truth': array([1., 0., 0., ..., 0., 0., 0.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:11 TEST RESULTS
# {'loss': tensor(0.4555, device='cuda:0'),
#  'preds': array([False, False, False, ..., False, False, False]),
#  'truth': array([0., 0., 0., ..., 0., 0., 0.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:12 TEST RESULTS
# {'loss': tensor(0.4426, device='cuda:0'),
#  'preds': array([False, False, False, ...,  True, False, False]),
#  'truth': array([1., 0., 0., ..., 1., 0., 0.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:13 TEST RESULTS
# {'loss': tensor(0.4629, device='cuda:0'),
#  'preds': array([ True, False,  True, ..., False,  True, False]),
#  'truth': array([1., 1., 1., ..., 0., 1., 0.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:14 TEST RESULTS
# {'loss': tensor(0.4558, device='cuda:0'),
#  'preds': array([False, False, False, ...,  True,  True,  True]),
#  'truth': array([0., 0., 0., ..., 1., 1., 1.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:15 TEST RESULTS
# {'loss': tensor(0.4580, device='cuda:0'),
#  'preds': array([False, False, False, ...,  True, False,  True]),
#  'truth': array([0., 0., 1., ..., 1., 0., 1.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:16 TEST RESULTS
# {'loss': tensor(0.4575, device='cuda:0'),
#  'preds': array([False, False, False, ...,  True, False,  True]),
#  'truth': array([1., 1., 0., ..., 1., 0., 1.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:17 TEST RESULTS
# {'loss': tensor(0.4596, device='cuda:0'),
#  'preds': array([False, False, False, ..., False, False,  True]),
#  'truth': array([0., 1., 0., ..., 0., 0., 1.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:18 TEST RESULTS
# {'loss': tensor(0.4463, device='cuda:0'),
#  'preds': array([False, False, False, ...,  True, False,  True]),
#  'truth': array([1., 0., 0., ..., 1., 0., 1.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:19 TEST RESULTS
# {'loss': tensor(0.4336, device='cuda:0'),
#  'preds': array([False, False, False, ..., False,  True,  True]),
#  'truth': array([0., 0., 0., ..., 0., 1., 1.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:20 TEST RESULTS
# {'loss': tensor(0.4618, device='cuda:0'),
#  'preds': array([False, False, False, ..., False,  True,  True]),
#  'truth': array([0., 1., 0., ..., 0., 1., 1.], dtype=float32)}
# --------------------------------------------------------------------------------
# Set SLURM handle signals.
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Testing', layout=Layout(flex='2'), max=…
# --------------------------------------------------------------------------------
# DATALOADER:0 TEST RESULTS
# {'current_lr': tensor(0.0010),
#  'eff': tensor(0., device='cuda:0'),
#  'loss': tensor(0.4618, device='cuda:0'),
#  'preds': array([False, False, False, ..., False,  True,  True]),
#  'pur': tensor(nan, device='cuda:0'),
#  'train_loss': tensor(0.4520, device='cuda:0'),
#  'truth': array([0., 1., 0., ..., 0., 1., 1.], dtype=float32),
#  'val_loss': tensor(0.4526, device='cuda:0')}
# --------------------------------------------------------------------------------
# DATALOADER:1 TEST RESULTS
# {'loss': tensor(0.4638, device='cuda:0'),
#  'preds': array([False, False, False, ..., False, False, False]),
#  'truth': array([0., 1., 0., ..., 1., 1., 1.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:2 TEST RESULTS
# {'loss': tensor(0.4726, device='cuda:0'),
#  'preds': array([False, False, False, ..., False, False, False]),
#  'truth': array([0., 1., 1., ..., 1., 1., 0.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:3 TEST RESULTS
# {'loss': tensor(0.4659, device='cuda:0'),
#  'preds': array([False, False, False, ..., False, False, False]),
#  'truth': array([0., 0., 0., ..., 1., 0., 0.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:4 TEST RESULTS
# {'loss': tensor(0.4344, device='cuda:0'),
#  'preds': array([False, False, False, ..., False, False, False]),
#  'truth': array([1., 1., 0., ..., 1., 0., 0.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:5 TEST RESULTS
# {'loss': tensor(0.4513, device='cuda:0'),
#  'preds': array([False, False, False, ..., False, False, False]),
#  'truth': array([0., 0., 0., ..., 1., 0., 0.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:6 TEST RESULTS
# {'loss': tensor(0.4248, device='cuda:0'),
#  'preds': array([False, False, False, ..., False, False, False]),
#  'truth': array([0., 1., 0., ..., 1., 0., 0.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:7 TEST RESULTS
# {'loss': tensor(0.4596, device='cuda:0'),
#  'preds': array([False, False, False, ..., False, False, False]),
#  'truth': array([0., 0., 0., ..., 0., 0., 1.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:8 TEST RESULTS
# {'loss': tensor(0.4244, device='cuda:0'),
#  'preds': array([False, False, False, ..., False, False, False]),
#  'truth': array([1., 1., 0., ..., 1., 1., 1.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:9 TEST RESULTS
# {'loss': tensor(0.4612, device='cuda:0'),
#  'preds': array([False, False, False, ..., False, False, False]),
#  'truth': array([0., 0., 0., ..., 1., 1., 1.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:10 TEST RESULTS
# {'loss': tensor(0.4615, device='cuda:0'),
#  'preds': array([False, False, False, ..., False, False, False]),
#  'truth': array([1., 0., 0., ..., 0., 0., 0.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:11 TEST RESULTS
# {'loss': tensor(0.4555, device='cuda:0'),
#  'preds': array([False, False, False, ..., False, False, False]),
#  'truth': array([0., 0., 0., ..., 0., 0., 0.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:12 TEST RESULTS
# {'loss': tensor(0.4426, device='cuda:0'),
#  'preds': array([False, False, False, ..., False, False, False]),
#  'truth': array([1., 0., 0., ..., 1., 0., 0.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:13 TEST RESULTS
# {'loss': tensor(0.4629, device='cuda:0'),
#  'preds': array([False, False, False, ..., False, False, False]),
#  'truth': array([1., 1., 1., ..., 0., 1., 0.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:14 TEST RESULTS
# {'loss': tensor(0.4558, device='cuda:0'),
#  'preds': array([False, False, False, ..., False, False, False]),
#  'truth': array([0., 0., 0., ..., 1., 1., 1.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:15 TEST RESULTS
# {'loss': tensor(0.4580, device='cuda:0'),
#  'preds': array([False, False, False, ..., False, False, False]),
#  'truth': array([0., 0., 1., ..., 1., 0., 1.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:16 TEST RESULTS
# {'loss': tensor(0.4575, device='cuda:0'),
#  'preds': array([False, False, False, ..., False, False, False]),
#  'truth': array([1., 1., 0., ..., 1., 0., 1.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:17 TEST RESULTS
# {'loss': tensor(0.4596, device='cuda:0'),
#  'preds': array([False, False, False, ..., False, False, False]),
#  'truth': array([0., 1., 0., ..., 0., 0., 1.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:18 TEST RESULTS
# {'loss': tensor(0.4463, device='cuda:0'),
#  'preds': array([False, False, False, ..., False, False, False]),
#  'truth': array([1., 0., 0., ..., 1., 0., 1.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:19 TEST RESULTS
# {'loss': tensor(0.4336, device='cuda:0'),
#  'preds': array([False, False, False, ..., False, False, False]),
#  'truth': array([0., 0., 0., ..., 0., 1., 1.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:20 TEST RESULTS
# {'loss': tensor(0.4618, device='cuda:0'),
#  'preds': array([False, False, False, ..., False, False, False]),
#  'truth': array([0., 1., 0., ..., 0., 1., 1.], dtype=float32)}
# --------------------------------------------------------------------------------
# ../LightningModules/GNN/utils.py:187: RuntimeWarning: invalid value encountered in true_divide
#   purities = [tp/p for (p, tp) in zip(ps, tps)]

# %% [markdown]
# We should always visualise two important metrics: the efficiency (the number of true positives divided by the total number of possible true edges) and the purity (the number of true positives divided by the number of predicted edges). Is it clear to you why the graphs below behave as they do, as we widen the sphere around each hit to generate neighboring edges?

# %%
plt.figure(figsize=(12,8))
plt.plot(all_cuts, all_efficiencies, label="Efficiency");
plt.plot(all_cuts, all_purities, label="Purity");
plt.legend()
plt.title("Performance", fontsize=24), plt.xlabel("Edge cut", fontsize=18), plt.ylabel("Eff and Purity of GNN", fontsize=18);

# %% [markdown]
# ## Attention Mechanism

# %% [markdown]
# Attention is a way of allowing each node to pay more **attention** to some neighbors than others. This idea came from language transformers, and in fact if you view a translation as a graph, the two are exactly the same:

# %% [markdown]
# <img src="https://miro.medium.com/max/1682/1*xW7d7-y0MW5QjtGvyqZN4A.gif" width="800" height="400">

# %% [markdown]
# In practice, it means learning an **edge weight** for each edge, which we include in the sum over each node. In our case, since we want to then use the edges as a score, we make it do double-duty as an attention weight **and** the output score predicting whether the edge is true or not. Turns out, it works!

# %% [markdown]
# <img src="https://miro.medium.com/max/2204/1*ABkaR2glZNP6oh08oY4l-Q.png" width="800" height="400">

# %% [markdown]
# ### Train GNN

# %%
from LightningModules.GNN.Models.agnn import ResAGNN

# %%
with open("example_gnn.yaml") as f:
        hparams = yaml.load(f, Loader=yaml.FullLoader)

# %%
model = ResAGNN(hparams)
trainer = Trainer(gpus=1, max_epochs=20)
trainer.fit(model)
# Out:
# Failed to query for notebook name, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable
# wandb: Currently logged in as: murnanedaniel (use `wandb login --relogin` to force relogin)
# wandb: wandb version 0.10.19 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
#                 Tracking run with wandb version 0.10.9<br/>
#                 Syncing run <strong style="color:#cdcd00">classic-night-7</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/murnanedaniel/Test-GNN" target="_blank">https://wandb.ai/murnanedaniel/Test-GNN</a><br/>
#                 Run page: <a href="https://wandb.ai/murnanedaniel/Test-GNN/runs/9q31blln" target="_blank">https://wandb.ai/murnanedaniel/Test-GNN/runs/9q31blln</a><br/>
#                 Run data is saved locally in <code>wandb/run-20210216_123606-9q31blln</code><br/><br/>
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Set SLURM handle signals.
#
#   | Name          | Type        | Params
# ----------------------------------------------
# 0 | input_network | Sequential  | 384
# 1 | edge_network  | EdgeNetwork | 18 K
# 2 | node_network  | NodeNetwork | 17 K
# /global/homes/d/danieltm/.conda/envs/exatrkx-test/lib/python3.7/site-packages/pytorch_lightning/utilities/distributed.py:45: UserWarning: The dataloader, val dataloader 0, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 80 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
#   warnings.warn(*args, **kwargs)
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validation sanity check', layout=Layout…
# /global/homes/d/danieltm/.conda/envs/exatrkx-test/lib/python3.7/site-packages/torch/nn/functional.py:1639: UserWarning: nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.
#   warnings.warn("nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.")
# ../LightningModules/GNN/gnn_base.py:119: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   eff = torch.tensor(edge_true_positive/edge_true)
# ../LightningModules/GNN/gnn_base.py:120: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   pur = torch.tensor(edge_true_positive/edge_positive)
# /global/homes/d/danieltm/.conda/envs/exatrkx-test/lib/python3.7/site-packages/pytorch_lightning/utilities/distributed.py:45: UserWarning: The dataloader, train dataloader, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 80 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
#   warnings.warn(*args, **kwargs)
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Training', layout=Layout(flex='2'), max…
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validating', layout=Layout(flex='2'), m…
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validating', layout=Layout(flex='2'), m…
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validating', layout=Layout(flex='2'), m…
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validating', layout=Layout(flex='2'), m…
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validating', layout=Layout(flex='2'), m…
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validating', layout=Layout(flex='2'), m…
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validating', layout=Layout(flex='2'), m…
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validating', layout=Layout(flex='2'), m…
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validating', layout=Layout(flex='2'), m…
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validating', layout=Layout(flex='2'), m…
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validating', layout=Layout(flex='2'), m…
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validating', layout=Layout(flex='2'), m…
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validating', layout=Layout(flex='2'), m…
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validating', layout=Layout(flex='2'), m…
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validating', layout=Layout(flex='2'), m…
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validating', layout=Layout(flex='2'), m…
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validating', layout=Layout(flex='2'), m…
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validating', layout=Layout(flex='2'), m…
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validating', layout=Layout(flex='2'), m…
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validating', layout=Layout(flex='2'), m…
# 1

# %% [markdown]
# ### Test GNN

# %% [markdown]
# This took longer to train, right? This is because there are now **two** networks; a node network that runs an MLP over the node hidden features, and an edge network that runs the node features on either end of an edge through an MLP to get the edge weight (or score) at each step of message passing.

# %%
test_results = trainer.test(ckpt_path=None)
# Out:
# Set SLURM handle signals.
# /global/homes/d/danieltm/.conda/envs/exatrkx-test/lib/python3.7/site-packages/pytorch_lightning/utilities/distributed.py:45: UserWarning: The dataloader, test dataloader 0, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 80 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
#   warnings.warn(*args, **kwargs)
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Testing', layout=Layout(flex='2'), max=…
# --------------------------------------------------------------------------------
# DATALOADER:0 TEST RESULTS
# {'current_lr': tensor(0.0010),
#  'eff': tensor(0.8751, device='cuda:0'),
#  'pur': tensor(0.8157, device='cuda:0'),
#  'train_loss': tensor(0.3398, device='cuda:0'),
#  'val_loss': tensor(0.3448, device='cuda:0')}
# --------------------------------------------------------------------------------
# DATALOADER:1 TEST RESULTS
# {'loss': tensor(0.3508, device='cuda:0'),
#  'preds': array([ True, False, False, ...,  True,  True,  True]),
#  'truth': array([0., 1., 0., ..., 1., 1., 1.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:2 TEST RESULTS
# {'loss': tensor(0.3676, device='cuda:0'),
#  'preds': array([False, False, False, ...,  True,  True, False]),
#  'truth': array([0., 1., 1., ..., 1., 1., 0.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:3 TEST RESULTS
# {'loss': tensor(0.3597, device='cuda:0'),
#  'preds': array([False, False, False, ...,  True, False, False]),
#  'truth': array([0., 0., 0., ..., 1., 0., 0.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:4 TEST RESULTS
# {'loss': tensor(0.3357, device='cuda:0'),
#  'preds': array([ True,  True,  True, ...,  True, False, False]),
#  'truth': array([1., 1., 0., ..., 1., 0., 0.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:5 TEST RESULTS
# {'loss': tensor(0.3430, device='cuda:0'),
#  'preds': array([False, False, False, ...,  True, False, False]),
#  'truth': array([0., 0., 0., ..., 1., 0., 0.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:6 TEST RESULTS
# {'loss': tensor(0.3243, device='cuda:0'),
#  'preds': array([ True, False,  True, ...,  True, False, False]),
#  'truth': array([0., 1., 0., ..., 1., 0., 0.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:7 TEST RESULTS
# {'loss': tensor(0.3686, device='cuda:0'),
#  'preds': array([ True,  True, False, ..., False, False,  True]),
#  'truth': array([0., 0., 0., ..., 0., 0., 1.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:8 TEST RESULTS
# {'loss': tensor(0.2785, device='cuda:0'),
#  'preds': array([ True, False, False, ...,  True,  True,  True]),
#  'truth': array([1., 1., 0., ..., 1., 1., 1.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:9 TEST RESULTS
# {'loss': tensor(0.3476, device='cuda:0'),
#  'preds': array([False, False, False, ...,  True,  True,  True]),
#  'truth': array([0., 0., 0., ..., 1., 1., 1.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:10 TEST RESULTS
# {'loss': tensor(0.3327, device='cuda:0'),
#  'preds': array([ True, False, False, ..., False, False, False]),
#  'truth': array([1., 0., 0., ..., 0., 0., 0.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:11 TEST RESULTS
# {'loss': tensor(0.3434, device='cuda:0'),
#  'preds': array([False, False, False, ..., False, False, False]),
#  'truth': array([0., 0., 0., ..., 0., 0., 0.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:12 TEST RESULTS
# {'loss': tensor(0.3353, device='cuda:0'),
#  'preds': array([False, False, False, ...,  True, False, False]),
#  'truth': array([1., 0., 0., ..., 1., 0., 0.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:13 TEST RESULTS
# {'loss': tensor(0.3670, device='cuda:0'),
#  'preds': array([ True,  True,  True, ..., False,  True, False]),
#  'truth': array([1., 1., 1., ..., 0., 1., 0.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:14 TEST RESULTS
# {'loss': tensor(0.3428, device='cuda:0'),
#  'preds': array([False, False, False, ...,  True,  True,  True]),
#  'truth': array([0., 0., 0., ..., 1., 1., 1.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:15 TEST RESULTS
# {'loss': tensor(0.3741, device='cuda:0'),
#  'preds': array([False, False, False, ...,  True, False,  True]),
#  'truth': array([0., 0., 1., ..., 1., 0., 1.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:16 TEST RESULTS
# {'loss': tensor(0.3599, device='cuda:0'),
#  'preds': array([ True,  True, False, ...,  True, False,  True]),
#  'truth': array([1., 1., 0., ..., 1., 0., 1.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:17 TEST RESULTS
# {'loss': tensor(0.3532, device='cuda:0'),
#  'preds': array([False, False, False, ..., False, False,  True]),
#  'truth': array([0., 1., 0., ..., 0., 0., 1.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:18 TEST RESULTS
# {'loss': tensor(0.3383, device='cuda:0'),
#  'preds': array([ True, False, False, ...,  True, False,  True]),
#  'truth': array([1., 0., 0., ..., 1., 0., 1.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:19 TEST RESULTS
# {'loss': tensor(0.3350, device='cuda:0'),
#  'preds': array([False, False, False, ...,  True,  True,  True]),
#  'truth': array([0., 0., 0., ..., 0., 1., 1.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:20 TEST RESULTS
# {'loss': tensor(0.3393, device='cuda:0'),
#  'preds': array([False, False, False, ...,  True,  True,  True]),
#  'truth': array([0., 1., 0., ..., 0., 1., 1.], dtype=float32)}
# --------------------------------------------------------------------------------

# %% [markdown]
# ## Performance

# %%
from LightningModules.GNN.utils import get_metrics

# %% [markdown]
# Let's see how well the model learned to classify edges. One thing to note about this performance: The GNN is doing a *harder job* than the embedding. The embedding was trying to learn the nearest neighbors in the graph of true tracks, but the GNN is learning to classify whether edges connect nodes in the same track. For many edges, these two things are the same thing, but some edges will connect hits at other points along the track.

# %%
model.eval();

# %%
get_metrics(test_results)
# Out:
# (0.8751267, 0.81574662230641)

# %% [markdown]
# ### Test metrics

# %%
all_efficiencies, all_purities = [], []
all_cuts = np.linspace(0., 1., 11)

with torch.no_grad():
    for cut in all_cuts:

        model.hparams.edge_cut = cut
        test_results = trainer.test(ckpt_path=None)

        mean_efficiency, mean_purity = get_metrics(test_results)

        all_efficiencies.append(mean_efficiency)
        all_purities.append(mean_purity)
# Out:
# Set SLURM handle signals.
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Testing', layout=Layout(flex='2'), max=…
# --------------------------------------------------------------------------------
# DATALOADER:0 TEST RESULTS
# {'current_lr': tensor(0.0010),
#  'eff': tensor(1., device='cuda:0'),
#  'loss': tensor(0.3393, device='cuda:0'),
#  'preds': array([False, False, False, ...,  True,  True,  True]),
#  'pur': tensor(0.3663, device='cuda:0'),
#  'train_loss': tensor(0.3398, device='cuda:0'),
#  'truth': array([0., 1., 0., ..., 0., 1., 1.], dtype=float32),
#  'val_loss': tensor(0.3448, device='cuda:0')}
# --------------------------------------------------------------------------------
# DATALOADER:1 TEST RESULTS
# {'loss': tensor(0.3508, device='cuda:0'),
#  'preds': array([ True,  True,  True, ...,  True,  True,  True]),
#  'truth': array([0., 1., 0., ..., 1., 1., 1.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:2 TEST RESULTS
# {'loss': tensor(0.3676, device='cuda:0'),
#  'preds': array([ True,  True,  True, ...,  True,  True,  True]),
#  'truth': array([0., 1., 1., ..., 1., 1., 0.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:3 TEST RESULTS
# {'loss': tensor(0.3597, device='cuda:0'),
#  'preds': array([ True,  True,  True, ...,  True,  True,  True]),
#  'truth': array([0., 0., 0., ..., 1., 0., 0.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:4 TEST RESULTS
# {'loss': tensor(0.3357, device='cuda:0'),
#  'preds': array([ True,  True,  True, ...,  True,  True,  True]),
#  'truth': array([1., 1., 0., ..., 1., 0., 0.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:5 TEST RESULTS
# {'loss': tensor(0.3430, device='cuda:0'),
#  'preds': array([ True,  True,  True, ...,  True,  True,  True]),
#  'truth': array([0., 0., 0., ..., 1., 0., 0.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:6 TEST RESULTS
# {'loss': tensor(0.3243, device='cuda:0'),
#  'preds': array([ True,  True,  True, ...,  True,  True,  True]),
#  'truth': array([0., 1., 0., ..., 1., 0., 0.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:7 TEST RESULTS
# {'loss': tensor(0.3686, device='cuda:0'),
#  'preds': array([ True,  True,  True, ...,  True,  True,  True]),
#  'truth': array([0., 0., 0., ..., 0., 0., 1.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:8 TEST RESULTS
# {'loss': tensor(0.2785, device='cuda:0'),
#  'preds': array([ True,  True,  True, ...,  True,  True,  True]),
#  'truth': array([1., 1., 0., ..., 1., 1., 1.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:9 TEST RESULTS
# {'loss': tensor(0.3476, device='cuda:0'),
#  'preds': array([ True,  True,  True, ...,  True,  True,  True]),
#  'truth': array([0., 0., 0., ..., 1., 1., 1.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:10 TEST RESULTS
# {'loss': tensor(0.3327, device='cuda:0'),
#  'preds': array([ True,  True,  True, ...,  True,  True,  True]),
#  'truth': array([1., 0., 0., ..., 0., 0., 0.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:11 TEST RESULTS
# {'loss': tensor(0.3434, device='cuda:0'),
#  'preds': array([ True,  True,  True, ...,  True,  True,  True]),
#  'truth': array([0., 0., 0., ..., 0., 0., 0.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:12 TEST RESULTS
# {'loss': tensor(0.3353, device='cuda:0'),
#  'preds': array([ True,  True,  True, ...,  True,  True,  True]),
#  'truth': array([1., 0., 0., ..., 1., 0., 0.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:13 TEST RESULTS
# {'loss': tensor(0.3670, device='cuda:0'),
#  'preds': array([ True,  True,  True, ...,  True,  True,  True]),
#  'truth': array([1., 1., 1., ..., 0., 1., 0.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:14 TEST RESULTS
# {'loss': tensor(0.3428, device='cuda:0'),
#  'preds': array([ True,  True,  True, ...,  True,  True,  True]),
#  'truth': array([0., 0., 0., ..., 1., 1., 1.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:15 TEST RESULTS
# {'loss': tensor(0.3741, device='cuda:0'),
#  'preds': array([ True,  True,  True, ...,  True,  True,  True]),
#  'truth': array([0., 0., 1., ..., 1., 0., 1.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:16 TEST RESULTS
# {'loss': tensor(0.3599, device='cuda:0'),
#  'preds': array([ True,  True,  True, ...,  True,  True,  True]),
#  'truth': array([1., 1., 0., ..., 1., 0., 1.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:17 TEST RESULTS
# {'loss': tensor(0.3532, device='cuda:0'),
#  'preds': array([ True,  True,  True, ...,  True,  True,  True]),
#  'truth': array([0., 1., 0., ..., 0., 0., 1.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:18 TEST RESULTS
# {'loss': tensor(0.3383, device='cuda:0'),
#  'preds': array([ True,  True,  True, ...,  True,  True,  True]),
#  'truth': array([1., 0., 0., ..., 1., 0., 1.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:19 TEST RESULTS
# {'loss': tensor(0.3350, device='cuda:0'),
#  'preds': array([ True,  True,  True, ...,  True,  True,  True]),
#  'truth': array([0., 0., 0., ..., 0., 1., 1.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:20 TEST RESULTS
# {'loss': tensor(0.3393, device='cuda:0'),
#  'preds': array([ True,  True,  True, ...,  True,  True,  True]),
#  'truth': array([0., 1., 0., ..., 0., 1., 1.], dtype=float32)}
# --------------------------------------------------------------------------------
# Set SLURM handle signals.
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Testing', layout=Layout(flex='2'), max=…
# --------------------------------------------------------------------------------
# DATALOADER:0 TEST RESULTS
# {'current_lr': tensor(0.0010),
#  'eff': tensor(0.9916, device='cuda:0'),
#  'loss': tensor(0.3393, device='cuda:0'),
#  'preds': array([ True,  True,  True, ...,  True,  True,  True]),
#  'pur': tensor(0.5663, device='cuda:0'),
#  'train_loss': tensor(0.3398, device='cuda:0'),
#  'truth': array([0., 1., 0., ..., 0., 1., 1.], dtype=float32),
#  'val_loss': tensor(0.3448, device='cuda:0')}
# --------------------------------------------------------------------------------
# DATALOADER:1 TEST RESULTS
# {'loss': tensor(0.3508, device='cuda:0'),
#  'preds': array([ True,  True, False, ...,  True,  True,  True]),
#  'truth': array([0., 1., 0., ..., 1., 1., 1.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:2 TEST RESULTS
# {'loss': tensor(0.3676, device='cuda:0'),
#  'preds': array([False,  True,  True, ...,  True,  True, False]),
#  'truth': array([0., 1., 1., ..., 1., 1., 0.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:3 TEST RESULTS
# {'loss': tensor(0.3597, device='cuda:0'),
#  'preds': array([False, False, False, ...,  True, False, False]),
#  'truth': array([0., 0., 0., ..., 1., 0., 0.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:4 TEST RESULTS
# {'loss': tensor(0.3357, device='cuda:0'),
#  'preds': array([ True,  True,  True, ...,  True, False, False]),
#  'truth': array([1., 1., 0., ..., 1., 0., 0.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:5 TEST RESULTS
# {'loss': tensor(0.3430, device='cuda:0'),
#  'preds': array([False, False, False, ...,  True, False, False]),
#  'truth': array([0., 0., 0., ..., 1., 0., 0.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:6 TEST RESULTS
# {'loss': tensor(0.3243, device='cuda:0'),
#  'preds': array([ True,  True,  True, ...,  True, False, False]),
#  'truth': array([0., 1., 0., ..., 1., 0., 0.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:7 TEST RESULTS
# {'loss': tensor(0.3686, device='cuda:0'),
#  'preds': array([ True,  True, False, ..., False, False,  True]),
#  'truth': array([0., 0., 0., ..., 0., 0., 1.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:8 TEST RESULTS
# {'loss': tensor(0.2785, device='cuda:0'),
#  'preds': array([ True,  True, False, ...,  True,  True,  True]),
#  'truth': array([1., 1., 0., ..., 1., 1., 1.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:9 TEST RESULTS
# {'loss': tensor(0.3476, device='cuda:0'),
#  'preds': array([False, False, False, ...,  True,  True,  True]),
#  'truth': array([0., 0., 0., ..., 1., 1., 1.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:10 TEST RESULTS
# {'loss': tensor(0.3327, device='cuda:0'),
#  'preds': array([ True, False, False, ..., False, False, False]),
#  'truth': array([1., 0., 0., ..., 0., 0., 0.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:11 TEST RESULTS
# {'loss': tensor(0.3434, device='cuda:0'),
#  'preds': array([False, False, False, ..., False, False, False]),
#  'truth': array([0., 0., 0., ..., 0., 0., 0.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:12 TEST RESULTS
# {'loss': tensor(0.3353, device='cuda:0'),
#  'preds': array([ True, False, False, ...,  True,  True,  True]),
#  'truth': array([1., 0., 0., ..., 1., 0., 0.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:13 TEST RESULTS
# {'loss': tensor(0.3670, device='cuda:0'),
#  'preds': array([ True,  True,  True, ..., False,  True, False]),
#  'truth': array([1., 1., 1., ..., 0., 1., 0.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:14 TEST RESULTS
# {'loss': tensor(0.3428, device='cuda:0'),
#  'preds': array([False,  True,  True, ...,  True,  True,  True]),
#  'truth': array([0., 0., 0., ..., 1., 1., 1.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:15 TEST RESULTS
# {'loss': tensor(0.3741, device='cuda:0'),
#  'preds': array([False, False,  True, ...,  True, False,  True]),
#  'truth': array([0., 0., 1., ..., 1., 0., 1.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:16 TEST RESULTS
# {'loss': tensor(0.3599, device='cuda:0'),
#  'preds': array([ True,  True, False, ...,  True, False,  True]),
#  'truth': array([1., 1., 0., ..., 1., 0., 1.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:17 TEST RESULTS
# {'loss': tensor(0.3532, device='cuda:0'),
#  'preds': array([False,  True, False, ..., False, False,  True]),
#  'truth': array([0., 1., 0., ..., 0., 0., 1.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:18 TEST RESULTS
# {'loss': tensor(0.3383, device='cuda:0'),
#  'preds': array([ True, False, False, ...,  True, False,  True]),
#  'truth': array([1., 0., 0., ..., 1., 0., 1.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:19 TEST RESULTS
# {'loss': tensor(0.3350, device='cuda:0'),
#  'preds': array([False, False, False, ...,  True,  True,  True]),
#  'truth': array([0., 0., 0., ..., 0., 1., 1.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:20 TEST RESULTS
# {'loss': tensor(0.3393, device='cuda:0'),
#  'preds': array([False, False, False, ...,  True,  True,  True]),
#  'truth': array([0., 1., 0., ..., 0., 1., 1.], dtype=float32)}
# --------------------------------------------------------------------------------
# Set SLURM handle signals.
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Testing', layout=Layout(flex='2'), max=…
# --------------------------------------------------------------------------------
# DATALOADER:0 TEST RESULTS
# {'current_lr': tensor(0.0010),
#  'eff': tensor(0.9732, device='cuda:0'),
#  'loss': tensor(0.3393, device='cuda:0'),
#  'preds': array([False, False, False, ...,  True,  True,  True]),
#  'pur': tensor(0.6282, device='cuda:0'),
#  'train_loss': tensor(0.3398, device='cuda:0'),
#  'truth': array([0., 1., 0., ..., 0., 1., 1.], dtype=float32),
#  'val_loss': tensor(0.3448, device='cuda:0')}
# --------------------------------------------------------------------------------
# DATALOADER:1 TEST RESULTS
# {'loss': tensor(0.3508, device='cuda:0'),
#  'preds': array([ True,  True, False, ...,  True,  True,  True]),
#  'truth': array([0., 1., 0., ..., 1., 1., 1.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:2 TEST RESULTS
# {'loss': tensor(0.3676, device='cuda:0'),
#  'preds': array([False,  True,  True, ...,  True,  True, False]),
#  'truth': array([0., 1., 1., ..., 1., 1., 0.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:3 TEST RESULTS
# {'loss': tensor(0.3597, device='cuda:0'),
#  'preds': array([False, False, False, ...,  True, False, False]),
#  'truth': array([0., 0., 0., ..., 1., 0., 0.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:4 TEST RESULTS
# {'loss': tensor(0.3357, device='cuda:0'),
#  'preds': array([ True,  True,  True, ...,  True, False, False]),
#  'truth': array([1., 1., 0., ..., 1., 0., 0.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:5 TEST RESULTS
# {'loss': tensor(0.3430, device='cuda:0'),
#  'preds': array([False, False, False, ...,  True, False, False]),
#  'truth': array([0., 0., 0., ..., 1., 0., 0.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:6 TEST RESULTS
# {'loss': tensor(0.3243, device='cuda:0'),
#  'preds': array([ True,  True,  True, ...,  True, False, False]),
#  'truth': array([0., 1., 0., ..., 1., 0., 0.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:7 TEST RESULTS
# {'loss': tensor(0.3686, device='cuda:0'),
#  'preds': array([ True,  True, False, ..., False, False,  True]),
#  'truth': array([0., 0., 0., ..., 0., 0., 1.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:8 TEST RESULTS
# {'loss': tensor(0.2785, device='cuda:0'),
#  'preds': array([ True,  True, False, ...,  True,  True,  True]),
#  'truth': array([1., 1., 0., ..., 1., 1., 1.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:9 TEST RESULTS
# {'loss': tensor(0.3476, device='cuda:0'),
#  'preds': array([False, False, False, ...,  True,  True,  True]),
#  'truth': array([0., 0., 0., ..., 1., 1., 1.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:10 TEST RESULTS
# {'loss': tensor(0.3327, device='cuda:0'),
#  'preds': array([ True, False, False, ..., False, False, False]),
#  'truth': array([1., 0., 0., ..., 0., 0., 0.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:11 TEST RESULTS
# {'loss': tensor(0.3434, device='cuda:0'),
#  'preds': array([False, False, False, ..., False, False, False]),
#  'truth': array([0., 0., 0., ..., 0., 0., 0.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:12 TEST RESULTS
# {'loss': tensor(0.3353, device='cuda:0'),
#  'preds': array([ True, False, False, ...,  True,  True,  True]),
#  'truth': array([1., 0., 0., ..., 1., 0., 0.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:13 TEST RESULTS
# {'loss': tensor(0.3670, device='cuda:0'),
#  'preds': array([ True,  True,  True, ..., False,  True, False]),
#  'truth': array([1., 1., 1., ..., 0., 1., 0.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:14 TEST RESULTS
# {'loss': tensor(0.3428, device='cuda:0'),
#  'preds': array([False, False, False, ...,  True,  True,  True]),
#  'truth': array([0., 0., 0., ..., 1., 1., 1.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:15 TEST RESULTS
# {'loss': tensor(0.3741, device='cuda:0'),
#  'preds': array([False, False, False, ...,  True, False,  True]),
#  'truth': array([0., 0., 1., ..., 1., 0., 1.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:16 TEST RESULTS
# {'loss': tensor(0.3599, device='cuda:0'),
#  'preds': array([ True,  True, False, ...,  True, False,  True]),
#  'truth': array([1., 1., 0., ..., 1., 0., 1.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:17 TEST RESULTS
# {'loss': tensor(0.3532, device='cuda:0'),
#  'preds': array([False,  True, False, ..., False, False,  True]),
#  'truth': array([0., 1., 0., ..., 0., 0., 1.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:18 TEST RESULTS
# {'loss': tensor(0.3383, device='cuda:0'),
#  'preds': array([ True, False, False, ...,  True, False,  True]),
#  'truth': array([1., 0., 0., ..., 1., 0., 1.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:19 TEST RESULTS
# {'loss': tensor(0.3350, device='cuda:0'),
#  'preds': array([False, False, False, ...,  True,  True,  True]),
#  'truth': array([0., 0., 0., ..., 0., 1., 1.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:20 TEST RESULTS
# {'loss': tensor(0.3393, device='cuda:0'),
#  'preds': array([False, False, False, ...,  True,  True,  True]),
#  'truth': array([0., 1., 0., ..., 0., 1., 1.], dtype=float32)}
# --------------------------------------------------------------------------------
# Set SLURM handle signals.
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Testing', layout=Layout(flex='2'), max=…
# --------------------------------------------------------------------------------
# DATALOADER:0 TEST RESULTS
# {'current_lr': tensor(0.0010),
#  'eff': tensor(0.9439, device='cuda:0'),
#  'loss': tensor(0.3393, device='cuda:0'),
#  'preds': array([False, False, False, ...,  True,  True,  True]),
#  'pur': tensor(0.6986, device='cuda:0'),
#  'train_loss': tensor(0.3398, device='cuda:0'),
#  'truth': array([0., 1., 0., ..., 0., 1., 1.], dtype=float32),
#  'val_loss': tensor(0.3448, device='cuda:0')}
# --------------------------------------------------------------------------------
# DATALOADER:1 TEST RESULTS
# {'loss': tensor(0.3508, device='cuda:0'),
#  'preds': array([ True,  True, False, ...,  True,  True,  True]),
#  'truth': array([0., 1., 0., ..., 1., 1., 1.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:2 TEST RESULTS
# {'loss': tensor(0.3676, device='cuda:0'),
#  'preds': array([False, False, False, ...,  True,  True, False]),
#  'truth': array([0., 1., 1., ..., 1., 1., 0.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:3 TEST RESULTS
# {'loss': tensor(0.3597, device='cuda:0'),
#  'preds': array([False, False, False, ...,  True, False, False]),
#  'truth': array([0., 0., 0., ..., 1., 0., 0.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:4 TEST RESULTS
# {'loss': tensor(0.3357, device='cuda:0'),
#  'preds': array([ True,  True,  True, ...,  True, False, False]),
#  'truth': array([1., 1., 0., ..., 1., 0., 0.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:5 TEST RESULTS
# {'loss': tensor(0.3430, device='cuda:0'),
#  'preds': array([False, False, False, ...,  True, False, False]),
#  'truth': array([0., 0., 0., ..., 1., 0., 0.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:6 TEST RESULTS
# {'loss': tensor(0.3243, device='cuda:0'),
#  'preds': array([ True,  True,  True, ...,  True, False, False]),
#  'truth': array([0., 1., 0., ..., 1., 0., 0.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:7 TEST RESULTS
# {'loss': tensor(0.3686, device='cuda:0'),
#  'preds': array([ True,  True, False, ..., False, False,  True]),
#  'truth': array([0., 0., 0., ..., 0., 0., 1.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:8 TEST RESULTS
# {'loss': tensor(0.2785, device='cuda:0'),
#  'preds': array([ True, False, False, ...,  True,  True,  True]),
#  'truth': array([1., 1., 0., ..., 1., 1., 1.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:9 TEST RESULTS
# {'loss': tensor(0.3476, device='cuda:0'),
#  'preds': array([False, False, False, ...,  True,  True,  True]),
#  'truth': array([0., 0., 0., ..., 1., 1., 1.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:10 TEST RESULTS
# {'loss': tensor(0.3327, device='cuda:0'),
#  'preds': array([ True, False, False, ..., False, False, False]),
#  'truth': array([1., 0., 0., ..., 0., 0., 0.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:11 TEST RESULTS
# {'loss': tensor(0.3434, device='cuda:0'),
#  'preds': array([False, False, False, ..., False, False, False]),
#  'truth': array([0., 0., 0., ..., 0., 0., 0.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:12 TEST RESULTS
# {'loss': tensor(0.3353, device='cuda:0'),
#  'preds': array([ True, False, False, ...,  True, False, False]),
#  'truth': array([1., 0., 0., ..., 1., 0., 0.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:13 TEST RESULTS
# {'loss': tensor(0.3670, device='cuda:0'),
#  'preds': array([ True,  True,  True, ..., False,  True, False]),
#  'truth': array([1., 1., 1., ..., 0., 1., 0.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:14 TEST RESULTS
# {'loss': tensor(0.3428, device='cuda:0'),
#  'preds': array([False, False, False, ...,  True,  True,  True]),
#  'truth': array([0., 0., 0., ..., 1., 1., 1.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:15 TEST RESULTS
# {'loss': tensor(0.3741, device='cuda:0'),
#  'preds': array([False, False, False, ...,  True, False,  True]),
#  'truth': array([0., 0., 1., ..., 1., 0., 1.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:16 TEST RESULTS
# {'loss': tensor(0.3599, device='cuda:0'),
#  'preds': array([ True,  True, False, ...,  True, False,  True]),
#  'truth': array([1., 1., 0., ..., 1., 0., 1.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:17 TEST RESULTS
# {'loss': tensor(0.3532, device='cuda:0'),
#  'preds': array([False, False, False, ..., False, False,  True]),
#  'truth': array([0., 1., 0., ..., 0., 0., 1.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:18 TEST RESULTS
# {'loss': tensor(0.3383, device='cuda:0'),
#  'preds': array([ True, False, False, ...,  True, False,  True]),
#  'truth': array([1., 0., 0., ..., 1., 0., 1.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:19 TEST RESULTS
# {'loss': tensor(0.3350, device='cuda:0'),
#  'preds': array([False, False, False, ...,  True,  True,  True]),
#  'truth': array([0., 0., 0., ..., 0., 1., 1.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:20 TEST RESULTS
# {'loss': tensor(0.3393, device='cuda:0'),
#  'preds': array([False, False, False, ...,  True,  True,  True]),
#  'truth': array([0., 1., 0., ..., 0., 1., 1.], dtype=float32)}
# --------------------------------------------------------------------------------
# Set SLURM handle signals.
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Testing', layout=Layout(flex='2'), max=…
# --------------------------------------------------------------------------------
# DATALOADER:0 TEST RESULTS
# {'current_lr': tensor(0.0010),
#  'eff': tensor(0.9101, device='cuda:0'),
#  'loss': tensor(0.3393, device='cuda:0'),
#  'preds': array([False, False, False, ...,  True,  True,  True]),
#  'pur': tensor(0.7619, device='cuda:0'),
#  'train_loss': tensor(0.3398, device='cuda:0'),
#  'truth': array([0., 1., 0., ..., 0., 1., 1.], dtype=float32),
#  'val_loss': tensor(0.3448, device='cuda:0')}
# --------------------------------------------------------------------------------
# DATALOADER:1 TEST RESULTS
# {'loss': tensor(0.3508, device='cuda:0'),
#  'preds': array([ True,  True, False, ...,  True,  True,  True]),
#  'truth': array([0., 1., 0., ..., 1., 1., 1.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:2 TEST RESULTS
# {'loss': tensor(0.3676, device='cuda:0'),
#  'preds': array([False, False, False, ...,  True,  True, False]),
#  'truth': array([0., 1., 1., ..., 1., 1., 0.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:3 TEST RESULTS
# {'loss': tensor(0.3597, device='cuda:0'),
#  'preds': array([False, False, False, ...,  True, False, False]),
#  'truth': array([0., 0., 0., ..., 1., 0., 0.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:4 TEST RESULTS
# {'loss': tensor(0.3357, device='cuda:0'),
#  'preds': array([ True,  True,  True, ...,  True, False, False]),
#  'truth': array([1., 1., 0., ..., 1., 0., 0.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:5 TEST RESULTS
# {'loss': tensor(0.3430, device='cuda:0'),
#  'preds': array([False, False, False, ...,  True, False, False]),
#  'truth': array([0., 0., 0., ..., 1., 0., 0.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:6 TEST RESULTS
# {'loss': tensor(0.3243, device='cuda:0'),
#  'preds': array([ True,  True,  True, ...,  True, False, False]),
#  'truth': array([0., 1., 0., ..., 1., 0., 0.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:7 TEST RESULTS
# {'loss': tensor(0.3686, device='cuda:0'),
#  'preds': array([ True,  True, False, ..., False, False,  True]),
#  'truth': array([0., 0., 0., ..., 0., 0., 1.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:8 TEST RESULTS
# {'loss': tensor(0.2785, device='cuda:0'),
#  'preds': array([ True, False, False, ...,  True,  True,  True]),
#  'truth': array([1., 1., 0., ..., 1., 1., 1.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:9 TEST RESULTS
# {'loss': tensor(0.3476, device='cuda:0'),
#  'preds': array([False, False, False, ...,  True,  True,  True]),
#  'truth': array([0., 0., 0., ..., 1., 1., 1.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:10 TEST RESULTS
# {'loss': tensor(0.3327, device='cuda:0'),
#  'preds': array([ True, False, False, ..., False, False, False]),
#  'truth': array([1., 0., 0., ..., 0., 0., 0.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:11 TEST RESULTS
# {'loss': tensor(0.3434, device='cuda:0'),
#  'preds': array([False, False, False, ..., False, False, False]),
#  'truth': array([0., 0., 0., ..., 0., 0., 0.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:12 TEST RESULTS
# {'loss': tensor(0.3353, device='cuda:0'),
#  'preds': array([ True, False, False, ...,  True, False, False]),
#  'truth': array([1., 0., 0., ..., 1., 0., 0.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:13 TEST RESULTS
# {'loss': tensor(0.3670, device='cuda:0'),
#  'preds': array([ True,  True,  True, ..., False,  True, False]),
#  'truth': array([1., 1., 1., ..., 0., 1., 0.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:14 TEST RESULTS
# {'loss': tensor(0.3428, device='cuda:0'),
#  'preds': array([False, False, False, ...,  True,  True,  True]),
#  'truth': array([0., 0., 0., ..., 1., 1., 1.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:15 TEST RESULTS
# {'loss': tensor(0.3741, device='cuda:0'),
#  'preds': array([False, False, False, ...,  True, False,  True]),
#  'truth': array([0., 0., 1., ..., 1., 0., 1.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:16 TEST RESULTS
# {'loss': tensor(0.3599, device='cuda:0'),
#  'preds': array([ True,  True, False, ...,  True, False,  True]),
#  'truth': array([1., 1., 0., ..., 1., 0., 1.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:17 TEST RESULTS
# {'loss': tensor(0.3532, device='cuda:0'),
#  'preds': array([False, False, False, ..., False, False,  True]),
#  'truth': array([0., 1., 0., ..., 0., 0., 1.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:18 TEST RESULTS
# {'loss': tensor(0.3383, device='cuda:0'),
#  'preds': array([ True, False, False, ...,  True, False,  True]),
#  'truth': array([1., 0., 0., ..., 1., 0., 1.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:19 TEST RESULTS
# {'loss': tensor(0.3350, device='cuda:0'),
#  'preds': array([False, False, False, ...,  True,  True,  True]),
#  'truth': array([0., 0., 0., ..., 0., 1., 1.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:20 TEST RESULTS
# {'loss': tensor(0.3393, device='cuda:0'),
#  'preds': array([False, False, False, ...,  True,  True,  True]),
#  'truth': array([0., 1., 0., ..., 0., 1., 1.], dtype=float32)}
# --------------------------------------------------------------------------------
# Set SLURM handle signals.
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Testing', layout=Layout(flex='2'), max=…
# --------------------------------------------------------------------------------
# DATALOADER:0 TEST RESULTS
# {'current_lr': tensor(0.0010),
#  'eff': tensor(0.8751, device='cuda:0'),
#  'loss': tensor(0.3393, device='cuda:0'),
#  'preds': array([False, False, False, ...,  True,  True,  True]),
#  'pur': tensor(0.8157, device='cuda:0'),
#  'train_loss': tensor(0.3398, device='cuda:0'),
#  'truth': array([0., 1., 0., ..., 0., 1., 1.], dtype=float32),
#  'val_loss': tensor(0.3448, device='cuda:0')}
# --------------------------------------------------------------------------------
# DATALOADER:1 TEST RESULTS
# {'loss': tensor(0.3508, device='cuda:0'),
#  'preds': array([ True, False, False, ...,  True,  True,  True]),
#  'truth': array([0., 1., 0., ..., 1., 1., 1.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:2 TEST RESULTS
# {'loss': tensor(0.3676, device='cuda:0'),
#  'preds': array([False, False, False, ...,  True,  True, False]),
#  'truth': array([0., 1., 1., ..., 1., 1., 0.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:3 TEST RESULTS
# {'loss': tensor(0.3597, device='cuda:0'),
#  'preds': array([False, False, False, ...,  True, False, False]),
#  'truth': array([0., 0., 0., ..., 1., 0., 0.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:4 TEST RESULTS
# {'loss': tensor(0.3357, device='cuda:0'),
#  'preds': array([ True,  True,  True, ...,  True, False, False]),
#  'truth': array([1., 1., 0., ..., 1., 0., 0.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:5 TEST RESULTS
# {'loss': tensor(0.3430, device='cuda:0'),
#  'preds': array([False, False, False, ...,  True, False, False]),
#  'truth': array([0., 0., 0., ..., 1., 0., 0.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:6 TEST RESULTS
# {'loss': tensor(0.3243, device='cuda:0'),
#  'preds': array([ True, False,  True, ...,  True, False, False]),
#  'truth': array([0., 1., 0., ..., 1., 0., 0.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:7 TEST RESULTS
# {'loss': tensor(0.3686, device='cuda:0'),
#  'preds': array([ True,  True, False, ..., False, False,  True]),
#  'truth': array([0., 0., 0., ..., 0., 0., 1.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:8 TEST RESULTS
# {'loss': tensor(0.2785, device='cuda:0'),
#  'preds': array([ True, False, False, ...,  True,  True,  True]),
#  'truth': array([1., 1., 0., ..., 1., 1., 1.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:9 TEST RESULTS
# {'loss': tensor(0.3476, device='cuda:0'),
#  'preds': array([False, False, False, ...,  True,  True,  True]),
#  'truth': array([0., 0., 0., ..., 1., 1., 1.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:10 TEST RESULTS
# {'loss': tensor(0.3327, device='cuda:0'),
#  'preds': array([ True, False, False, ..., False, False, False]),
#  'truth': array([1., 0., 0., ..., 0., 0., 0.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:11 TEST RESULTS
# {'loss': tensor(0.3434, device='cuda:0'),
#  'preds': array([False, False, False, ..., False, False, False]),
#  'truth': array([0., 0., 0., ..., 0., 0., 0.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:12 TEST RESULTS
# {'loss': tensor(0.3353, device='cuda:0'),
#  'preds': array([False, False, False, ...,  True, False, False]),
#  'truth': array([1., 0., 0., ..., 1., 0., 0.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:13 TEST RESULTS
# {'loss': tensor(0.3670, device='cuda:0'),
#  'preds': array([ True,  True,  True, ..., False,  True, False]),
#  'truth': array([1., 1., 1., ..., 0., 1., 0.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:14 TEST RESULTS
# {'loss': tensor(0.3428, device='cuda:0'),
#  'preds': array([False, False, False, ...,  True,  True,  True]),
#  'truth': array([0., 0., 0., ..., 1., 1., 1.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:15 TEST RESULTS
# {'loss': tensor(0.3741, device='cuda:0'),
#  'preds': array([False, False, False, ...,  True, False,  True]),
#  'truth': array([0., 0., 1., ..., 1., 0., 1.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:16 TEST RESULTS
# {'loss': tensor(0.3599, device='cuda:0'),
#  'preds': array([ True,  True, False, ...,  True, False,  True]),
#  'truth': array([1., 1., 0., ..., 1., 0., 1.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:17 TEST RESULTS
# {'loss': tensor(0.3532, device='cuda:0'),
#  'preds': array([False, False, False, ..., False, False,  True]),
#  'truth': array([0., 1., 0., ..., 0., 0., 1.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:18 TEST RESULTS
# {'loss': tensor(0.3383, device='cuda:0'),
#  'preds': array([ True, False, False, ...,  True, False,  True]),
#  'truth': array([1., 0., 0., ..., 1., 0., 1.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:19 TEST RESULTS
# {'loss': tensor(0.3350, device='cuda:0'),
#  'preds': array([False, False, False, ...,  True,  True,  True]),
#  'truth': array([0., 0., 0., ..., 0., 1., 1.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:20 TEST RESULTS
# {'loss': tensor(0.3393, device='cuda:0'),
#  'preds': array([False, False, False, ...,  True,  True,  True]),
#  'truth': array([0., 1., 0., ..., 0., 1., 1.], dtype=float32)}
# --------------------------------------------------------------------------------
# Set SLURM handle signals.
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Testing', layout=Layout(flex='2'), max=…
# --------------------------------------------------------------------------------
# DATALOADER:0 TEST RESULTS
# {'current_lr': tensor(0.0010),
#  'eff': tensor(0.8389, device='cuda:0'),
#  'loss': tensor(0.3393, device='cuda:0'),
#  'preds': array([False, False, False, ...,  True,  True,  True]),
#  'pur': tensor(0.8612, device='cuda:0'),
#  'train_loss': tensor(0.3398, device='cuda:0'),
#  'truth': array([0., 1., 0., ..., 0., 1., 1.], dtype=float32),
#  'val_loss': tensor(0.3448, device='cuda:0')}
# --------------------------------------------------------------------------------
# DATALOADER:1 TEST RESULTS
# {'loss': tensor(0.3508, device='cuda:0'),
#  'preds': array([ True, False, False, ...,  True,  True,  True]),
#  'truth': array([0., 1., 0., ..., 1., 1., 1.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:2 TEST RESULTS
# {'loss': tensor(0.3676, device='cuda:0'),
#  'preds': array([False, False, False, ...,  True,  True, False]),
#  'truth': array([0., 1., 1., ..., 1., 1., 0.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:3 TEST RESULTS
# {'loss': tensor(0.3597, device='cuda:0'),
#  'preds': array([False, False, False, ...,  True, False, False]),
#  'truth': array([0., 0., 0., ..., 1., 0., 0.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:4 TEST RESULTS
# {'loss': tensor(0.3357, device='cuda:0'),
#  'preds': array([ True,  True,  True, ...,  True, False, False]),
#  'truth': array([1., 1., 0., ..., 1., 0., 0.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:5 TEST RESULTS
# {'loss': tensor(0.3430, device='cuda:0'),
#  'preds': array([False, False, False, ...,  True, False, False]),
#  'truth': array([0., 0., 0., ..., 1., 0., 0.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:6 TEST RESULTS
# {'loss': tensor(0.3243, device='cuda:0'),
#  'preds': array([ True, False, False, ...,  True, False, False]),
#  'truth': array([0., 1., 0., ..., 1., 0., 0.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:7 TEST RESULTS
# {'loss': tensor(0.3686, device='cuda:0'),
#  'preds': array([ True,  True, False, ..., False, False,  True]),
#  'truth': array([0., 0., 0., ..., 0., 0., 1.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:8 TEST RESULTS
# {'loss': tensor(0.2785, device='cuda:0'),
#  'preds': array([ True, False, False, ...,  True,  True,  True]),
#  'truth': array([1., 1., 0., ..., 1., 1., 1.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:9 TEST RESULTS
# {'loss': tensor(0.3476, device='cuda:0'),
#  'preds': array([False, False, False, ...,  True, False,  True]),
#  'truth': array([0., 0., 0., ..., 1., 1., 1.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:10 TEST RESULTS
# {'loss': tensor(0.3327, device='cuda:0'),
#  'preds': array([ True, False, False, ..., False, False, False]),
#  'truth': array([1., 0., 0., ..., 0., 0., 0.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:11 TEST RESULTS
# {'loss': tensor(0.3434, device='cuda:0'),
#  'preds': array([False, False, False, ..., False, False, False]),
#  'truth': array([0., 0., 0., ..., 0., 0., 0.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:12 TEST RESULTS
# {'loss': tensor(0.3353, device='cuda:0'),
#  'preds': array([False, False, False, ...,  True, False, False]),
#  'truth': array([1., 0., 0., ..., 1., 0., 0.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:13 TEST RESULTS
# {'loss': tensor(0.3670, device='cuda:0'),
#  'preds': array([ True,  True,  True, ..., False,  True, False]),
#  'truth': array([1., 1., 1., ..., 0., 1., 0.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:14 TEST RESULTS
# {'loss': tensor(0.3428, device='cuda:0'),
#  'preds': array([False, False, False, ...,  True,  True,  True]),
#  'truth': array([0., 0., 0., ..., 1., 1., 1.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:15 TEST RESULTS
# {'loss': tensor(0.3741, device='cuda:0'),
#  'preds': array([False, False, False, ...,  True, False,  True]),
#  'truth': array([0., 0., 1., ..., 1., 0., 1.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:16 TEST RESULTS
# {'loss': tensor(0.3599, device='cuda:0'),
#  'preds': array([ True,  True, False, ...,  True, False,  True]),
#  'truth': array([1., 1., 0., ..., 1., 0., 1.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:17 TEST RESULTS
# {'loss': tensor(0.3532, device='cuda:0'),
#  'preds': array([False, False, False, ..., False, False,  True]),
#  'truth': array([0., 1., 0., ..., 0., 0., 1.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:18 TEST RESULTS
# {'loss': tensor(0.3383, device='cuda:0'),
#  'preds': array([ True, False, False, ...,  True, False,  True]),
#  'truth': array([1., 0., 0., ..., 1., 0., 1.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:19 TEST RESULTS
# {'loss': tensor(0.3350, device='cuda:0'),
#  'preds': array([False, False, False, ...,  True,  True,  True]),
#  'truth': array([0., 0., 0., ..., 0., 1., 1.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:20 TEST RESULTS
# {'loss': tensor(0.3393, device='cuda:0'),
#  'preds': array([False, False, False, ..., False,  True,  True]),
#  'truth': array([0., 1., 0., ..., 0., 1., 1.], dtype=float32)}
# --------------------------------------------------------------------------------
# Set SLURM handle signals.
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Testing', layout=Layout(flex='2'), max=…
# --------------------------------------------------------------------------------
# DATALOADER:0 TEST RESULTS
# {'current_lr': tensor(0.0010),
#  'eff': tensor(0.7978, device='cuda:0'),
#  'loss': tensor(0.3393, device='cuda:0'),
#  'preds': array([False, False, False, ..., False,  True,  True]),
#  'pur': tensor(0.9005, device='cuda:0'),
#  'train_loss': tensor(0.3398, device='cuda:0'),
#  'truth': array([0., 1., 0., ..., 0., 1., 1.], dtype=float32),
#  'val_loss': tensor(0.3448, device='cuda:0')}
# --------------------------------------------------------------------------------
# DATALOADER:1 TEST RESULTS
# {'loss': tensor(0.3508, device='cuda:0'),
#  'preds': array([ True, False, False, ...,  True,  True,  True]),
#  'truth': array([0., 1., 0., ..., 1., 1., 1.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:2 TEST RESULTS
# {'loss': tensor(0.3676, device='cuda:0'),
#  'preds': array([False, False, False, ...,  True,  True, False]),
#  'truth': array([0., 1., 1., ..., 1., 1., 0.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:3 TEST RESULTS
# {'loss': tensor(0.3597, device='cuda:0'),
#  'preds': array([False, False, False, ...,  True, False, False]),
#  'truth': array([0., 0., 0., ..., 1., 0., 0.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:4 TEST RESULTS
# {'loss': tensor(0.3357, device='cuda:0'),
#  'preds': array([False, False,  True, ...,  True, False, False]),
#  'truth': array([1., 1., 0., ..., 1., 0., 0.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:5 TEST RESULTS
# {'loss': tensor(0.3430, device='cuda:0'),
#  'preds': array([False, False, False, ...,  True, False, False]),
#  'truth': array([0., 0., 0., ..., 1., 0., 0.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:6 TEST RESULTS
# {'loss': tensor(0.3243, device='cuda:0'),
#  'preds': array([ True, False, False, ...,  True, False, False]),
#  'truth': array([0., 1., 0., ..., 1., 0., 0.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:7 TEST RESULTS
# {'loss': tensor(0.3686, device='cuda:0'),
#  'preds': array([False,  True, False, ..., False, False,  True]),
#  'truth': array([0., 0., 0., ..., 0., 0., 1.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:8 TEST RESULTS
# {'loss': tensor(0.2785, device='cuda:0'),
#  'preds': array([ True, False, False, ...,  True,  True,  True]),
#  'truth': array([1., 1., 0., ..., 1., 1., 1.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:9 TEST RESULTS
# {'loss': tensor(0.3476, device='cuda:0'),
#  'preds': array([False, False, False, ...,  True, False,  True]),
#  'truth': array([0., 0., 0., ..., 1., 1., 1.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:10 TEST RESULTS
# {'loss': tensor(0.3327, device='cuda:0'),
#  'preds': array([ True, False, False, ..., False, False, False]),
#  'truth': array([1., 0., 0., ..., 0., 0., 0.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:11 TEST RESULTS
# {'loss': tensor(0.3434, device='cuda:0'),
#  'preds': array([False, False, False, ..., False, False, False]),
#  'truth': array([0., 0., 0., ..., 0., 0., 0.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:12 TEST RESULTS
# {'loss': tensor(0.3353, device='cuda:0'),
#  'preds': array([False, False, False, ...,  True, False, False]),
#  'truth': array([1., 0., 0., ..., 1., 0., 0.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:13 TEST RESULTS
# ...
#  'preds': array([False, False, False, ...,  True, False,  True]),
#  'truth': array([0., 0., 0., ..., 1., 1., 1.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:10 TEST RESULTS
# {'loss': tensor(0.3327, device='cuda:0'),
#  'preds': array([ True, False, False, ..., False, False, False]),
#  'truth': array([1., 0., 0., ..., 0., 0., 0.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:11 TEST RESULTS
# {'loss': tensor(0.3434, device='cuda:0'),
#  'preds': array([False, False, False, ..., False, False, False]),
#  'truth': array([0., 0., 0., ..., 0., 0., 0.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:12 TEST RESULTS
# {'loss': tensor(0.3353, device='cuda:0'),
#  'preds': array([False, False, False, ...,  True, False, False]),
#  'truth': array([1., 0., 0., ..., 1., 0., 0.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:13 TEST RESULTS
# {'loss': tensor(0.3670, device='cuda:0'),
#  'preds': array([ True,  True,  True, ..., False,  True, False]),
#  'truth': array([1., 1., 1., ..., 0., 1., 0.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:14 TEST RESULTS
# {'loss': tensor(0.3428, device='cuda:0'),
#  'preds': array([False, False, False, ...,  True,  True,  True]),
#  'truth': array([0., 0., 0., ..., 1., 1., 1.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:15 TEST RESULTS
# {'loss': tensor(0.3741, device='cuda:0'),
#  'preds': array([False, False, False, ...,  True, False, False]),
#  'truth': array([0., 0., 1., ..., 1., 0., 1.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:16 TEST RESULTS
# {'loss': tensor(0.3599, device='cuda:0'),
#  'preds': array([ True,  True, False, ...,  True, False,  True]),
#  'truth': array([1., 1., 0., ..., 1., 0., 1.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:17 TEST RESULTS
# {'loss': tensor(0.3532, device='cuda:0'),
#  'preds': array([False, False, False, ..., False, False,  True]),
#  'truth': array([0., 1., 0., ..., 0., 0., 1.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:18 TEST RESULTS
# {'loss': tensor(0.3383, device='cuda:0'),
#  'preds': array([False, False, False, ...,  True, False,  True]),
#  'truth': array([1., 0., 0., ..., 1., 0., 1.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:19 TEST RESULTS
# {'loss': tensor(0.3350, device='cuda:0'),
#  'preds': array([False, False, False, ...,  True,  True,  True]),
#  'truth': array([0., 0., 0., ..., 0., 1., 1.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:20 TEST RESULTS
# {'loss': tensor(0.3393, device='cuda:0'),
#  'preds': array([False, False, False, ..., False,  True,  True]),
#  'truth': array([0., 1., 0., ..., 0., 1., 1.], dtype=float32)}
# --------------------------------------------------------------------------------
# Set SLURM handle signals.
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Testing', layout=Layout(flex='2'), max=…
# --------------------------------------------------------------------------------
# DATALOADER:0 TEST RESULTS
# {'current_lr': tensor(0.0010),
#  'eff': tensor(0.6653, device='cuda:0'),
#  'loss': tensor(0.3393, device='cuda:0'),
#  'preds': array([False, False, False, ..., False,  True,  True]),
#  'pur': tensor(0.9680, device='cuda:0'),
#  'train_loss': tensor(0.3398, device='cuda:0'),
#  'truth': array([0., 1., 0., ..., 0., 1., 1.], dtype=float32),
#  'val_loss': tensor(0.3448, device='cuda:0')}
# --------------------------------------------------------------------------------
# DATALOADER:1 TEST RESULTS
# {'loss': tensor(0.3508, device='cuda:0'),
#  'preds': array([ True, False, False, ...,  True,  True,  True]),
#  'truth': array([0., 1., 0., ..., 1., 1., 1.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:2 TEST RESULTS
# {'loss': tensor(0.3676, device='cuda:0'),
#  'preds': array([False, False, False, ..., False,  True, False]),
#  'truth': array([0., 1., 1., ..., 1., 1., 0.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:3 TEST RESULTS
# {'loss': tensor(0.3597, device='cuda:0'),
#  'preds': array([False, False, False, ...,  True, False, False]),
#  'truth': array([0., 0., 0., ..., 1., 0., 0.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:4 TEST RESULTS
# {'loss': tensor(0.3357, device='cuda:0'),
#  'preds': array([False, False, False, ...,  True, False, False]),
#  'truth': array([1., 1., 0., ..., 1., 0., 0.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:5 TEST RESULTS
# {'loss': tensor(0.3430, device='cuda:0'),
#  'preds': array([False, False, False, ..., False, False, False]),
#  'truth': array([0., 0., 0., ..., 1., 0., 0.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:6 TEST RESULTS
# {'loss': tensor(0.3243, device='cuda:0'),
#  'preds': array([ True, False, False, ...,  True, False, False]),
#  'truth': array([0., 1., 0., ..., 1., 0., 0.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:7 TEST RESULTS
# {'loss': tensor(0.3686, device='cuda:0'),
#  'preds': array([False,  True, False, ..., False, False,  True]),
#  'truth': array([0., 0., 0., ..., 0., 0., 1.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:8 TEST RESULTS
# {'loss': tensor(0.2785, device='cuda:0'),
#  'preds': array([ True, False, False, ...,  True,  True,  True]),
#  'truth': array([1., 1., 0., ..., 1., 1., 1.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:9 TEST RESULTS
# {'loss': tensor(0.3476, device='cuda:0'),
#  'preds': array([False, False, False, ...,  True, False,  True]),
#  'truth': array([0., 0., 0., ..., 1., 1., 1.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:10 TEST RESULTS
# {'loss': tensor(0.3327, device='cuda:0'),
#  'preds': array([ True, False, False, ..., False, False, False]),
#  'truth': array([1., 0., 0., ..., 0., 0., 0.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:11 TEST RESULTS
# {'loss': tensor(0.3434, device='cuda:0'),
#  'preds': array([False, False, False, ..., False, False, False]),
#  'truth': array([0., 0., 0., ..., 0., 0., 0.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:12 TEST RESULTS
# {'loss': tensor(0.3353, device='cuda:0'),
#  'preds': array([False, False, False, ..., False, False, False]),
#  'truth': array([1., 0., 0., ..., 1., 0., 0.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:13 TEST RESULTS
# {'loss': tensor(0.3670, device='cuda:0'),
#  'preds': array([ True,  True,  True, ..., False,  True, False]),
#  'truth': array([1., 1., 1., ..., 0., 1., 0.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:14 TEST RESULTS
# {'loss': tensor(0.3428, device='cuda:0'),
#  'preds': array([False, False, False, ...,  True,  True,  True]),
#  'truth': array([0., 0., 0., ..., 1., 1., 1.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:15 TEST RESULTS
# {'loss': tensor(0.3741, device='cuda:0'),
#  'preds': array([False, False, False, ...,  True, False, False]),
#  'truth': array([0., 0., 1., ..., 1., 0., 1.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:16 TEST RESULTS
# {'loss': tensor(0.3599, device='cuda:0'),
#  'preds': array([False, False, False, ...,  True, False,  True]),
#  'truth': array([1., 1., 0., ..., 1., 0., 1.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:17 TEST RESULTS
# {'loss': tensor(0.3532, device='cuda:0'),
#  'preds': array([False, False, False, ..., False, False,  True]),
#  'truth': array([0., 1., 0., ..., 0., 0., 1.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:18 TEST RESULTS
# {'loss': tensor(0.3383, device='cuda:0'),
#  'preds': array([False, False, False, ...,  True, False,  True]),
#  'truth': array([1., 0., 0., ..., 1., 0., 1.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:19 TEST RESULTS
# {'loss': tensor(0.3350, device='cuda:0'),
#  'preds': array([False, False, False, ...,  True,  True,  True]),
#  'truth': array([0., 0., 0., ..., 0., 1., 1.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:20 TEST RESULTS
# {'loss': tensor(0.3393, device='cuda:0'),
#  'preds': array([False, False, False, ..., False,  True,  True]),
#  'truth': array([0., 1., 0., ..., 0., 1., 1.], dtype=float32)}
# --------------------------------------------------------------------------------
# Set SLURM handle signals.
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Testing', layout=Layout(flex='2'), max=…
# --------------------------------------------------------------------------------
# DATALOADER:0 TEST RESULTS
# {'current_lr': tensor(0.0010),
#  'eff': tensor(0., device='cuda:0'),
#  'loss': tensor(0.3393, device='cuda:0'),
#  'preds': array([False, False, False, ..., False,  True,  True]),
#  'pur': tensor(nan, device='cuda:0'),
#  'train_loss': tensor(0.3398, device='cuda:0'),
#  'truth': array([0., 1., 0., ..., 0., 1., 1.], dtype=float32),
#  'val_loss': tensor(0.3448, device='cuda:0')}
# --------------------------------------------------------------------------------
# DATALOADER:1 TEST RESULTS
# {'loss': tensor(0.3508, device='cuda:0'),
#  'preds': array([False, False, False, ..., False, False, False]),
#  'truth': array([0., 1., 0., ..., 1., 1., 1.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:2 TEST RESULTS
# {'loss': tensor(0.3676, device='cuda:0'),
#  'preds': array([False, False, False, ..., False, False, False]),
#  'truth': array([0., 1., 1., ..., 1., 1., 0.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:3 TEST RESULTS
# {'loss': tensor(0.3597, device='cuda:0'),
#  'preds': array([False, False, False, ..., False, False, False]),
#  'truth': array([0., 0., 0., ..., 1., 0., 0.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:4 TEST RESULTS
# {'loss': tensor(0.3357, device='cuda:0'),
#  'preds': array([False, False, False, ..., False, False, False]),
#  'truth': array([1., 1., 0., ..., 1., 0., 0.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:5 TEST RESULTS
# {'loss': tensor(0.3430, device='cuda:0'),
#  'preds': array([False, False, False, ..., False, False, False]),
#  'truth': array([0., 0., 0., ..., 1., 0., 0.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:6 TEST RESULTS
# {'loss': tensor(0.3243, device='cuda:0'),
#  'preds': array([False, False, False, ..., False, False, False]),
#  'truth': array([0., 1., 0., ..., 1., 0., 0.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:7 TEST RESULTS
# {'loss': tensor(0.3686, device='cuda:0'),
#  'preds': array([False, False, False, ..., False, False, False]),
#  'truth': array([0., 0., 0., ..., 0., 0., 1.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:8 TEST RESULTS
# {'loss': tensor(0.2785, device='cuda:0'),
#  'preds': array([False, False, False, ..., False, False, False]),
#  'truth': array([1., 1., 0., ..., 1., 1., 1.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:9 TEST RESULTS
# {'loss': tensor(0.3476, device='cuda:0'),
#  'preds': array([False, False, False, ..., False, False, False]),
#  'truth': array([0., 0., 0., ..., 1., 1., 1.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:10 TEST RESULTS
# {'loss': tensor(0.3327, device='cuda:0'),
#  'preds': array([False, False, False, ..., False, False, False]),
#  'truth': array([1., 0., 0., ..., 0., 0., 0.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:11 TEST RESULTS
# {'loss': tensor(0.3434, device='cuda:0'),
#  'preds': array([False, False, False, ..., False, False, False]),
#  'truth': array([0., 0., 0., ..., 0., 0., 0.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:12 TEST RESULTS
# {'loss': tensor(0.3353, device='cuda:0'),
#  'preds': array([False, False, False, ..., False, False, False]),
#  'truth': array([1., 0., 0., ..., 1., 0., 0.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:13 TEST RESULTS
# {'loss': tensor(0.3670, device='cuda:0'),
#  'preds': array([False, False, False, ..., False, False, False]),
#  'truth': array([1., 1., 1., ..., 0., 1., 0.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:14 TEST RESULTS
# {'loss': tensor(0.3428, device='cuda:0'),
#  'preds': array([False, False, False, ..., False, False, False]),
#  'truth': array([0., 0., 0., ..., 1., 1., 1.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:15 TEST RESULTS
# {'loss': tensor(0.3741, device='cuda:0'),
#  'preds': array([False, False, False, ..., False, False, False]),
#  'truth': array([0., 0., 1., ..., 1., 0., 1.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:16 TEST RESULTS
# {'loss': tensor(0.3599, device='cuda:0'),
#  'preds': array([False, False, False, ..., False, False, False]),
#  'truth': array([1., 1., 0., ..., 1., 0., 1.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:17 TEST RESULTS
# {'loss': tensor(0.3532, device='cuda:0'),
#  'preds': array([False, False, False, ..., False, False, False]),
#  'truth': array([0., 1., 0., ..., 0., 0., 1.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:18 TEST RESULTS
# {'loss': tensor(0.3383, device='cuda:0'),
#  'preds': array([False, False, False, ..., False, False, False]),
#  'truth': array([1., 0., 0., ..., 1., 0., 1.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:19 TEST RESULTS
# {'loss': tensor(0.3350, device='cuda:0'),
#  'preds': array([False, False, False, ..., False, False, False]),
#  'truth': array([0., 0., 0., ..., 0., 1., 1.], dtype=float32)}
# --------------------------------------------------------------------------------
# DATALOADER:20 TEST RESULTS
# {'loss': tensor(0.3393, device='cuda:0'),
#  'preds': array([False, False, False, ..., False, False, False]),
#  'truth': array([0., 1., 0., ..., 0., 1., 1.], dtype=float32)}
# --------------------------------------------------------------------------------
# ../LightningModules/GNN/utils.py:187: RuntimeWarning: invalid value encountered in true_divide
#   purities = [tp/p for (p, tp) in zip(ps, tps)]

# %% [markdown]
# Let's check that indeed the Attention mechanism improved performance:

# %%
plt.figure(figsize=(12,8))
plt.plot(all_cuts, all_efficiencies, label="Efficiency");
plt.plot(all_cuts, all_purities, label="Purity");
plt.legend()
plt.title("Performance", fontsize=24), plt.xlabel("Edge cut", fontsize=18), plt.ylabel("Eff and Purity of GNN", fontsize=18);

# %% [markdown]
# ## Further Investigation

# %% [markdown]
# 1. Train the Attention GNN for longer! This was just a very short example.
# 1. Is there an effect on performance from the number of message passing steps (hopefully yes)?
# 1. Is there any performance gain from increasing the number of hidden channels?
# 2. What about *decreasing* the number of channels?
# 3. What about increasing/decreasing the number of dimensions in the latent space?
# 5. Play with the graph convolution! This can be found in the `forward` method of the `NodeNetwork` and `EdgeNetwork` classes. There are a million ways to combine edge features with node features, and there may be combinations that we haven't found yet!
# 4. Is it possible to overtrain? That is, try increasing the number of epochs and seeing if the validation loss always decreases, plateaus, or starts to increase. **Hint**: to overtrain, try reducing the number of training examples to a small number
