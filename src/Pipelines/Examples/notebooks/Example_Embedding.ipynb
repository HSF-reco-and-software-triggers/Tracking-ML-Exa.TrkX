# %% [markdown]
# # Example of Metric Learning in Embedded Space

# %%
# %load_ext autoreload
# %autoreload 2

# %%
# System imports
import os
import sys
import yaml

# External imports
import matplotlib.pyplot as plt
import scipy as sp
from sklearn.decomposition import PCA
from sklearn.metrics import auc
import numpy as np
import pandas as pd
import seaborn as sns
import torch

sys.path.append('..')
device = "cuda" if torch.cuda.is_available() else "cpu"

# %% [markdown]
# Example notebook for embedding TrackML hits
# - [ ] Load PyLightning model
# - [ ] Explain PyLightning model
# - [ ] Explain dataset in model
# - [ ] Plot some of the data
# - [ ] Explain embedding concept
# - [ ] Train embedding
# - [ ] Apply embedding
# - [ ] Plot embedding output
# - [ ] Explain hard negative mining + RP for training
# - [ ] Visualise performance
# - [ ] Explain some relevant hyperparameters

# %% [markdown]
# ## Pytorch Lightning Model

# %% [markdown]
# In this example notebook, we will use an approach to ML called Pytorch Lightning. Pytorch is a library like Tensorflow, which is very popular in ML engineering. It's main appeal is foolproof tracking of gradients for backpropagation, and very easy manipulation of tensors on and off GPUs.
#
# Pytorch Lightning is an extension of Pytorch that makes some decisions about the best-practices for training. Instead of you writing the training loop yourself, and moving things on and off a GPU, it handles much of this for you. You write all the data loading logic, the loss functions, etc. into a `LightningModule` and then hand this module to a `Trainer`. Together, the module and trainer are the two objects that allow training and inference.

# %% [markdown]
# So we start by importing a class that we have written ourselves, in this case a LightningModule that is in charge of loading TrackML (Codalab) data, and training and validating an embedding/metric learning model.

# %%
from LightningModules.Embedding.Models.layerless_embedding import LayerlessEmbedding

# %% [markdown]
# ### Construct PyLightning model

# %% [markdown]
# An ML model typically has many knobs to turn, as well as locations of data, some training preferences, and so on. For convenience, let's put all of these parameters into a YAML file and load it.

# %%
with open("example_embedding.yaml") as f:
        hparams = yaml.load(f, Loader=yaml.FullLoader)

# %% [markdown]
# We plug these parameters into a constructor of the `LayerlessEmbedding` Lightning Module. This doesn't **do** anything yet - merely creates the object.

# %%
model = LayerlessEmbedding(hparams)

# %% [markdown]
# ## The Dataset

# %% [markdown]
# To load the data, we call a `setup` method. There is some flexibility in how to handle data, and one should check the Pytorch Lightning docs to see the spectrum of options. This is my favourite way: Hide all of the data loading inside the Lightning module. We are explicitly calling `setup` here because we're going to visualise some of the data first. In future, once you know the nature of the data, we can skip this step, since the trainer will call this automatically when it starts training.

# %% [markdown]
# NOTE: This may take a minute or two, since the data is being trimmed to particles above a certain momentum threshold.

# %%
model.setup(stage="fit")

# %% [markdown]
# ### Visualise geometry

# %% [markdown]
# Just as a sanity check, let's look directly at the geometry of the data, as well as some distributions. This is just to make sure that, e.g. it's normalised in some reasonable way (that is, it doesn't vary from -1000 to +1000 or some large numbers, but that it is distributed close to +1 and -1 - this makes training much more effective!), and there aren't weird outliers (this also damages training!).

# %%
trainset = model.trainset

# %%
example_data = trainset[0]
r, phi, z = example_data.x.T

# %%
x, y = r*np.cos(phi*np.pi), r*np.sin(phi*np.pi)

# %%
plt.figure(figsize=(12,12))
plt.scatter(r, z)
plt.title("Longitudinal View of Detector", fontsize=24), plt.xlabel("r", fontsize=18), plt.ylabel("z", fontsize=18)
# Out:
# (Text(0.5, 1.0, 'Longitudinal View of Detector'),
#  Text(0.5, 0, 'r'),
#  Text(0, 0.5, 'z'))

# %%
plt.figure(figsize=(12,12))
plt.scatter(x, y)
plt.title("Azimuthal View of Detector", fontsize=24), plt.xlabel("x", fontsize=18), plt.ylabel("y", fontsize=18)
# Out:
# (Text(0.5, 1.0, 'Azimuthal View of Detector'),
#  Text(0.5, 0, 'x'),
#  Text(0, 0.5, 'y'))

# %% [markdown]
# ### Visualise distributions

# %%
plt.figure(figsize=(12,8))
sns.histplot(example_data.pt, binrange=[0, 5])
plt.title("Distribution of Momentum", fontsize=24), plt.xlabel("pT (GeV)", fontsize=18), plt.ylabel("Count", fontsize=18)
# Out:
# (Text(0.5, 1.0, 'Distribution of Momentum'),
#  Text(0.5, 0, 'pT (GeV)'),
#  Text(0, 0.5, 'Count'))

# %% [markdown]
# Observe the hard cut-off below 1GeV - this is because we are ignoring lower energy hits to keep things easy for now. But we should include them again once we are happy with our ML architecture!

# %%
_, particle_counts = np.unique(example_data.pid.numpy(), return_counts = True)

# %%
plt.figure(figsize=(12,8))
sns.histplot(particle_counts, binwidth=1)
plt.title("Distribution of Hits per Particle", fontsize=24), plt.xlabel("Hits", fontsize=18), plt.ylabel("Count", fontsize=18)
# Out:
# (Text(0.5, 1.0, 'Distribution of Hits per Particle'),
#  Text(0.5, 0, 'Hits'),
#  Text(0, 0.5, 'Count'))

# %% [markdown]
# This gives an idea about how long each particle track is. We can see that most particle tracks leave > 10 hits, which will be useful for our graph neural networks down the track. In general, shorter tracks are harder to detect, and less useful for doing meaningful physics.

# %% [markdown]
# ## Metric Learning

# %%
from pytorch_lightning import Trainer

# %% [markdown]
# ### Train embedding

# %% [markdown]
# Finally! Let's train! We instantiate a `Trainer` class that knows things like which hardware to work with, how long to train for, and a **bunch** of default options that we ignore here. Check out the Trainer class docs in Pytorch Lightning. Suffice it to say that it clears away much repetitive boilerplate in training code.

# %%
trainer = Trainer(gpus=1, max_epochs=10)
trainer.fit(model)
# Out:
# GPU available: True, used: True
# INFO:lightning:GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# INFO:lightning:TPU available: False, using: 0 TPU cores
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:lightning:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Set SLURM handle signals.
# INFO:lightning:Set SLURM handle signals.
#
#   | Name      | Type       | Params
# -----------------------------------------
# 0 | layers    | ModuleList | 13 K
# 1 | emb_layer | Linear     | 520
# 2 | norm      | LayerNorm  | 128
# 3 | act       | Tanh       | 0
# INFO:lightning:
#   | Name      | Type       | Params
# -----------------------------------------
# 0 | layers    | ModuleList | 13 K
# 1 | emb_layer | Linear     | 520
# 2 | norm      | LayerNorm  | 128
# 3 | act       | Tanh       | 0
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validation sanity check', layout=Layout…
# ../LightningModules/Embedding/embedding_base.py:179: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   logging.info("Purity: {}".format(pur))
# ../LightningModules/Embedding/embedding_base.py:180: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   logging.info(batch.event_file)
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Training', layout=Layout(flex='2'), max…
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validating', layout=Layout(flex='2'), m…
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validating', layout=Layout(flex='2'), m…
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validating', layout=Layout(flex='2'), m…
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validating', layout=Layout(flex='2'), m…
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validating', layout=Layout(flex='2'), m…
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validating', layout=Layout(flex='2'), m…
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validating', layout=Layout(flex='2'), m…
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validating', layout=Layout(flex='2'), m…
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validating', layout=Layout(flex='2'), m…
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validating', layout=Layout(flex='2'), m…
# 1

# %% [markdown]
# ### Test embedding

# %% [markdown]
# A Pytorch Lightning Trainer has two main methods: `fit` and `test`. They represent the two main steps of any ML engingeering or research: Train a model, then make sure it can infer accurately on test (i.e. **hidden**) data.

# %% [markdown]
# Note that `ckpt_path` just tells the trainer to use the latest "checkpoint" of the model, rather than *best* checkpoint. A checkpoint is a saved version of the model, a snapshot at a particular stage of the training process. Pytorch Lightning automatically saves a checkpoint of your model in case something crashes and we need to resume.

# %%
test_results = trainer.test(ckpt_path=None)
# Out:
# Set SLURM handle signals.
# INFO:lightning:Set SLURM handle signals.
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Testing', layout=Layout(flex='2'), max=…
# --------------------------------------------------------------------------------
# DATALOADER:0 TEST RESULTS
# {'loss': tensor(0.9384, device='cuda:0'),
#  'preds': array([[    0,     0,     0, ..., 12138, 12138, 12138],
#        [    1,    50,   107, ..., 11792, 11807, 11989]]),
#  'truth': array([False, False, False, ..., False,  True, False]),
#  'truth_graph': array([[  60,   60,  133, ..., 4898, 6374, 7943],
#        [ 606,  662,  606, ..., 3861, 4898, 6374]])}
# --------------------------------------------------------------------------------
# DATALOADER:1 TEST RESULTS
# {'loss': tensor(0.9367, device='cuda:0'),
#  'preds': array([[    0,     0,     0, ..., 10328, 10328, 10328],
#        [   12,  1966,  2119, ..., 10222, 10223, 10235]]),
#  'truth': array([False,  True, False, ..., False, False, False]),
#  'truth_graph': array([[2662, 2662, 4038, ..., 9154, 9520, 9805],
#        [4038, 4068, 4771, ..., 8278, 9154, 9520]])}
# --------------------------------------------------------------------------------
# DATALOADER:2 TEST RESULTS
# {'loss': tensor(0.9457, device='cuda:0'),
#  'preds': array([[    0,     0,     0, ..., 14294, 14294, 14294],
#        [  899,   951,  1221, ..., 14235, 14287, 14289]]),
#  'truth': array([False, False,  True, ..., False, False, False]),
#  'truth_graph': array([[ 3121,  3121,  3310, ..., 11432, 12165, 12165],
#        [ 6073,  6122,  6073, ..., 10525, 11409, 11432]])}
# --------------------------------------------------------------------------------
# DATALOADER:3 TEST RESULTS
# {'loss': tensor(0.9499, device='cuda:0'),
#  'preds': array([[    0,     0,     0, ..., 15165, 15165, 15165],
#        [ 1617,  2221,  2419, ..., 14798, 14799, 15149]]),
#  'truth': array([False, False, False, ...,  True,  True, False]),
#  'truth_graph': array([[  398,  1362,  1362, ..., 10712, 10712, 12744],
#        [ 1362,  2246,  2271, ...,  9636,  9682, 10712]])}
# --------------------------------------------------------------------------------
# DATALOADER:4 TEST RESULTS
# {'loss': tensor(0.9438, device='cuda:0'),
#  'preds': array([[    0,     1,     1, ..., 12411, 12411, 12411],
#        [ 1035,     3,    35, ..., 11763, 12118, 12410]]),
#  'truth': array([ True, False, False, ..., False,  True, False]),
#  'truth_graph': array([[ 438, 1196, 1196, ..., 6388, 7803, 9220],
#        [1196, 2024, 2060, ..., 4736, 6388, 7803]])}
# --------------------------------------------------------------------------------
# DATALOADER:5 TEST RESULTS
# {'loss': tensor(0.9446, device='cuda:0'),
#  'preds': array([[    0,     0,     0, ..., 12919, 12919, 12919],
#        [  116,   168,   306, ..., 11875, 12243, 12592]]),
#  'truth': array([False, False, False, ..., False, False,  True]),
#  'truth_graph': array([[ 1474,  1583,  3120, ..., 11927, 12284, 12643],
#        [ 3120,  3120,  4250, ..., 11526, 11927, 12284]])}
# --------------------------------------------------------------------------------
# DATALOADER:6 TEST RESULTS
# {'loss': tensor(0.9312, device='cuda:0'),
#  'preds': array([[    0,     0,     0, ..., 10675, 10675, 10675],
#        [    7,  5575,  5599, ..., 10362, 10379, 10669]]),
#  'truth': array([False, False, False, ..., False,  True, False]),
#  'truth_graph': array([[ 213,  754, 1331, ...,  781, 1341, 1988],
#        [ 754, 1331, 1961, ...,  243,  781, 1341]])}
# --------------------------------------------------------------------------------
# DATALOADER:7 TEST RESULTS
# {'loss': tensor(0.9487, device='cuda:0'),
#  'preds': array([[    0,     0,     0, ..., 14283, 14283, 14283],
#        [ 1683,  1946,  3622, ..., 14205, 14251, 14273]]),
#  'truth': array([ True, False, False, ..., False, False, False]),
#  'truth_graph': array([[ 2003,  2031,  2105, ...,  7873,  9879, 11186],
#        [ 4096,  4096,  4096, ...,  5713,  7873,  9879]])}
# --------------------------------------------------------------------------------
# DATALOADER:8 TEST RESULTS
# {'loss': tensor(0.9463, device='cuda:0'),
#  'preds': array([[    0,     0,     0, ..., 14742, 14742, 14742],
#        [    4,  1349,  1414, ..., 14357, 14696, 14702]]),
#  'truth': array([False,  True,  True, ...,  True, False, False]),
#  'truth_graph': array([[  332,  1135,  1962, ...,  9651, 11510, 13121],
#        [ 1135,  1962,  2827, ...,  7044,  9651, 11510]])}
# --------------------------------------------------------------------------------
# DATALOADER:9 TEST RESULTS
# {'loss': tensor(0.9446, device='cuda:0'),
#  'preds': array([[    0,     0,     0, ..., 13944, 13944, 13944],
#        [    2,   167,   384, ..., 13573, 13574, 13943]]),
#  'truth': array([False, False,  True, ..., False, False, False]),
#  'truth_graph': array([[1311, 2919, 2919, ..., 6518, 8201, 9794],
#        [2919, 4143, 4192, ..., 4997, 6518, 8201]])}
# --------------------------------------------------------------------------------
# DATALOADER:10 TEST RESULTS
# {'loss': tensor(0.9478, device='cuda:0'),
#  'preds': array([[    0,     0,     0, ..., 14015, 14016, 14016],
#        [  198,   216,   391, ..., 14001, 12891, 13656]]),
#  'truth': array([False, False,  True, ..., False, False,  True]),
#  'truth_graph': array([[  618,   655,  1826, ...,  7487,  9028, 10620],
#        [ 1826,  1826,  2872, ...,  5554,  7487,  9028]])}
# --------------------------------------------------------------------------------
# DATALOADER:11 TEST RESULTS
# {'loss': tensor(0.9453, device='cuda:0'),
#  'preds': array([[    0,     0,     0, ..., 13423, 13423, 13423],
#        [    5,  1798,  3772, ..., 13086, 13406, 13422]]),
#  'truth': array([False,  True, False, ...,  True, False, False]),
#  'truth_graph': array([[ 1578,  3277,  4511, ..., 11266, 12007, 12407],
#        [ 3277,  4511,  5766, ...,  9464, 11266, 12007]])}
# --------------------------------------------------------------------------------
# DATALOADER:12 TEST RESULTS
# {'loss': tensor(0.9386, device='cuda:0'),
#  'preds': array([[   0,    0,    0, ..., 8076, 8076, 8076],
#        [  25,   64,  107, ..., 7880, 7985, 7991]]),
#  'truth': array([False, False, False, ...,  True, False, False]),
#  'truth_graph': array([[ 121,  155,  604, ..., 7687, 7892, 7896],
#        [ 604,  604, 1022, ..., 7465, 7687, 7687]])}
# --------------------------------------------------------------------------------
# DATALOADER:13 TEST RESULTS
# {'loss': tensor(0.9310, device='cuda:0'),
#  'preds': array([[    0,     0,     0, ..., 10365, 10365, 10365],
#        [    1,     3,     5, ...,  9496, 10098, 10100]]),
#  'truth': array([False, False, False, ..., False,  True,  True]),
#  'truth_graph': array([[  977,  2196,  2196, ...,  8374,  8887, 10205],
#        [ 2196,  3112,  3156, ...,  6897,  8374,  8887]])}
# --------------------------------------------------------------------------------
# DATALOADER:14 TEST RESULTS
# {'loss': tensor(0.9482, device='cuda:0'),
#  'preds': array([[    0,     0,     0, ..., 14872, 14872, 14872],
#        [   22,   181,   285, ..., 14828, 14850, 14868]]),
#  'truth': array([False, False, False, ..., False, False, False]),
#  'truth_graph': array([[ 1291,  3021,  4279, ...,  5237, 13584, 13584],
#        [ 3021,  4279,  5513, ...,  3800,  5195,  5237]])}
# --------------------------------------------------------------------------------
# DATALOADER:15 TEST RESULTS
# {'loss': tensor(0.9454, device='cuda:0'),
#  'preds': array([[    0,     0,     0, ..., 14041, 14041, 14041],
#        [ 9296, 10330, 11289, ..., 13975, 14028, 14031]]),
#  'truth': array([False, False, False, ..., False, False, False]),
#  'truth_graph': array([[  120,   790,  1516, ..., 12972, 13368, 13741],
#        [  790,  1516,  2254, ..., 12527, 12972, 13368]])}
# --------------------------------------------------------------------------------
# DATALOADER:16 TEST RESULTS
# {'loss': tensor(0.9464, device='cuda:0'),
#  'preds': array([[    0,     0,     0, ..., 13936, 13936, 13936],
#        [  447,   474,   476, ..., 13886, 13928, 13933]]),
#  'truth': array([False, False, False, ..., False, False, False]),
#  'truth_graph': array([[ 1961,  2036,  3957, ..., 11098, 12162, 12743],
#        [ 3957,  3957,  5305, ...,  9151, 11098, 12162]])}
# --------------------------------------------------------------------------------
# DATALOADER:17 TEST RESULTS
# {'loss': tensor(0.9496, device='cuda:0'),
#  'preds': array([[    0,     0,     0, ..., 14476, 14476, 14476],
#        [    5,   357,   366, ..., 14074, 14076, 14407]]),
#  'truth': array([False, False, False, ...,  True,  True, False]),
#  'truth_graph': array([[ 5592,  5592,  5592, ..., 10928, 10945, 10965],
#        [ 6564,  6569,  6619, ...,  9364,  9364,  9364]])}
# --------------------------------------------------------------------------------
# DATALOADER:18 TEST RESULTS
# {'loss': tensor(0.9505, device='cuda:0'),
#  'preds': array([[    0,     0,     0, ..., 14966, 14966, 14966],
#        [ 1107,  1150,  2614, ..., 14945, 14964, 14965]]),
#  'truth': array([False,  True, False, ..., False, False, False]),
#  'truth_graph': array([[  661,   661,  1814, ...,  7008, 10734, 12626],
#        [ 1814,  1865,  2925, ...,  4020,  7008, 10734]])}
# --------------------------------------------------------------------------------
# DATALOADER:19 TEST RESULTS
# {'loss': tensor(0.9399, device='cuda:0'),
#  'preds': array([[    0,     0,     0, ..., 12150, 12150, 12150],
#        [  132,   686,   695, ..., 11810, 11812, 11813]]),
#  'truth': array([False, False, False, ...,  True,  True,  True]),
#  'truth_graph': array([[  103,   103,   179, ..., 11070, 11463, 11463],
#        [  706,   760,   706, ...,  9935, 11067, 11070]])}
# --------------------------------------------------------------------------------

# %% [markdown]
# ## Performance

# %%
from LightningModules.Embedding.utils import get_metrics

# %% [markdown]
# Let's see how well the model learned to embed the hits into a space that separates them into discrete clusters. As in the data visualisation above, we are going manual here. So one thing we need to do is tell the model that we are **evaluating**, not **training**, with `model.eval()`. We also make sure to wrap everything with `with torch.no_grad()` to ignore any gradients. This speeds things up and gives the GPU's memory a rest, since we're not interesting in any kind of training from here on in.

# %%
model.eval();

# %% [markdown]
# ### Test metrics

# %%
all_efficiencies, all_purities = [], []
all_radius = np.arange(0.5, 1.2, 0.1)

with torch.no_grad():
    for r in all_radius:

        model.hparams.r_test = r
        test_results = trainer.test(ckpt_path=None)

        mean_efficiency, mean_purity = get_metrics(test_results, model)

        all_efficiencies.append(mean_efficiency)
        all_purities.append(mean_purity)
# Out:
# Set SLURM handle signals.
# INFO:lightning:Set SLURM handle signals.
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Testing', layout=Layout(flex='2'), max=…
# Set SLURM handle signals.
# INFO:lightning:Set SLURM handle signals.
# --------------------------------------------------------------------------------
# DATALOADER:0 TEST RESULTS
# {'loss': tensor(0.5963, device='cuda:0'),
#  'preds': array([[    0,     3,     3, ..., 12136, 12136, 12138],
#        [  273,     4,   803, ..., 11802, 12018, 11807]]),
#  'truth': array([ True, False,  True, ...,  True, False,  True]),
#  'truth_graph': array([[  60,   60,  133, ..., 4898, 6374, 7943],
#        [ 606,  662,  606, ..., 3861, 4898, 6374]])}
# --------------------------------------------------------------------------------
# DATALOADER:1 TEST RESULTS
# {'loss': tensor(0.5957, device='cuda:0'),
#  'preds': array([[    0,     1,     1, ..., 10326, 10327, 10328],
#        [   12,     2,     6, ..., 10044, 10046, 10048]]),
#  'truth': array([False, False, False, ...,  True,  True,  True]),
#  'truth_graph': array([[2662, 2662, 4038, ..., 9154, 9520, 9805],
#        [4038, 4068, 4771, ..., 8278, 9154, 9520]])}
# --------------------------------------------------------------------------------
# DATALOADER:2 TEST RESULTS
# {'loss': tensor(0.6049, device='cuda:0'),
#  'preds': array([[    1,     1,     2, ..., 14294, 14294, 14294],
#        [ 3927,  7233,    46, ..., 14228, 14287, 14289]]),
#  'truth': array([ True, False, False, ..., False, False, False]),
#  'truth_graph': array([[ 3121,  3121,  3310, ..., 11432, 12165, 12165],
#        [ 6073,  6122,  6073, ..., 10525, 11409, 11432]])}
# --------------------------------------------------------------------------------
# DATALOADER:3 TEST RESULTS
# {'loss': tensor(0.6160, device='cuda:0'),
#  'preds': array([[    0,     1,     2, ..., 15164, 15165, 15165],
#        [ 1617,  1265,   593, ..., 15162, 14798, 14799]]),
#  'truth': array([False,  True, False, ..., False,  True,  True]),
#  'truth_graph': array([[  398,  1362,  1362, ..., 10712, 10712, 12744],
#        [ 1362,  2246,  2271, ...,  9636,  9682, 10712]])}
# --------------------------------------------------------------------------------
# DATALOADER:4 TEST RESULTS
# {'loss': tensor(0.6087, device='cuda:0'),
#  'preds': array([[    1,     1,     3, ..., 12410, 12411, 12411],
#        [    3,   839,     1, ..., 12411, 12118, 12410]]),
#  'truth': array([False, False, False, ..., False,  True, False]),
#  'truth_graph': array([[ 438, 1196, 1196, ..., 6388, 7803, 9220],
#        [1196, 2024, 2060, ..., 4736, 6388, 7803]])}
# --------------------------------------------------------------------------------
# DATALOADER:5 TEST RESULTS
# {'loss': tensor(0.6273, device='cuda:0'),
#  'preds': array([[    0,     0,     1, ..., 12917, 12918, 12919],
#        [  168,   823,  1859, ..., 12574, 12573, 12592]]),
#  'truth': array([False, False,  True, ...,  True,  True,  True]),
#  'truth_graph': array([[ 1474,  1583,  3120, ..., 11927, 12284, 12643],
#        [ 3120,  3120,  4250, ..., 11526, 11927, 12284]])}
# --------------------------------------------------------------------------------
# DATALOADER:6 TEST RESULTS
# {'loss': tensor(0.5910, device='cuda:0'),
#  'preds': array([[    2,     4,     4, ..., 10674, 10674, 10675],
#        [  548,   309,   922, ..., 10624, 10662, 10379]]),
#  'truth': array([False, False, False, ..., False, False,  True]),
#  'truth_graph': array([[ 213,  754, 1331, ...,  781, 1341, 1988],
#        [ 754, 1331, 1961, ...,  243,  781, 1341]])}
# --------------------------------------------------------------------------------
# DATALOADER:7 TEST RESULTS
# {'loss': tensor(0.6168, device='cuda:0'),
#  'preds': array([[    1,     2,     2, ..., 14283, 14283, 14283],
#        [  961,     4,  1630, ..., 13735, 13875, 14205]]),
#  'truth': array([False, False,  True, ..., False,  True, False]),
#  'truth_graph': array([[ 2003,  2031,  2105, ...,  7873,  9879, 11186],
#        [ 4096,  4096,  4096, ...,  5713,  7873,  9879]])}
# --------------------------------------------------------------------------------
# DATALOADER:8 TEST RESULTS
# {'loss': tensor(0.6125, device='cuda:0'),
#  'preds': array([[    0,     0,     0, ..., 14739, 14740, 14741],
#        [    4,  1349,  1414, ..., 14354, 14348, 14354]]),
#  'truth': array([False,  True,  True, ...,  True,  True,  True]),
#  'truth_graph': array([[  332,  1135,  1962, ...,  9651, 11510, 13121],
#        [ 1135,  1962,  2827, ...,  7044,  9651, 11510]])}
# --------------------------------------------------------------------------------
# DATALOADER:9 TEST RESULTS
# {'loss': tensor(0.6137, device='cuda:0'),
#  'preds': array([[    0,     1,     2, ..., 13944, 13944, 13944],
#        [    2,  1105,     0, ..., 13569, 13571, 13943]]),
#  'truth': array([False,  True, False, ...,  True,  True, False]),
#  'truth_graph': array([[1311, 2919, 2919, ..., 6518, 8201, 9794],
#        [2919, 4143, 4192, ..., 4997, 6518, 8201]])}
# --------------------------------------------------------------------------------
# DATALOADER:10 TEST RESULTS
# {'loss': tensor(0.6211, device='cuda:0'),
#  'preds': array([[    1,     1,     1, ..., 14015, 14015, 14016],
#        [   19,   118,   437, ..., 13651, 14001, 13656]]),
#  'truth': array([False, False,  True, ...,  True, False,  True]),
#  'truth_graph': array([[  618,   655,  1826, ...,  7487,  9028, 10620],
#        [ 1826,  1826,  2872, ...,  5554,  7487,  9028]])}
# --------------------------------------------------------------------------------
# DATALOADER:11 TEST RESULTS
# {'loss': tensor(0.6091, device='cuda:0'),
#  'preds': array([[    0,     0,     1, ..., 13422, 13423, 13423],
#        [    5,  1798,     4, ..., 13423, 13086, 13422]]),
#  'truth': array([False,  True, False, ..., False,  True, False]),
#  'truth_graph': array([[ 1578,  3277,  4511, ..., 11266, 12007, 12407],
#        [ 3277,  4511,  5766, ...,  9464, 11266, 12007]])}
# --------------------------------------------------------------------------------
# DATALOADER:12 TEST RESULTS
# {'loss': tensor(0.6091, device='cuda:0'),
#  'preds': array([[   0,    1,    1, ..., 8073, 8074, 8075],
#        [ 276, 3543, 3548, ..., 7873, 7877, 7883]]),
#  'truth': array([ True, False, False, ...,  True,  True,  True]),
#  'truth_graph': array([[ 121,  155,  604, ..., 7687, 7892, 7896],
#        [ 604,  604, 1022, ..., 7465, 7687, 7687]])}
# --------------------------------------------------------------------------------
# DATALOADER:13 TEST RESULTS
# {'loss': tensor(0.5834, device='cuda:0'),
#  'preds': array([[    0,     0,     0, ..., 10364, 10365, 10365],
#        [    1,     3,     5, ..., 10363, 10098, 10100]]),
#  'truth': array([False, False, False, ..., False,  True,  True]),
#  'truth_graph': array([[  977,  2196,  2196, ...,  8374,  8887, 10205],
#        [ 2196,  3112,  3156, ...,  6897,  8374,  8887]])}
# --------------------------------------------------------------------------------
# DATALOADER:14 TEST RESULTS
# {'loss': tensor(0.6160, device='cuda:0'),
#  'preds': array([[    0,     1,     1, ..., 14872, 14872, 14872],
#        [  555,     3,  3090, ..., 14442, 14488, 14850]]),
#  'truth': array([ True, False, False, ..., False,  True, False]),
#  'truth_graph': array([[ 1291,  3021,  4279, ...,  5237, 13584, 13584],
#        [ 3021,  4279,  5513, ...,  3800,  5195,  5237]])}
# --------------------------------------------------------------------------------
# DATALOADER:15 TEST RESULTS
# {'loss': tensor(0.6146, device='cuda:0'),
#  'preds': array([[    1,     3,     4, ..., 14041, 14041, 14041],
#        [ 1308,   626,   964, ..., 13684, 13689, 13975]]),
#  'truth': array([ True, False, False, ...,  True,  True, False]),
#  'truth_graph': array([[  120,   790,  1516, ..., 12972, 13368, 13741],
#        [  790,  1516,  2254, ..., 12527, 12972, 13368]])}
# --------------------------------------------------------------------------------
# DATALOADER:16 TEST RESULTS
# {'loss': tensor(0.6053, device='cuda:0'),
#  'preds': array([[    0,     0,     0, ..., 13935, 13936, 13936],
#        [ 1291,  1374,  2238, ..., 13860, 13528, 13529]]),
#  'truth': array([False, False, False, ..., False,  True,  True]),
#  'truth_graph': array([[ 1961,  2036,  3957, ..., 11098, 12162, 12743],
#        [ 3957,  3957,  5305, ...,  9151, 11098, 12162]])}
# --------------------------------------------------------------------------------
# DATALOADER:17 TEST RESULTS
# {'loss': tensor(0.6368, device='cuda:0'),
#  'preds': array([[    0,     0,     1, ..., 14475, 14476, 14476],
#        [    5,   650,   804, ..., 14071, 14074, 14076]]),
#  'truth': array([False, False,  True, ...,  True,  True,  True]),
#  'truth_graph': array([[ 5592,  5592,  5592, ..., 10928, 10945, 10965],
#        [ 6564,  6569,  6619, ...,  9364,  9364,  9364]])}
# --------------------------------------------------------------------------------
# DATALOADER:18 TEST RESULTS
# {'loss': tensor(0.6244, device='cuda:0'),
#  'preds': array([[    1,     3,     3, ..., 14966, 14966, 14966],
#        [    8,     4,  2040, ..., 14453, 14571, 14908]]),
#  'truth': array([False, False,  True, ..., False,  True, False]),
#  'truth_graph': array([[  661,   661,  1814, ...,  7008, 10734, 12626],
#        [ 1814,  1865,  2925, ...,  4020,  7008, 10734]])}
# --------------------------------------------------------------------------------
# DATALOADER:19 TEST RESULTS
# {'loss': tensor(0.5985, device='cuda:0'),
#  'preds': array([[    1,     1,     2, ..., 12150, 12150, 12150],
#        [    4,  1114,     6, ..., 11810, 11812, 11813]]),
#  'truth': array([False,  True, False, ...,  True,  True,  True]),
#  'truth_graph': array([[  103,   103,   179, ..., 11070, 11463, 11463],
#        [  706,   760,   706, ...,  9935, 11067, 11070]])}
# --------------------------------------------------------------------------------
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Testing', layout=Layout(flex='2'), max=…
# Set SLURM handle signals.
# INFO:lightning:Set SLURM handle signals.
# --------------------------------------------------------------------------------
# DATALOADER:0 TEST RESULTS
# {'loss': tensor(0.6349, device='cuda:0'),
#  'preds': array([[    0,     0,     2, ..., 12136, 12136, 12138],
#        [  273,   284,   714, ..., 11802, 12018, 11807]]),
#  'truth': array([ True, False,  True, ...,  True, False,  True]),
#  'truth_graph': array([[  60,   60,  133, ..., 4898, 6374, 7943],
#        [ 606,  662,  606, ..., 3861, 4898, 6374]])}
# --------------------------------------------------------------------------------
# DATALOADER:1 TEST RESULTS
# {'loss': tensor(0.6368, device='cuda:0'),
#  'preds': array([[    0,     1,     1, ..., 10326, 10327, 10328],
#        [   12,     2,     6, ..., 10044, 10046, 10048]]),
#  'truth': array([False, False, False, ...,  True,  True,  True]),
#  'truth_graph': array([[2662, 2662, 4038, ..., 9154, 9520, 9805],
#        [4038, 4068, 4771, ..., 8278, 9154, 9520]])}
# --------------------------------------------------------------------------------
# DATALOADER:2 TEST RESULTS
# {'loss': tensor(0.6486, device='cuda:0'),
#  'preds': array([[    1,     1,     1, ..., 14294, 14294, 14294],
#        [ 3927,  7233, 12393, ..., 14235, 14287, 14289]]),
#  'truth': array([ True, False, False, ..., False, False, False]),
#  'truth_graph': array([[ 3121,  3121,  3310, ..., 11432, 12165, 12165],
#        [ 6073,  6122,  6073, ..., 10525, 11409, 11432]])}
# --------------------------------------------------------------------------------
# DATALOADER:3 TEST RESULTS
# {'loss': tensor(0.6596, device='cuda:0'),
#  'preds': array([[    0,     1,     2, ..., 15164, 15165, 15165],
#        [ 1617,  1265,   593, ..., 15162, 14798, 14799]]),
#  'truth': array([False,  True, False, ..., False,  True,  True]),
#  'truth_graph': array([[  398,  1362,  1362, ..., 10712, 10712, 12744],
#        [ 1362,  2246,  2271, ...,  9636,  9682, 10712]])}
# --------------------------------------------------------------------------------
# DATALOADER:4 TEST RESULTS
# {'loss': tensor(0.6507, device='cuda:0'),
#  'preds': array([[    1,     1,     1, ..., 12410, 12411, 12411],
#        [    3,   160,   199, ..., 12411, 12118, 12410]]),
#  'truth': array([False, False, False, ..., False,  True, False]),
#  'truth_graph': array([[ 438, 1196, 1196, ..., 6388, 7803, 9220],
#        [1196, 2024, 2060, ..., 4736, 6388, 7803]])}
# --------------------------------------------------------------------------------
# DATALOADER:5 TEST RESULTS
# {'loss': tensor(0.6665, device='cuda:0'),
#  'preds': array([[    0,     0,     1, ..., 12917, 12918, 12919],
#        [  168,   823,  1859, ..., 12574, 12573, 12592]]),
#  'truth': array([False, False,  True, ...,  True,  True,  True]),
#  'truth_graph': array([[ 1474,  1583,  3120, ..., 11927, 12284, 12643],
#        [ 3120,  3120,  4250, ..., 11526, 11927, 12284]])}
# --------------------------------------------------------------------------------
# DATALOADER:6 TEST RESULTS
# {'loss': tensor(0.6315, device='cuda:0'),
#  'preds': array([[    2,     2,     4, ..., 10674, 10674, 10675],
#        [  548,  1055,   309, ..., 10624, 10662, 10379]]),
#  'truth': array([False, False, False, ..., False, False,  True]),
#  'truth_graph': array([[ 213,  754, 1331, ...,  781, 1341, 1988],
#        [ 754, 1331, 1961, ...,  243,  781, 1341]])}
# --------------------------------------------------------------------------------
# DATALOADER:7 TEST RESULTS
# {'loss': tensor(0.6619, device='cuda:0'),
#  'preds': array([[    1,     2,     2, ..., 14283, 14283, 14283],
#        [  961,     4,  1630, ..., 13735, 13875, 14205]]),
#  'truth': array([False, False,  True, ..., False,  True, False]),
#  'truth_graph': array([[ 2003,  2031,  2105, ...,  7873,  9879, 11186],
#        [ 4096,  4096,  4096, ...,  5713,  7873,  9879]])}
# --------------------------------------------------------------------------------
# DATALOADER:8 TEST RESULTS
# {'loss': tensor(0.6567, device='cuda:0'),
#  'preds': array([[    0,     0,     0, ..., 14741, 14742, 14742],
#        [    4,  1349,  1414, ..., 14739, 14350, 14356]]),
#  'truth': array([False,  True,  True, ..., False,  True,  True]),
#  'truth_graph': array([[  332,  1135,  1962, ...,  9651, 11510, 13121],
#        [ 1135,  1962,  2827, ...,  7044,  9651, 11510]])}
# --------------------------------------------------------------------------------
# DATALOADER:9 TEST RESULTS
# {'loss': tensor(0.6538, device='cuda:0'),
#  'preds': array([[    0,     0,     1, ..., 13944, 13944, 13944],
#        [    2,   384,  1105, ..., 13569, 13571, 13943]]),
#  'truth': array([False,  True,  True, ...,  True,  True, False]),
#  'truth_graph': array([[1311, 2919, 2919, ..., 6518, 8201, 9794],
#        [2919, 4143, 4192, ..., 4997, 6518, 8201]])}
# --------------------------------------------------------------------------------
# DATALOADER:10 TEST RESULTS
# {'loss': tensor(0.6609, device='cuda:0'),
#  'preds': array([[    0,     1,     1, ..., 14015, 14015, 14016],
#        [  391,     2,    19, ..., 13651, 14001, 13656]]),
#  'truth': array([ True, False, False, ...,  True, False,  True]),
#  'truth_graph': array([[  618,   655,  1826, ...,  7487,  9028, 10620],
#        [ 1826,  1826,  2872, ...,  5554,  7487,  9028]])}
# --------------------------------------------------------------------------------
# DATALOADER:11 TEST RESULTS
# {'loss': tensor(0.6533, device='cuda:0'),
#  'preds': array([[    0,     0,     1, ..., 13422, 13423, 13423],
#        [    5,  1798,     4, ..., 13423, 13086, 13422]]),
#  'truth': array([False,  True, False, ..., False,  True, False]),
#  'truth_graph': array([[ 1578,  3277,  4511, ..., 11266, 12007, 12407],
#        [ 3277,  4511,  5766, ...,  9464, 11266, 12007]])}
# --------------------------------------------------------------------------------
# DATALOADER:12 TEST RESULTS
# {'loss': tensor(0.6493, device='cuda:0'),
#  'preds': array([[   0,    1,    1, ..., 8075, 8076, 8076],
#        [ 276,    3, 3543, ..., 7883, 7878, 7880]]),
#  'truth': array([ True, False, False, ...,  True,  True,  True]),
#  'truth_graph': array([[ 121,  155,  604, ..., 7687, 7892, 7896],
#        [ 604,  604, 1022, ..., 7465, 7687, 7687]])}
# --------------------------------------------------------------------------------
# DATALOADER:13 TEST RESULTS
# {'loss': tensor(0.6261, device='cuda:0'),
#  'preds': array([[    0,     0,     0, ..., 10364, 10365, 10365],
#        [    1,     3,     5, ..., 10363, 10098, 10100]]),
#  'truth': array([False, False, False, ..., False,  True,  True]),
#  'truth_graph': array([[  977,  2196,  2196, ...,  8374,  8887, 10205],
#        [ 2196,  3112,  3156, ...,  6897,  8374,  8887]])}
# --------------------------------------------------------------------------------
# DATALOADER:14 TEST RESULTS
# {'loss': tensor(0.6611, device='cuda:0'),
#  'preds': array([[    0,     1,     1, ..., 14872, 14872, 14872],
#        [  555,     3,  3090, ..., 14488, 14827, 14850]]),
#  'truth': array([ True, False, False, ...,  True, False, False]),
#  'truth_graph': array([[ 1291,  3021,  4279, ...,  5237, 13584, 13584],
#        [ 3021,  4279,  5513, ...,  3800,  5195,  5237]])}
# --------------------------------------------------------------------------------
# DATALOADER:15 TEST RESULTS
# {'loss': tensor(0.6602, device='cuda:0'),
#  'preds': array([[    1,     3,     3, ..., 14041, 14041, 14041],
#        [ 1308,   626,   808, ..., 13684, 13689, 13975]]),
#  'truth': array([ True, False,  True, ...,  True,  True, False]),
#  'truth_graph': array([[  120,   790,  1516, ..., 12972, 13368, 13741],
#        [  790,  1516,  2254, ..., 12527, 12972, 13368]])}
# --------------------------------------------------------------------------------
# DATALOADER:16 TEST RESULTS
# {'loss': tensor(0.6521, device='cuda:0'),
#  'preds': array([[    0,     0,     0, ..., 13935, 13936, 13936],
#        [  474,  1291,  1374, ..., 13860, 13528, 13529]]),
#  'truth': array([False, False, False, ..., False,  True,  True]),
#  'truth_graph': array([[ 1961,  2036,  3957, ..., 11098, 12162, 12743],
#        [ 3957,  3957,  5305, ...,  9151, 11098, 12162]])}
# --------------------------------------------------------------------------------
# DATALOADER:17 TEST RESULTS
# {'loss': tensor(0.6808, device='cuda:0'),
#  'preds': array([[    0,     0,     0, ..., 14475, 14476, 14476],
#        [    5,   523,   650, ..., 14071, 14074, 14076]]),
#  'truth': array([False, False, False, ...,  True,  True,  True]),
#  'truth_graph': array([[ 5592,  5592,  5592, ..., 10928, 10945, 10965],
#        [ 6564,  6569,  6619, ...,  9364,  9364,  9364]])}
# --------------------------------------------------------------------------------
# DATALOADER:18 TEST RESULTS
# {'loss': tensor(0.6694, device='cuda:0'),
#  'preds': array([[    1,     3,     3, ..., 14966, 14966, 14966],
#        [    8,     4,  2040, ..., 14571, 14908, 14919]]),
#  'truth': array([False, False,  True, ...,  True, False, False]),
#  'truth_graph': array([[  661,   661,  1814, ...,  7008, 10734, 12626],
#        [ 1814,  1865,  2925, ...,  4020,  7008, 10734]])}
# --------------------------------------------------------------------------------
# DATALOADER:19 TEST RESULTS
# {'loss': tensor(0.6413, device='cuda:0'),
#  'preds': array([[    0,     0,     1, ..., 12150, 12150, 12150],
#        [ 1012,  1087,     4, ..., 11810, 11812, 11813]]),
#  'truth': array([ True,  True, False, ...,  True,  True,  True]),
#  'truth_graph': array([[  103,   103,   179, ..., 11070, 11463, 11463],
#        [  706,   760,   706, ...,  9935, 11067, 11070]])}
# --------------------------------------------------------------------------------
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Testing', layout=Layout(flex='2'), max=…
# Set SLURM handle signals.
# INFO:lightning:Set SLURM handle signals.
# --------------------------------------------------------------------------------
# DATALOADER:0 TEST RESULTS
# {'loss': tensor(0.6906, device='cuda:0'),
#  'preds': array([[    0,     0,     0, ..., 12136, 12136, 12138],
#        [    1,   273,   284, ..., 11802, 12018, 11807]]),
#  'truth': array([False,  True, False, ...,  True, False,  True]),
#  'truth_graph': array([[  60,   60,  133, ..., 4898, 6374, 7943],
#        [ 606,  662,  606, ..., 3861, 4898, 6374]])}
# --------------------------------------------------------------------------------
# DATALOADER:1 TEST RESULTS
# {'loss': tensor(0.6950, device='cuda:0'),
#  'preds': array([[    0,     0,     1, ..., 10327, 10327, 10328],
#        [   12,  1966,     2, ...,  9764, 10046, 10048]]),
#  'truth': array([False,  True, False, ..., False,  True,  True]),
#  'truth_graph': array([[2662, 2662, 4038, ..., 9154, 9520, 9805],
#        [4038, 4068, 4771, ..., 8278, 9154, 9520]])}
# --------------------------------------------------------------------------------
# DATALOADER:2 TEST RESULTS
# {'loss': tensor(0.7080, device='cuda:0'),
#  'preds': array([[    1,     1,     1, ..., 14294, 14294, 14294],
#        [ 3927,  7233, 11286, ..., 14235, 14287, 14289]]),
#  'truth': array([ True, False, False, ..., False, False, False]),
#  'truth_graph': array([[ 3121,  3121,  3310, ..., 11432, 12165, 12165],
#        [ 6073,  6122,  6073, ..., 10525, 11409, 11432]])}
# --------------------------------------------------------------------------------
# DATALOADER:3 TEST RESULTS
# {'loss': tensor(0.7191, device='cuda:0'),
#  'preds': array([[    0,     1,     2, ..., 15164, 15165, 15165],
#        [ 1617,  1265,   593, ..., 15162, 14798, 14799]]),
#  'truth': array([False,  True, False, ..., False,  True,  True]),
#  'truth_graph': array([[  398,  1362,  1362, ..., 10712, 10712, 12744],
#        [ 1362,  2246,  2271, ...,  9636,  9682, 10712]])}
# --------------------------------------------------------------------------------
# DATALOADER:4 TEST RESULTS
# {'loss': tensor(0.7078, device='cuda:0'),
#  'preds': array([[    1,     1,     1, ..., 12411, 12411, 12411],
#        [    3,   121,   160, ..., 11763, 12118, 12410]]),
#  'truth': array([False, False, False, ..., False,  True, False]),
#  'truth_graph': array([[ 438, 1196, 1196, ..., 6388, 7803, 9220],
#        [1196, 2024, 2060, ..., 4736, 6388, 7803]])}
# --------------------------------------------------------------------------------
# DATALOADER:5 TEST RESULTS
# {'loss': tensor(0.7209, device='cuda:0'),
#  'preds': array([[    0,     0,     1, ..., 12917, 12918, 12919],
#        [  168,   823,     4, ..., 12574, 12573, 12592]]),
#  'truth': array([False, False, False, ...,  True,  True,  True]),
#  'truth_graph': array([[ 1474,  1583,  3120, ..., 11927, 12284, 12643],
#        [ 3120,  3120,  4250, ..., 11526, 11927, 12284]])}
# --------------------------------------------------------------------------------
# DATALOADER:6 TEST RESULTS
# {'loss': tensor(0.6864, device='cuda:0'),
#  'preds': array([[    1,     2,     2, ..., 10674, 10674, 10675],
#        [    9,   548,  1055, ..., 10624, 10662, 10379]]),
#  'truth': array([False, False, False, ..., False, False,  True]),
#  'truth_graph': array([[ 213,  754, 1331, ...,  781, 1341, 1988],
#        [ 754, 1331, 1961, ...,  243,  781, 1341]])}
# --------------------------------------------------------------------------------
# DATALOADER:7 TEST RESULTS
# {'loss': tensor(0.7203, device='cuda:0'),
#  'preds': array([[    1,     2,     2, ..., 14283, 14283, 14283],
#        [  961,     4,  1630, ..., 13735, 13875, 14205]]),
#  'truth': array([False, False,  True, ..., False,  True, False]),
#  'truth_graph': array([[ 2003,  2031,  2105, ...,  7873,  9879, 11186],
#        [ 4096,  4096,  4096, ...,  5713,  7873,  9879]])}
# --------------------------------------------------------------------------------
# DATALOADER:8 TEST RESULTS
# {'loss': tensor(0.7170, device='cuda:0'),
#  'preds': array([[    0,     0,     0, ..., 14741, 14742, 14742],
#        [    4,  1349,  1414, ..., 14739, 14350, 14356]]),
#  'truth': array([False,  True,  True, ..., False,  True,  True]),
#  'truth_graph': array([[  332,  1135,  1962, ...,  9651, 11510, 13121],
#        [ 1135,  1962,  2827, ...,  7044,  9651, 11510]])}
# --------------------------------------------------------------------------------
# DATALOADER:9 TEST RESULTS
# {'loss': tensor(0.7117, device='cuda:0'),
#  'preds': array([[    0,     0,     1, ..., 13944, 13944, 13944],
#        [    2,   384,  1105, ..., 13569, 13571, 13943]]),
#  'truth': array([False,  True,  True, ...,  True,  True, False]),
#  'truth_graph': array([[1311, 2919, 2919, ..., 6518, 8201, 9794],
#        [2919, 4143, 4192, ..., 4997, 6518, 8201]])}
# --------------------------------------------------------------------------------
# DATALOADER:10 TEST RESULTS
# {'loss': tensor(0.7185, device='cuda:0'),
#  'preds': array([[    0,     1,     1, ..., 14015, 14015, 14016],
#        [  391,     2,    19, ..., 13665, 14001, 13656]]),
#  'truth': array([ True, False, False, ..., False, False,  True]),
#  'truth_graph': array([[  618,   655,  1826, ...,  7487,  9028, 10620],
#        [ 1826,  1826,  2872, ...,  5554,  7487,  9028]])}
# --------------------------------------------------------------------------------
# DATALOADER:11 TEST RESULTS
# {'loss': tensor(0.7102, device='cuda:0'),
#  'preds': array([[    0,     0,     1, ..., 13423, 13423, 13423],
#        [    5,  1798,     4, ..., 13047, 13086, 13422]]),
#  'truth': array([False,  True, False, ..., False,  True, False]),
#  'truth_graph': array([[ 1578,  3277,  4511, ..., 11266, 12007, 12407],
#        [ 3277,  4511,  5766, ...,  9464, 11266, 12007]])}
# --------------------------------------------------------------------------------
# DATALOADER:12 TEST RESULTS
# {'loss': tensor(0.7078, device='cuda:0'),
#  'preds': array([[   0,    1,    1, ..., 8075, 8076, 8076],
#        [ 276,    3, 3543, ..., 7883, 7878, 7880]]),
#  'truth': array([ True, False, False, ...,  True,  True,  True]),
#  'truth_graph': array([[ 121,  155,  604, ..., 7687, 7892, 7896],
#        [ 604,  604, 1022, ..., 7465, 7687, 7687]])}
# --------------------------------------------------------------------------------
# DATALOADER:13 TEST RESULTS
# {'loss': tensor(0.6810, device='cuda:0'),
#  'preds': array([[    0,     0,     0, ..., 10364, 10365, 10365],
#        [    1,     3,     5, ..., 10363, 10098, 10100]]),
#  'truth': array([False, False, False, ..., False,  True,  True]),
#  'truth_graph': array([[  977,  2196,  2196, ...,  8374,  8887, 10205],
#        [ 2196,  3112,  3156, ...,  6897,  8374,  8887]])}
# --------------------------------------------------------------------------------
# DATALOADER:14 TEST RESULTS
# {'loss': tensor(0.7217, device='cuda:0'),
#  'preds': array([[    0,     0,     1, ..., 14872, 14872, 14872],
#        [  309,   555,     3, ..., 14488, 14827, 14850]]),
#  'truth': array([False,  True, False, ...,  True, False, False]),
#  'truth_graph': array([[ 1291,  3021,  4279, ...,  5237, 13584, 13584],
#        [ 3021,  4279,  5513, ...,  3800,  5195,  5237]])}
# --------------------------------------------------------------------------------
# DATALOADER:15 TEST RESULTS
# {'loss': tensor(0.7173, device='cuda:0'),
#  'preds': array([[    1,     1,     3, ..., 14041, 14041, 14041],
#        [ 1308,  2350,   626, ..., 13684, 13689, 13975]]),
#  'truth': array([ True, False, False, ...,  True,  True, False]),
#  'truth_graph': array([[  120,   790,  1516, ..., 12972, 13368, 13741],
#        [  790,  1516,  2254, ..., 12527, 12972, 13368]])}
# --------------------------------------------------------------------------------
# DATALOADER:16 TEST RESULTS
# {'loss': tensor(0.7112, device='cuda:0'),
#  'preds': array([[    0,     0,     0, ..., 13935, 13936, 13936],
#        [  474,  1291,  1336, ..., 13860, 13528, 13529]]),
#  'truth': array([False, False, False, ..., False,  True,  True]),
#  'truth_graph': array([[ 1961,  2036,  3957, ..., 11098, 12162, 12743],
#        [ 3957,  3957,  5305, ...,  9151, 11098, 12162]])}
# --------------------------------------------------------------------------------
# DATALOADER:17 TEST RESULTS
# {'loss': tensor(0.7378, device='cuda:0'),
#  'preds': array([[    0,     0,     0, ..., 14475, 14476, 14476],
#        [    5,   523,   650, ..., 14071, 14074, 14076]]),
#  'truth': array([False, False, False, ...,  True,  True,  True]),
#  'truth_graph': array([[ 5592,  5592,  5592, ..., 10928, 10945, 10965],
#        [ 6564,  6569,  6619, ...,  9364,  9364,  9364]])}
# --------------------------------------------------------------------------------
# DATALOADER:18 TEST RESULTS
# {'loss': tensor(0.7297, device='cuda:0'),
#  'preds': array([[    0,     1,     3, ..., 14966, 14966, 14966],
#        [ 1107,     8,     4, ..., 14571, 14908, 14919]]),
#  'truth': array([False, False, False, ...,  True, False, False]),
#  'truth_graph': array([[  661,   661,  1814, ...,  7008, 10734, 12626],
#        [ 1814,  1865,  2925, ...,  4020,  7008, 10734]])}
# --------------------------------------------------------------------------------
# DATALOADER:19 TEST RESULTS
# {'loss': tensor(0.6971, device='cuda:0'),
#  'preds': array([[    0,     0,     1, ..., 12150, 12150, 12150],
#        [ 1012,  1087,     4, ..., 11810, 11812, 11813]]),
#  'truth': array([ True,  True, False, ...,  True,  True,  True]),
#  'truth_graph': array([[  103,   103,   179, ..., 11070, 11463, 11463],
#        [  706,   760,   706, ...,  9935, 11067, 11070]])}
# --------------------------------------------------------------------------------
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Testing', layout=Layout(flex='2'), max=…
# Set SLURM handle signals.
# INFO:lightning:Set SLURM handle signals.
# --------------------------------------------------------------------------------
# DATALOADER:0 TEST RESULTS
# {'loss': tensor(0.7496, device='cuda:0'),
#  'preds': array([[    0,     0,     0, ..., 12138, 12138, 12138],
#        [    1,   273,   284, ..., 11628, 11807, 11989]]),
#  'truth': array([False,  True, False, ..., False,  True, False]),
#  'truth_graph': array([[  60,   60,  133, ..., 4898, 6374, 7943],
#        [ 606,  662,  606, ..., 3861, 4898, 6374]])}
# --------------------------------------------------------------------------------
# DATALOADER:1 TEST RESULTS
# {'loss': tensor(0.7530, device='cuda:0'),
#  'preds': array([[    0,     0,     1, ..., 10327, 10328, 10328],
#        [   12,  1966,     2, ..., 10046,  9969, 10048]]),
#  'truth': array([False,  True, False, ...,  True, False,  True]),
#  'truth_graph': array([[2662, 2662, 4038, ..., 9154, 9520, 9805],
#        [4038, 4068, 4771, ..., 8278, 9154, 9520]])}
# --------------------------------------------------------------------------------
# DATALOADER:2 TEST RESULTS
# {'loss': tensor(0.7667, device='cuda:0'),
#  'preds': array([[    1,     1,     1, ..., 14294, 14294, 14294],
#        [ 3927,  7233, 11286, ..., 14235, 14287, 14289]]),
#  'truth': array([ True, False, False, ..., False, False, False]),
#  'truth_graph': array([[ 3121,  3121,  3310, ..., 11432, 12165, 12165],
#        [ 6073,  6122,  6073, ..., 10525, 11409, 11432]])}
# --------------------------------------------------------------------------------
# DATALOADER:3 TEST RESULTS
# {'loss': tensor(0.7768, device='cuda:0'),
#  'preds': array([[    0,     1,     1, ..., 15164, 15165, 15165],
#        [ 1617,  1265,  2632, ..., 15162, 14798, 14799]]),
#  'truth': array([False,  True, False, ..., False,  True,  True]),
#  'truth_graph': array([[  398,  1362,  1362, ..., 10712, 10712, 12744],
#        [ 1362,  2246,  2271, ...,  9636,  9682, 10712]])}
# --------------------------------------------------------------------------------
# DATALOADER:4 TEST RESULTS
# {'loss': tensor(0.7644, device='cuda:0'),
#  'preds': array([[    0,     1,     1, ..., 12411, 12411, 12411],
#        [ 1035,     3,    35, ..., 11763, 12118, 12410]]),
#  'truth': array([ True, False, False, ..., False,  True, False]),
#  'truth_graph': array([[ 438, 1196, 1196, ..., 6388, 7803, 9220],
#        [1196, 2024, 2060, ..., 4736, 6388, 7803]])}
# --------------------------------------------------------------------------------
# DATALOADER:5 TEST RESULTS
# {'loss': tensor(0.7748, device='cuda:0'),
#  'preds': array([[    0,     0,     0, ..., 12918, 12919, 12919],
#        [  168,   360,   413, ..., 12573, 12243, 12592]]),
#  'truth': array([False,  True,  True, ...,  True, False,  True]),
#  'truth_graph': array([[ 1474,  1583,  3120, ..., 11927, 12284, 12643],
#        [ 3120,  3120,  4250, ..., 11526, 11927, 12284]])}
# --------------------------------------------------------------------------------
# DATALOADER:6 TEST RESULTS
# {'loss': tensor(0.7443, device='cuda:0'),
#  'preds': array([[    0,     0,     1, ..., 10674, 10674, 10675],
#        [ 5575,  5599,     9, ..., 10624, 10662, 10379]]),
#  'truth': array([False, False, False, ..., False, False,  True]),
#  'truth_graph': array([[ 213,  754, 1331, ...,  781, 1341, 1988],
#        [ 754, 1331, 1961, ...,  243,  781, 1341]])}
# --------------------------------------------------------------------------------
# DATALOADER:7 TEST RESULTS
# {'loss': tensor(0.7761, device='cuda:0'),
#  'preds': array([[    0,     1,     1, ..., 14283, 14283, 14283],
#        [ 1946,   362,   559, ..., 13875, 14145, 14205]]),
#  'truth': array([False, False,  True, ...,  True, False, False]),
#  'truth_graph': array([[ 2003,  2031,  2105, ...,  7873,  9879, 11186],
#        [ 4096,  4096,  4096, ...,  5713,  7873,  9879]])}
# --------------------------------------------------------------------------------
# DATALOADER:8 TEST RESULTS
# {'loss': tensor(0.7745, device='cuda:0'),
#  'preds': array([[    0,     0,     0, ..., 14742, 14742, 14742],
#        [    4,  1349,  1414, ..., 14350, 14353, 14356]]),
#  'truth': array([False,  True,  True, ...,  True,  True,  True]),
#  'truth_graph': array([[  332,  1135,  1962, ...,  9651, 11510, 13121],
#        [ 1135,  1962,  2827, ...,  7044,  9651, 11510]])}
# --------------------------------------------------------------------------------
# DATALOADER:9 TEST RESULTS
# {'loss': tensor(0.7667, device='cuda:0'),
#  'preds': array([[    0,     0,     1, ..., 13944, 13944, 13944],
#        [    2,   384,  1105, ..., 13571, 13573, 13943]]),
#  'truth': array([False,  True,  True, ...,  True, False, False]),
#  'truth_graph': array([[1311, 2919, 2919, ..., 6518, 8201, 9794],
#        [2919, 4143, 4192, ..., 4997, 6518, 8201]])}
# --------------------------------------------------------------------------------
# DATALOADER:10 TEST RESULTS
# {'loss': tensor(0.7738, device='cuda:0'),
#  'preds': array([[    0,     1,     1, ..., 14015, 14015, 14016],
#        [  391,     2,    19, ..., 13665, 14001, 13656]]),
#  'truth': array([ True, False, False, ..., False, False,  True]),
#  'truth_graph': array([[  618,   655,  1826, ...,  7487,  9028, 10620],
#        [ 1826,  1826,  2872, ...,  5554,  7487,  9028]])}
# --------------------------------------------------------------------------------
# DATALOADER:11 TEST RESULTS
# {'loss': tensor(0.7663, device='cuda:0'),
#  'preds': array([[    0,     0,     1, ..., 13423, 13423, 13423],
#        [    5,  1798,     4, ..., 13047, 13086, 13422]]),
#  'truth': array([False,  True, False, ..., False,  True, False]),
#  'truth_graph': array([[ 1578,  3277,  4511, ..., 11266, 12007, 12407],
#        [ 3277,  4511,  5766, ...,  9464, 11266, 12007]])}
# --------------------------------------------------------------------------------
# DATALOADER:12 TEST RESULTS
# {'loss': tensor(0.7653, device='cuda:0'),
#  'preds': array([[   0,    1,    1, ..., 8076, 8076, 8076],
#        [ 276,    3, 3543, ..., 7805, 7878, 7880]]),
#  'truth': array([ True, False, False, ..., False,  True,  True]),
#  'truth_graph': array([[ 121,  155,  604, ..., 7687, 7892, 7896],
#        [ 604,  604, 1022, ..., 7465, 7687, 7687]])}
# --------------------------------------------------------------------------------
# DATALOADER:13 TEST RESULTS
# {'loss': tensor(0.7380, device='cuda:0'),
#  'preds': array([[    0,     0,     0, ..., 10364, 10365, 10365],
#        [    1,     3,     5, ..., 10363, 10098, 10100]]),
#  'truth': array([False, False, False, ..., False,  True,  True]),
#  'truth_graph': array([[  977,  2196,  2196, ...,  8374,  8887, 10205],
#        [ 2196,  3112,  3156, ...,  6897,  8374,  8887]])}
# --------------------------------------------------------------------------------
# DATALOADER:14 TEST RESULTS
# {'loss': tensor(0.7780, device='cuda:0'),
#  'preds': array([[    0,     0,     0, ..., 14872, 14872, 14872],
#        [  309,   555,   916, ..., 14488, 14827, 14850]]),
#  'truth': array([False,  True, False, ...,  True, False, False]),
#  'truth_graph': array([[ 1291,  3021,  4279, ...,  5237, 13584, 13584],
#        [ 3021,  4279,  5513, ...,  3800,  5195,  5237]])}
# --------------------------------------------------------------------------------
# DATALOADER:15 TEST RESULTS
# {'loss': tensor(0.7737, device='cuda:0'),
#  'preds': array([[    1,     1,     1, ..., 14041, 14041, 14041],
#        [  964,  1308,  2350, ..., 13684, 13689, 13975]]),
#  'truth': array([False,  True, False, ...,  True,  True, False]),
#  'truth_graph': array([[  120,   790,  1516, ..., 12972, 13368, 13741],
#        [  790,  1516,  2254, ..., 12527, 12972, 13368]])}
# --------------------------------------------------------------------------------
# DATALOADER:16 TEST RESULTS
# {'loss': tensor(0.7703, device='cuda:0'),
#  'preds': array([[    0,     0,     0, ..., 13936, 13936, 13936],
#        [  474,  1291,  1336, ..., 13528, 13529, 13865]]),
#  'truth': array([False, False, False, ...,  True,  True, False]),
#  'truth_graph': array([[ 1961,  2036,  3957, ..., 11098, 12162, 12743],
#        [ 3957,  3957,  5305, ...,  9151, 11098, 12162]])}
# --------------------------------------------------------------------------------
# DATALOADER:17 TEST RESULTS
# {'loss': tensor(0.7917, device='cuda:0'),
#  'preds': array([[    0,     0,     0, ..., 14475, 14476, 14476],
#        [    5,   523,   650, ..., 14071, 14074, 14076]]),
#  'truth': array([False, False, False, ...,  True,  True,  True]),
#  'truth_graph': array([[ 5592,  5592,  5592, ..., 10928, 10945, 10965],
#        [ 6564,  6569,  6619, ...,  9364,  9364,  9364]])}
# --------------------------------------------------------------------------------
# DATALOADER:18 TEST RESULTS
# {'loss': tensor(0.7845, device='cuda:0'),
#  'preds': array([[    0,     0,     0, ..., 14966, 14966, 14966],
#        [ 1107,  1150,  2707, ..., 14571, 14908, 14919]]),
#  'truth': array([False,  True, False, ...,  True, False, False]),
#  'truth_graph': array([[  661,   661,  1814, ...,  7008, 10734, 12626],
#        [ 1814,  1865,  2925, ...,  4020,  7008, 10734]])}
# --------------------------------------------------------------------------------
# DATALOADER:19 TEST RESULTS
# {'loss': tensor(0.7553, device='cuda:0'),
#  'preds': array([[    0,     0,     1, ..., 12150, 12150, 12150],
#        [ 1012,  1087,     4, ..., 11810, 11812, 11813]]),
#  'truth': array([ True,  True, False, ...,  True,  True,  True]),
#  'truth_graph': array([[  103,   103,   179, ..., 11070, 11463, 11463],
#        [  706,   760,   706, ...,  9935, 11067, 11070]])}
# --------------------------------------------------------------------------------
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Testing', layout=Layout(flex='2'), max=…
# Set SLURM handle signals.
# INFO:lightning:Set SLURM handle signals.
# --------------------------------------------------------------------------------
# DATALOADER:0 TEST RESULTS
# {'loss': tensor(0.8085, device='cuda:0'),
#  'preds': array([[    0,     0,     0, ..., 12138, 12138, 12138],
#        [    1,   273,   284, ..., 11628, 11807, 11989]]),
#  'truth': array([False,  True, False, ..., False,  True, False]),
#  'truth_graph': array([[  60,   60,  133, ..., 4898, 6374, 7943],
#        [ 606,  662,  606, ..., 3861, 4898, 6374]])}
# --------------------------------------------------------------------------------
# DATALOADER:1 TEST RESULTS
# {'loss': tensor(0.8108, device='cuda:0'),
#  'preds': array([[    0,     0,     1, ..., 10328, 10328, 10328],
#        [   12,  1966,     2, ...,  9969,  9973, 10048]]),
#  'truth': array([False,  True, False, ..., False, False,  True]),
#  'truth_graph': array([[2662, 2662, 4038, ..., 9154, 9520, 9805],
#        [4038, 4068, 4771, ..., 8278, 9154, 9520]])}
# --------------------------------------------------------------------------------
# DATALOADER:2 TEST RESULTS
# {'loss': tensor(0.8230, device='cuda:0'),
#  'preds': array([[    0,     1,     1, ..., 14294, 14294, 14294],
#        [ 1221,  3927,  7233, ..., 14235, 14287, 14289]]),
#  'truth': array([ True,  True, False, ..., False, False, False]),
#  'truth_graph': array([[ 3121,  3121,  3310, ..., 11432, 12165, 12165],
#        [ 6073,  6122,  6073, ..., 10525, 11409, 11432]])}
# --------------------------------------------------------------------------------
# DATALOADER:3 TEST RESULTS
# {'loss': tensor(0.8311, device='cuda:0'),
#  'preds': array([[    0,     0,     0, ..., 15165, 15165, 15165],
#        [ 1617,  2466,  4792, ..., 14798, 14799, 15149]]),
#  'truth': array([False, False, False, ...,  True,  True, False]),
#  'truth_graph': array([[  398,  1362,  1362, ..., 10712, 10712, 12744],
#        [ 1362,  2246,  2271, ...,  9636,  9682, 10712]])}
# --------------------------------------------------------------------------------
# DATALOADER:4 TEST RESULTS
# {'loss': tensor(0.8211, device='cuda:0'),
#  'preds': array([[    0,     1,     1, ..., 12411, 12411, 12411],
#        [ 1035,     3,    35, ..., 11763, 12118, 12410]]),
#  'truth': array([ True, False, False, ..., False,  True, False]),
#  'truth_graph': array([[ 438, 1196, 1196, ..., 6388, 7803, 9220],
#        [1196, 2024, 2060, ..., 4736, 6388, 7803]])}
# --------------------------------------------------------------------------------
# DATALOADER:5 TEST RESULTS
# {'loss': tensor(0.8273, device='cuda:0'),
#  'preds': array([[    0,     0,     0, ..., 12918, 12919, 12919],
#        [  168,   360,   413, ..., 12573, 12243, 12592]]),
#  'truth': array([False,  True,  True, ...,  True, False,  True]),
#  'truth_graph': array([[ 1474,  1583,  3120, ..., 11927, 12284, 12643],
#        [ 3120,  3120,  4250, ..., 11526, 11927, 12284]])}
# --------------------------------------------------------------------------------
# DATALOADER:6 TEST RESULTS
# {'loss': tensor(0.8006, device='cuda:0'),
#  'preds': array([[    0,     0,     1, ..., 10674, 10674, 10675],
#        [ 5575,  5599,     9, ..., 10624, 10662, 10379]]),
#  'truth': array([False, False, False, ..., False, False,  True]),
#  'truth_graph': array([[ 213,  754, 1331, ...,  781, 1341, 1988],
#        [ 754, 1331, 1961, ...,  243,  781, 1341]])}
# --------------------------------------------------------------------------------
# DATALOADER:7 TEST RESULTS
# {'loss': tensor(0.8294, device='cuda:0'),
#  'preds': array([[    0,     0,     1, ..., 14283, 14283, 14283],
#        [ 1946,  4008,   362, ..., 13875, 14145, 14205]]),
#  'truth': array([False, False, False, ...,  True, False, False]),
#  'truth_graph': array([[ 2003,  2031,  2105, ...,  7873,  9879, 11186],
#        [ 4096,  4096,  4096, ...,  5713,  7873,  9879]])}
# --------------------------------------------------------------------------------
# DATALOADER:8 TEST RESULTS
# {'loss': tensor(0.8276, device='cuda:0'),
#  'preds': array([[    0,     0,     0, ..., 14742, 14742, 14742],
#        [    4,  1349,  1414, ..., 14350, 14353, 14356]]),
#  'truth': array([False,  True,  True, ...,  True,  True,  True]),
#  'truth_graph': array([[  332,  1135,  1962, ...,  9651, 11510, 13121],
#        [ 1135,  1962,  2827, ...,  7044,  9651, 11510]])}
# --------------------------------------------------------------------------------
# DATALOADER:9 TEST RESULTS
# {'loss': tensor(0.8201, device='cuda:0'),
#  'preds': array([[    0,     0,     1, ..., 13944, 13944, 13944],
#        [    2,   384,  1105, ..., 13571, 13573, 13943]]),
#  'truth': array([False,  True,  True, ...,  True, False, False]),
#  'truth_graph': array([[1311, 2919, 2919, ..., 6518, 8201, 9794],
#        [2919, 4143, 4192, ..., 4997, 6518, 8201]])}
# --------------------------------------------------------------------------------
# DATALOADER:10 TEST RESULTS
# {'loss': tensor(0.8279, device='cuda:0'),
#  'preds': array([[    0,     1,     1, ..., 14015, 14015, 14016],
#        [  391,     2,    19, ..., 13665, 14001, 13656]]),
#  'truth': array([ True, False, False, ..., False, False,  True]),
#  'truth_graph': array([[  618,   655,  1826, ...,  7487,  9028, 10620],
#        [ 1826,  1826,  2872, ...,  5554,  7487,  9028]])}
# --------------------------------------------------------------------------------
# DATALOADER:11 TEST RESULTS
# {'loss': tensor(0.8232, device='cuda:0'),
#  'preds': array([[    0,     0,     1, ..., 13423, 13423, 13423],
#        [    5,  1798,     4, ..., 13086, 13406, 13422]]),
#  'truth': array([False,  True, False, ...,  True, False, False]),
#  'truth_graph': array([[ 1578,  3277,  4511, ..., 11266, 12007, 12407],
#        [ 3277,  4511,  5766, ...,  9464, 11266, 12007]])}
# --------------------------------------------------------------------------------
# DATALOADER:12 TEST RESULTS
# {'loss': tensor(0.8176, device='cuda:0'),
#  'preds': array([[   0,    1,    1, ..., 8076, 8076, 8076],
#        [ 276,    3, 3543, ..., 7805, 7878, 7880]]),
#  'truth': array([ True, False, False, ..., False,  True,  True]),
#  'truth_graph': array([[ 121,  155,  604, ..., 7687, 7892, 7896],
#        [ 604,  604, 1022, ..., 7465, 7687, 7687]])}
# --------------------------------------------------------------------------------
# DATALOADER:13 TEST RESULTS
# {'loss': tensor(0.7998, device='cuda:0'),
#  'preds': array([[    0,     0,     0, ..., 10364, 10365, 10365],
#        [    1,     3,     5, ..., 10363, 10098, 10100]]),
#  'truth': array([False, False, False, ..., False,  True,  True]),
#  'truth_graph': array([[  977,  2196,  2196, ...,  8374,  8887, 10205],
#        [ 2196,  3112,  3156, ...,  6897,  8374,  8887]])}
# --------------------------------------------------------------------------------
# DATALOADER:14 TEST RESULTS
# {'loss': tensor(0.8310, device='cuda:0'),
#  'preds': array([[    0,     0,     0, ..., 14872, 14872, 14872],
#        [  181,   309,   465, ..., 14827, 14828, 14850]]),
#  'truth': array([False, False, False, ..., False, False, False]),
#  'truth_graph': array([[ 1291,  3021,  4279, ...,  5237, 13584, 13584],
#        [ 3021,  4279,  5513, ...,  3800,  5195,  5237]])}
# --------------------------------------------------------------------------------
# DATALOADER:15 TEST RESULTS
# {'loss': tensor(0.8278, device='cuda:0'),
#  'preds': array([[    1,     1,     1, ..., 14041, 14041, 14041],
#        [  964,  1308,  2350, ..., 13684, 13689, 13975]]),
#  'truth': array([False,  True, False, ...,  True,  True, False]),
#  'truth_graph': array([[  120,   790,  1516, ..., 12972, 13368, 13741],
#        [  790,  1516,  2254, ..., 12527, 12972, 13368]])}
# --------------------------------------------------------------------------------
# DATALOADER:16 TEST RESULTS
# {'loss': tensor(0.8253, device='cuda:0'),
#  'preds': array([[    0,     0,     0, ..., 13936, 13936, 13936],
#        [  447,   474,  1291, ..., 13528, 13529, 13865]]),
#  'truth': array([False, False, False, ...,  True,  True, False]),
#  'truth_graph': array([[ 1961,  2036,  3957, ..., 11098, 12162, 12743],
#        [ 3957,  3957,  5305, ...,  9151, 11098, 12162]])}
# --------------------------------------------------------------------------------
# DATALOADER:17 TEST RESULTS
# {'loss': tensor(0.8414, device='cuda:0'),
#  'preds': array([[    0,     0,     0, ..., 14475, 14476, 14476],
#        [    5,   523,   650, ..., 14338, 14074, 14076]]),
#  'truth': array([False, False, False, ..., False,  True,  True]),
#  'truth_graph': array([[ 5592,  5592,  5592, ..., 10928, 10945, 10965],
#        [ 6564,  6569,  6619, ...,  9364,  9364,  9364]])}
# --------------------------------------------------------------------------------
# DATALOADER:18 TEST RESULTS
# {'loss': tensor(0.8370, device='cuda:0'),
#  'preds': array([[    0,     0,     0, ..., 14966, 14966, 14966],
#        [ 1107,  1150,  2707, ..., 14571, 14908, 14919]]),
#  'truth': array([False,  True, False, ...,  True, False, False]),
#  'truth_graph': array([[  661,   661,  1814, ...,  7008, 10734, 12626],
#        [ 1814,  1865,  2925, ...,  4020,  7008, 10734]])}
# --------------------------------------------------------------------------------
# DATALOADER:19 TEST RESULTS
# {'loss': tensor(0.8129, device='cuda:0'),
#  'preds': array([[    0,     0,     0, ..., 12150, 12150, 12150],
#        [ 1012,  1087,  2020, ..., 11810, 11812, 11813]]),
#  'truth': array([ True,  True, False, ...,  True,  True,  True]),
#  'truth_graph': array([[  103,   103,   179, ..., 11070, 11463, 11463],
#        [  706,   760,   706, ...,  9935, 11067, 11070]])}
# --------------------------------------------------------------------------------
# ...
#  'preds': array([[    0,     0,     0, ..., 10674, 10674, 10675],
#        [ 5575,  5599,  5959, ..., 10624, 10662, 10379]]),
#  'truth': array([False, False, False, ..., False, False,  True]),
#  'truth_graph': array([[ 213,  754, 1331, ...,  781, 1341, 1988],
#        [ 754, 1331, 1961, ...,  243,  781, 1341]])}
# --------------------------------------------------------------------------------
# DATALOADER:7 TEST RESULTS
# {'loss': tensor(0.8668, device='cuda:0'),
#  'preds': array([[    0,     0,     1, ..., 14283, 14283, 14283],
#        [ 1946,  4008,   213, ..., 13875, 14145, 14205]]),
#  'truth': array([False, False, False, ...,  True, False, False]),
#  'truth_graph': array([[ 2003,  2031,  2105, ...,  7873,  9879, 11186],
#        [ 4096,  4096,  4096, ...,  5713,  7873,  9879]])}
# --------------------------------------------------------------------------------
# DATALOADER:8 TEST RESULTS
# {'loss': tensor(0.8650, device='cuda:0'),
#  'preds': array([[    0,     0,     0, ..., 14742, 14742, 14742],
#        [    4,  1349,  1414, ..., 14350, 14353, 14356]]),
#  'truth': array([False,  True,  True, ...,  True,  True,  True]),
#  'truth_graph': array([[  332,  1135,  1962, ...,  9651, 11510, 13121],
#        [ 1135,  1962,  2827, ...,  7044,  9651, 11510]])}
# --------------------------------------------------------------------------------
# DATALOADER:9 TEST RESULTS
# {'loss': tensor(0.8600, device='cuda:0'),
#  'preds': array([[    0,     0,     1, ..., 13944, 13944, 13944],
#        [    2,   384,  1105, ..., 13573, 13574, 13943]]),
#  'truth': array([False,  True,  True, ..., False, False, False]),
#  'truth_graph': array([[1311, 2919, 2919, ..., 6518, 8201, 9794],
#        [2919, 4143, 4192, ..., 4997, 6518, 8201]])}
# --------------------------------------------------------------------------------
# DATALOADER:10 TEST RESULTS
# {'loss': tensor(0.8655, device='cuda:0'),
#  'preds': array([[    0,     0,     1, ..., 14015, 14015, 14016],
#        [  216,   391,     2, ..., 13665, 14001, 13656]]),
#  'truth': array([False,  True, False, ..., False, False,  True]),
#  'truth_graph': array([[  618,   655,  1826, ...,  7487,  9028, 10620],
#        [ 1826,  1826,  2872, ...,  5554,  7487,  9028]])}
# --------------------------------------------------------------------------------
# DATALOADER:11 TEST RESULTS
# {'loss': tensor(0.8611, device='cuda:0'),
#  'preds': array([[    0,     0,     0, ..., 13423, 13423, 13423],
#        [    5,  1798,  3772, ..., 13086, 13406, 13422]]),
#  'truth': array([False,  True, False, ...,  True, False, False]),
#  'truth_graph': array([[ 1578,  3277,  4511, ..., 11266, 12007, 12407],
#        [ 3277,  4511,  5766, ...,  9464, 11266, 12007]])}
# --------------------------------------------------------------------------------
# DATALOADER:12 TEST RESULTS
# {'loss': tensor(0.8556, device='cuda:0'),
#  'preds': array([[   0,    1,    1, ..., 8076, 8076, 8076],
#        [ 276,    3, 3543, ..., 7805, 7878, 7880]]),
#  'truth': array([ True, False, False, ..., False,  True,  True]),
#  'truth_graph': array([[ 121,  155,  604, ..., 7687, 7892, 7896],
#        [ 604,  604, 1022, ..., 7465, 7687, 7687]])}
# --------------------------------------------------------------------------------
# DATALOADER:13 TEST RESULTS
# {'loss': tensor(0.8397, device='cuda:0'),
#  'preds': array([[    0,     0,     0, ..., 10364, 10365, 10365],
#        [    1,     3,     5, ..., 10363, 10098, 10100]]),
#  'truth': array([False, False, False, ..., False,  True,  True]),
#  'truth_graph': array([[  977,  2196,  2196, ...,  8374,  8887, 10205],
#        [ 2196,  3112,  3156, ...,  6897,  8374,  8887]])}
# --------------------------------------------------------------------------------
# DATALOADER:14 TEST RESULTS
# {'loss': tensor(0.8686, device='cuda:0'),
#  'preds': array([[    0,     0,     0, ..., 14872, 14872, 14872],
#        [  181,   309,   465, ..., 14827, 14828, 14850]]),
#  'truth': array([False, False, False, ..., False, False, False]),
#  'truth_graph': array([[ 1291,  3021,  4279, ...,  5237, 13584, 13584],
#        [ 3021,  4279,  5513, ...,  3800,  5195,  5237]])}
# --------------------------------------------------------------------------------
# DATALOADER:15 TEST RESULTS
# {'loss': tensor(0.8652, device='cuda:0'),
#  'preds': array([[    0,     1,     1, ..., 14041, 14041, 14041],
#        [11289,   708,   964, ..., 13684, 13689, 13975]]),
#  'truth': array([False, False, False, ...,  True,  True, False]),
#  'truth_graph': array([[  120,   790,  1516, ..., 12972, 13368, 13741],
#        [  790,  1516,  2254, ..., 12527, 12972, 13368]])}
# --------------------------------------------------------------------------------
# DATALOADER:16 TEST RESULTS
# {'loss': tensor(0.8639, device='cuda:0'),
#  'preds': array([[    0,     0,     0, ..., 13936, 13936, 13936],
#        [  447,   474,   544, ..., 13528, 13529, 13865]]),
#  'truth': array([False, False,  True, ...,  True,  True, False]),
#  'truth_graph': array([[ 1961,  2036,  3957, ..., 11098, 12162, 12743],
#        [ 3957,  3957,  5305, ...,  9151, 11098, 12162]])}
# --------------------------------------------------------------------------------
# DATALOADER:17 TEST RESULTS
# {'loss': tensor(0.8755, device='cuda:0'),
#  'preds': array([[    0,     0,     0, ..., 14475, 14476, 14476],
#        [    5,   520,   523, ..., 14338, 14074, 14076]]),
#  'truth': array([False, False, False, ..., False,  True,  True]),
#  'truth_graph': array([[ 5592,  5592,  5592, ..., 10928, 10945, 10965],
#        [ 6564,  6569,  6619, ...,  9364,  9364,  9364]])}
# --------------------------------------------------------------------------------
# DATALOADER:18 TEST RESULTS
# {'loss': tensor(0.8728, device='cuda:0'),
#  'preds': array([[    0,     0,     0, ..., 14966, 14966, 14966],
#        [ 1107,  1150,  2707, ..., 14571, 14908, 14919]]),
#  'truth': array([False,  True, False, ...,  True, False, False]),
#  'truth_graph': array([[  661,   661,  1814, ...,  7008, 10734, 12626],
#        [ 1814,  1865,  2925, ...,  4020,  7008, 10734]])}
# --------------------------------------------------------------------------------
# DATALOADER:19 TEST RESULTS
# {'loss': tensor(0.8529, device='cuda:0'),
#  'preds': array([[    0,     0,     0, ..., 12150, 12150, 12150],
#        [ 1012,  1087,  2020, ..., 11810, 11812, 11813]]),
#  'truth': array([ True,  True, False, ...,  True,  True,  True]),
#  'truth_graph': array([[  103,   103,   179, ..., 11070, 11463, 11463],
#        [  706,   760,   706, ...,  9935, 11067, 11070]])}
# --------------------------------------------------------------------------------
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Testing', layout=Layout(flex='2'), max=…
# --------------------------------------------------------------------------------
# DATALOADER:0 TEST RESULTS
# {'loss': tensor(0.8756, device='cuda:0'),
#  'preds': array([[    0,     0,     0, ..., 12138, 12138, 12138],
#        [    1,   273,   284, ..., 11628, 11807, 11989]]),
#  'truth': array([False,  True, False, ..., False,  True, False]),
#  'truth_graph': array([[  60,   60,  133, ..., 4898, 6374, 7943],
#        [ 606,  662,  606, ..., 3861, 4898, 6374]])}
# --------------------------------------------------------------------------------
# DATALOADER:1 TEST RESULTS
# {'loss': tensor(0.8754, device='cuda:0'),
#  'preds': array([[    0,     0,     1, ..., 10328, 10328, 10328],
#        [   12,  1966,     2, ...,  9969,  9973, 10048]]),
#  'truth': array([False,  True, False, ..., False, False,  True]),
#  'truth_graph': array([[2662, 2662, 4038, ..., 9154, 9520, 9805],
#        [4038, 4068, 4771, ..., 8278, 9154, 9520]])}
# --------------------------------------------------------------------------------
# DATALOADER:2 TEST RESULTS
# {'loss': tensor(0.8872, device='cuda:0'),
#  'preds': array([[    0,     0,     0, ..., 14294, 14294, 14294],
#        [ 1221,  1264,  2867, ..., 14235, 14287, 14289]]),
#  'truth': array([ True,  True, False, ..., False, False, False]),
#  'truth_graph': array([[ 3121,  3121,  3310, ..., 11432, 12165, 12165],
#        [ 6073,  6122,  6073, ..., 10525, 11409, 11432]])}
# --------------------------------------------------------------------------------
# DATALOADER:3 TEST RESULTS
# {'loss': tensor(0.8945, device='cuda:0'),
#  'preds': array([[    0,     0,     0, ..., 15165, 15165, 15165],
#        [ 1617,  2419,  2466, ..., 14798, 14799, 15149]]),
#  'truth': array([False, False, False, ...,  True,  True, False]),
#  'truth_graph': array([[  398,  1362,  1362, ..., 10712, 10712, 12744],
#        [ 1362,  2246,  2271, ...,  9636,  9682, 10712]])}
# --------------------------------------------------------------------------------
# DATALOADER:4 TEST RESULTS
# {'loss': tensor(0.8852, device='cuda:0'),
#  'preds': array([[    0,     1,     1, ..., 12411, 12411, 12411],
#        [ 1035,     3,    35, ..., 11763, 12118, 12410]]),
#  'truth': array([ True, False, False, ..., False,  True, False]),
#  'truth_graph': array([[ 438, 1196, 1196, ..., 6388, 7803, 9220],
#        [1196, 2024, 2060, ..., 4736, 6388, 7803]])}
# --------------------------------------------------------------------------------
# DATALOADER:5 TEST RESULTS
# {'loss': tensor(0.8875, device='cuda:0'),
#  'preds': array([[    0,     0,     0, ..., 12918, 12919, 12919],
#        [  116,   168,   360, ..., 12573, 12243, 12592]]),
#  'truth': array([False, False,  True, ...,  True, False,  True]),
#  'truth_graph': array([[ 1474,  1583,  3120, ..., 11927, 12284, 12643],
#        [ 3120,  3120,  4250, ..., 11526, 11927, 12284]])}
# --------------------------------------------------------------------------------
# DATALOADER:6 TEST RESULTS
# {'loss': tensor(0.8667, device='cuda:0'),
#  'preds': array([[    0,     0,     0, ..., 10674, 10675, 10675],
#        [ 5575,  5599,  5959, ..., 10662,  9694, 10379]]),
#  'truth': array([False, False, False, ..., False, False,  True]),
#  'truth_graph': array([[ 213,  754, 1331, ...,  781, 1341, 1988],
#        [ 754, 1331, 1961, ...,  243,  781, 1341]])}
# --------------------------------------------------------------------------------
# DATALOADER:7 TEST RESULTS
# {'loss': tensor(0.8923, device='cuda:0'),
#  'preds': array([[    0,     0,     0, ..., 14283, 14283, 14283],
#        [ 1946,  4008,  5408, ..., 14145, 14205, 14251]]),
#  'truth': array([False, False, False, ..., False, False, False]),
#  'truth_graph': array([[ 2003,  2031,  2105, ...,  7873,  9879, 11186],
#        [ 4096,  4096,  4096, ...,  5713,  7873,  9879]])}
# --------------------------------------------------------------------------------
# DATALOADER:8 TEST RESULTS
# {'loss': tensor(0.8893, device='cuda:0'),
#  'preds': array([[    0,     0,     0, ..., 14742, 14742, 14742],
#        [    4,  1349,  1414, ..., 14350, 14353, 14356]]),
#  'truth': array([False,  True,  True, ...,  True,  True,  True]),
#  'truth_graph': array([[  332,  1135,  1962, ...,  9651, 11510, 13121],
#        [ 1135,  1962,  2827, ...,  7044,  9651, 11510]])}
# --------------------------------------------------------------------------------
# DATALOADER:9 TEST RESULTS
# {'loss': tensor(0.8858, device='cuda:0'),
#  'preds': array([[    0,     0,     0, ..., 13944, 13944, 13944],
#        [    2,   384,  1039, ..., 13573, 13574, 13943]]),
#  'truth': array([False,  True, False, ..., False, False, False]),
#  'truth_graph': array([[1311, 2919, 2919, ..., 6518, 8201, 9794],
#        [2919, 4143, 4192, ..., 4997, 6518, 8201]])}
# --------------------------------------------------------------------------------
# DATALOADER:10 TEST RESULTS
# {'loss': tensor(0.8907, device='cuda:0'),
#  'preds': array([[    0,     0,     0, ..., 14015, 14015, 14016],
#        [  216,   391,  1080, ..., 13665, 14001, 13656]]),
#  'truth': array([False,  True, False, ..., False, False,  True]),
#  'truth_graph': array([[  618,   655,  1826, ...,  7487,  9028, 10620],
#        [ 1826,  1826,  2872, ...,  5554,  7487,  9028]])}
# --------------------------------------------------------------------------------
# DATALOADER:11 TEST RESULTS
# {'loss': tensor(0.8863, device='cuda:0'),
#  'preds': array([[    0,     0,     0, ..., 13423, 13423, 13423],
#        [    5,  1798,  3772, ..., 13086, 13406, 13422]]),
#  'truth': array([False,  True, False, ...,  True, False, False]),
#  'truth_graph': array([[ 1578,  3277,  4511, ..., 11266, 12007, 12407],
#        [ 3277,  4511,  5766, ...,  9464, 11266, 12007]])}
# --------------------------------------------------------------------------------
# DATALOADER:12 TEST RESULTS
# {'loss': tensor(0.8817, device='cuda:0'),
#  'preds': array([[   0,    1,    1, ..., 8076, 8076, 8076],
#        [ 276,    3, 3543, ..., 7805, 7878, 7880]]),
#  'truth': array([ True, False, False, ..., False,  True,  True]),
#  'truth_graph': array([[ 121,  155,  604, ..., 7687, 7892, 7896],
#        [ 604,  604, 1022, ..., 7465, 7687, 7687]])}
# --------------------------------------------------------------------------------
# DATALOADER:13 TEST RESULTS
# {'loss': tensor(0.8662, device='cuda:0'),
#  'preds': array([[    0,     0,     0, ..., 10365, 10365, 10365],
#        [    1,     3,     5, ...,  9496, 10098, 10100]]),
#  'truth': array([False, False, False, ..., False,  True,  True]),
#  'truth_graph': array([[  977,  2196,  2196, ...,  8374,  8887, 10205],
#        [ 2196,  3112,  3156, ...,  6897,  8374,  8887]])}
# --------------------------------------------------------------------------------
# DATALOADER:14 TEST RESULTS
# {'loss': tensor(0.8932, device='cuda:0'),
#  'preds': array([[    0,     0,     0, ..., 14872, 14872, 14872],
#        [   22,   181,   300, ..., 14827, 14828, 14850]]),
#  'truth': array([False, False, False, ..., False, False, False]),
#  'truth_graph': array([[ 1291,  3021,  4279, ...,  5237, 13584, 13584],
#        [ 3021,  4279,  5513, ...,  3800,  5195,  5237]])}
# --------------------------------------------------------------------------------
# DATALOADER:15 TEST RESULTS
# {'loss': tensor(0.8894, device='cuda:0'),
#  'preds': array([[    0,     0,     1, ..., 14041, 14041, 14041],
#        [11289, 12024,     4, ..., 13684, 13689, 13975]]),
#  'truth': array([False, False, False, ...,  True,  True, False]),
#  'truth_graph': array([[  120,   790,  1516, ..., 12972, 13368, 13741],
#        [  790,  1516,  2254, ..., 12527, 12972, 13368]])}
# --------------------------------------------------------------------------------
# DATALOADER:16 TEST RESULTS
# {'loss': tensor(0.8888, device='cuda:0'),
#  'preds': array([[    0,     0,     0, ..., 13936, 13936, 13936],
#        [  447,   474,   476, ..., 13529, 13865, 13886]]),
#  'truth': array([False, False, False, ...,  True, False, False]),
#  'truth_graph': array([[ 1961,  2036,  3957, ..., 11098, 12162, 12743],
#        [ 3957,  3957,  5305, ...,  9151, 11098, 12162]])}
# --------------------------------------------------------------------------------
# DATALOADER:17 TEST RESULTS
# {'loss': tensor(0.8983, device='cuda:0'),
#  'preds': array([[    0,     0,     0, ..., 14476, 14476, 14476],
#        [    5,   382,   482, ..., 13228, 14074, 14076]]),
#  'truth': array([False, False, False, ..., False,  True,  True]),
#  'truth_graph': array([[ 5592,  5592,  5592, ..., 10928, 10945, 10965],
#        [ 6564,  6569,  6619, ...,  9364,  9364,  9364]])}
# --------------------------------------------------------------------------------
# DATALOADER:18 TEST RESULTS
# {'loss': tensor(0.8959, device='cuda:0'),
#  'preds': array([[    0,     0,     0, ..., 14966, 14966, 14966],
#        [ 1107,  1150,  2707, ..., 14908, 14919, 14964]]),
#  'truth': array([False,  True, False, ..., False, False, False]),
#  'truth_graph': array([[  661,   661,  1814, ...,  7008, 10734, 12626],
#        [ 1814,  1865,  2925, ...,  4020,  7008, 10734]])}
# --------------------------------------------------------------------------------
# DATALOADER:19 TEST RESULTS
# {'loss': tensor(0.8789, device='cuda:0'),
#  'preds': array([[    0,     0,     0, ..., 12150, 12150, 12150],
#        [ 1012,  1087,  1341, ..., 11810, 11812, 11813]]),
#  'truth': array([ True,  True, False, ...,  True,  True,  True]),
#  'truth_graph': array([[  103,   103,   179, ..., 11070, 11463, 11463],
#        [  706,   760,   706, ...,  9935, 11067, 11070]])}
# --------------------------------------------------------------------------------

# %% [markdown]
# We should always visualise two important metrics: the efficiency (the number of true positives divided by the total number of possible true edges) and the purity (the number of true positives divided by the number of predicted edges). Is it clear to you why the graphs below behave as they do, as we widen the sphere around each hit to generate neighboring edges?

# %%
plt.figure(figsize=(12,8))
plt.plot(all_radius, all_efficiencies);
plt.title("Embedding efficiency", fontsize=24), plt.xlabel("Radius of neighborhood", fontsize=18), plt.ylabel("Efficiency", fontsize=18);

# %%
plt.figure(figsize=(12,8))
plt.plot(all_radius, all_purities);
plt.title("Embedding purity", fontsize=24), plt.xlabel("Radius of neighborhood", fontsize=18), plt.ylabel("Purity", fontsize=18);

# %% [markdown]
# ### Visualise embedding / latent space

# %% [markdown]
# Another useful thing to visualise is the actual space being embedded into. Since it's 8 dimensional, we can reduce it to 2 dimensions with "Principal Component Analysis".

# %%
from sklearn.decomposition import PCA

# %%
example_data = trainset[0]
particle_ids = example_data.pid
cyl_coords = example_data.x
cell_features = example_data.cell_data
all_features = torch.cat([cyl_coords, cell_features], axis=-1).to("cuda")

# %%
latent_features = model(all_features)

# %%
pca = PCA(n_components=2)

# %%
reduced_dimensions = pca.fit_transform(latent_features.detach().cpu())

# %%
reduced_dimensions
# Out:
# array([[ -9.09223254,  -3.33285963],
#        [-11.19454375,  -3.37781835],
#        [ 20.51986303,   4.56269583],
#        ...,
#        [ 17.95672343,   2.00187667],
#        [ 20.73261011,  -2.18240375],
#        [ 19.3198849 ,  -9.09976778]])

# %%
plt.figure(figsize=(12,8))
plt.scatter(reduced_dimensions[:, 0], reduced_dimensions[:, 1], s=1)

# %% [markdown]
# The above plot is what **all** the data looks like in the latent space. Let's pick a (long) particle track and see if the track is projected to be close together:

# %%
particles, counts = np.unique(example_data.pid, return_counts=True)

# %%
example_particle = particles[counts > 10][0]

# %%
plt.figure(figsize=(12,8))
plt.scatter(reduced_dimensions[:, 0], reduced_dimensions[:, 1], s=1)
plt.scatter(reduced_dimensions[particle_ids == example_particle, 0], reduced_dimensions[particle_ids == example_particle, 1])

# %% [markdown]
# There are at least 10 hits in the plot above. Hopefully some of them cluster together into blobs, and that the blobs are close to other blobs of the same color. We get ~99% efficiency with this model, so even if some blobs appear far away in the PCA-reduced 2D space, they are most likely much closer in the 8-dimensional space. You can check this yourself!

# %% [markdown]
# ## Further Investigation

# %% [markdown]
# 1. Is there any performance gain from increasing the number of hidden channels?
# 2. What about *decreasing* the number of channels?
# 3. What about increasing/decreasing the number of dimensions in the latent space?
# 4. Is it possible to overtrain? That is, try increasing the number of epochs and seeing if the validation loss always decreases, plateaus, or starts to increase
# 5. Learning rate can be **everything** in some models. What effect does it have to increase/decrease it here?
# 6. Similarly, "warm-up" is like a slow start, where the learning rate increases for X batches (default of 100 here). Try changing it and seeing if you can improve the final performance.
# 7. To train the model here we use a combination of random pairs (that is, just picking pairs of hits at random, seeing if they belong to the same track, and
