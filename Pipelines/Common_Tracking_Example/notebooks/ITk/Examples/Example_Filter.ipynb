# %% [markdown]
# # Example of Filtering Embedded Pairs

# %%
# %load_ext autoreload
# %autoreload 2

# System imports
import os
import sys
import yaml

# External imports
import matplotlib.pyplot as plt
import scipy as sp
from sklearn.decomposition import PCA
from sklearn.metrics import auc
import numpy as np
import pandas as pd
import seaborn as sns
import torch
from pytorch_lightning.loggers import TensorBoardLogger, WandbLogger
from pytorch_lightning import Trainer
import copy

sys.path.append("../..")
device = "cuda" if torch.cuda.is_available() else "cpu"

from LightningModules.Filter.Models.vanilla_filter import VanillaFilter
from LightningModules.Filter.Models.pyramid_filter import PyramidFilter

# %% [markdown]
# ## Pytorch Lightning Model

# %% [markdown]
# ### Construct PyLightning model

# %% [markdown]
# An ML model typically has many knobs to turn, as well as locations of data, some training preferences, and so on. For convenience, let's put all of these parameters into a YAML file and load it.

# %%
with open("example_filter.yaml") as f:
    hparams = yaml.load(f, Loader=yaml.FullLoader)

# %%
model = PyramidFilter(hparams)

# %% [markdown]
# ## The Dataset

# %%
# %%time
model.setup(stage="fit")
# Out:
# CPU times: user 146 ms, sys: 698 ms, total: 844 ms
# Wall time: 1.1 s

# %% [markdown]
# ### Visualise geometry

# %% [markdown]
# Just as a sanity check, let's look directly at the geometry of the data, as well as some distributions. This is just to make sure that, e.g. it's normalised in some reasonable way (that is, it doesn't vary from -1000 to +1000 or some large numbers, but that it is distributed close to +1 and -1 - this makes training much more effective!), and there aren't weird outliers (this also damages training!).

# %%
trainset = model.trainset

# %%
example_data = trainset[0]
r, phi, z = example_data.x.T

# %%
x, y = r * np.cos(phi * np.pi) * 1000, r * np.sin(phi * np.pi) * 1000
z = z * 1000

# %%
fig, axs = plt.subplots(1, 2, figsize=(22, 10))
axs[0].scatter(z, x, s=1)
axs[1].scatter(x, y, s=1)
axs[0].set_title("Longitudinal Spacepoint Distribution", fontsize=24), axs[
    0
].set_xlabel("z direction (mm)", fontsize=18), axs[0].set_ylabel(
    "x direction (mm)", fontsize=18
)
axs[1].set_title("Down-beampipe Spacepoint Distribution", fontsize=24), axs[
    1
].set_xlabel("x direction (mm)", fontsize=18), axs[1].set_ylabel(
    "y direction (mm)", fontsize=18
)
# Out:
# (Text(0.5, 1.0, 'Down-beampipe Spacepoint Distribution'),
#  Text(0.5, 0, 'x direction (mm)'),
#  Text(0, 0.5, 'y direction (mm)'))

# %% [markdown]
# ### Visualise distributions

# %%
plt.figure(figsize=(12, 8))
sns.histplot(
    example_data.pt[example_data.pt == example_data.pt],
    binwidth=200,
    binrange=[0, 5000],
)
plt.title("Distribution of Momentum", fontsize=24), plt.xlabel(
    "pT (GeV)", fontsize=18
), plt.ylabel("Count", fontsize=18)
# Out:
# (Text(0.5, 1.0, 'Distribution of Momentum'),
#  Text(0.5, 0, 'pT (GeV)'),
#  Text(0, 0.5, 'Count'))

# %% [markdown]
# Observe the hard cut-off below 1GeV - this is because we are ignoring lower energy hits to keep things easy for now. But we should include them again once we are happy with our ML architecture!

# %%
particle_num, particle_counts = np.unique(example_data.pid.numpy(), return_counts=True)

# %%
plt.figure(figsize=(12, 8))
sns.histplot(particle_counts[1:], binwidth=1)
plt.title("Distribution of Hits per Particle", fontsize=24), plt.xlabel(
    "Hits", fontsize=18
), plt.ylabel("Count", fontsize=18)
# Out:
# (Text(0.5, 1.0, 'Distribution of Hits per Particle'),
#  Text(0.5, 0, 'Hits'),
#  Text(0, 0.5, 'Count'))

# %% [markdown]
# This gives an idea about how long each particle track is. We can see that most particle tracks leave > 10 hits, which will be useful for our graph neural networks down the track. In general, shorter tracks are harder to detect, and less useful for doing meaningful physics.

# %%
example_data.edge_index.shape
# Out:
# torch.Size([2, 2166995])

# %%
(
    example_data.pid[example_data.edge_index[0]]
    == example_data.pid[example_data.edge_index[1]]
).sum()
# Out:
# tensor(642307)

# %%
example_data.y.sum()
# Out:
# tensor(5196.)

# %%
example_data
# Out:
# Data(cell_data=[96465, 11], edge_index=[2, 2166995], event_file="/global/cfs/cdirs/m3443/data/ITk-upgrade/processed/full_events_v4/event000010001", hid=[96465], modulewise_true_edges=[2, 37882], nhits=[96465], pid=[96465], primary=[96465], pt=[96465], signal_true_edges=[2, 5305], x=[96465, 3], y=[2166995])

# %% [markdown]
# ### Cell Info

# %%
cell_features = [
    "norm_x",
    "norm_y",
    "barrel_endcap",
    "layer_disk",
    "eta_module",
    "phi_module",
    "eta_angle_1",
    "phi_angle_1",
    "eta_angle_2",
    "phi_angle_2",
    "pixel",
]

# %%
example_data.cell_data
# Out:
# tensor([[ 0.3610,  0.1495,  0.0000,  ..., -1.0000, -1.0000,  1.0000],
#         [ 0.0000,  0.0000, -2.0000,  ..., -1.0000, -1.0000,  1.0000],
#         [ 0.0000,  0.0000,  2.0000,  ..., -1.0000, -1.0000,  1.0000],
#         ...,
#         [ 0.0000,  0.0000,  2.0000,  ...,  1.3239,  0.0059,  0.0000],
#         [ 0.0000,  0.0000,  2.0000,  ...,  0.5373,  0.0064,  0.0000],
#         [ 0.0000,  0.0000,  2.0000,  ...,  1.3246,  0.0064,  0.0000]])

# %%
for i, feature in enumerate(cell_features):
    plt.figure()
    sns.histplot(example_data.cell_data[:, i].numpy()).set_title(feature)

# %% [markdown]
# ## Filter Learning

# %% [markdown]
# ### Train filter

# %% [markdown]
# Finally! Let's train! We instantiate a `Trainer` class that knows things like which hardware to work with, how long to train for, and a **bunch** of default options that we ignore here. Check out the Trainer class docs in Pytorch Lightning. Suffice it to say that it clears away much repetitive boilerplate in training code.

# %%
from pytorch_lightning.callbacks import ModelCheckpoint

checkpoint_callback = ModelCheckpoint(
    monitor="eff", mode="max", save_top_k=2, save_last=True
)

# %%
# %%time
logger = WandbLogger(
    project=hparams["project"], group="InitialTest", save_dir=hparams["artifacts"]
)
trainer = Trainer(
    gpus=1,
    max_epochs=hparams["max_epochs"],
    num_sanity_val_steps=0,
    logger=logger,
    callbacks=[checkpoint_callback],
)
trainer.fit(model)
# Out:
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# ERROR:wandb.jupyter:Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: Currently logged in as: murnanedaniel (use `wandb login --relogin` to force relogin)
# wandb: wandb version 0.12.9 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
#                     Syncing run <strong><a href="https://wandb.ai/murnanedaniel/ITk_1GeVSignal_Barrel_Filter/runs/d0hpxf5c" target="_blank">woven-microwave-5</a></strong> to <a href="https://wandb.ai/murnanedaniel/ITk_1GeVSignal_Barrel_Filter" target="_blank">Weights & Biases</a> (<a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">docs</a>).<br/>
#   | Name         | Type       | Params
# --------------------------------------------
# 0 | input_layer  | Linear     | 23.6 K
# 1 | layers       | ModuleList | 689 K
# 2 | output_layer | Linear     | 129
# 3 | act          | Tanh       | 0
# --------------------------------------------
# 712 K     Trainable params
# 0         Non-trainable params
# 712 K     Total params
# 2.851     Total estimated model params size (MB)
# /global/homes/d/danieltm/.local/lib/python3.8/site-packages/pytorch_lightning/trainer/data_loading.py:110: UserWarning: The dataloader, train_dataloader, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 256 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
#   rank_zero_warn(
# /global/homes/d/danieltm/.local/lib/python3.8/site-packages/pytorch_lightning/trainer/data_loading.py:110: UserWarning: The dataloader, val_dataloader 0, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 256 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
#   rank_zero_warn(
# Epoch 0:   0%|          | 0/1020 [00:00<?, ?it/s]
# /global/homes/d/danieltm/.local/lib/python3.8/site-packages/pytorch_lightning/utilities/data.py:56: UserWarning: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 5. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
#   warning_cache.warn(
# Epoch 0:  98%|█████████▊| 1000/1020 [04:08<00:04,  4.02it/s, loss=1.26, v_num=xf5c]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/20 [00:00<?, ?it/s]
# Epoch 0:  98%|█████████▊| 1002/1020 [04:10<00:04,  4.00it/s, loss=1.26, v_num=xf5c]
# Validating:  10%|█         | 2/20 [00:02<00:23,  1.30s/it]
# Epoch 0:  98%|█████████▊| 1004/1020 [04:11<00:04,  3.99it/s, loss=1.26, v_num=xf5c]
# Validating:  20%|██        | 4/20 [00:04<00:14,  1.09it/s]
# Epoch 0:  99%|█████████▊| 1006/1020 [04:13<00:03,  3.97it/s, loss=1.26, v_num=xf5c]
# Validating:  30%|███       | 6/20 [00:05<00:10,  1.29it/s]
# Epoch 0:  99%|█████████▉| 1008/1020 [04:14<00:03,  3.96it/s, loss=1.26, v_num=xf5c]
# Validating:  40%|████      | 8/20 [00:06<00:08,  1.39it/s]
# Epoch 0:  99%|█████████▉| 1010/1020 [04:16<00:02,  3.94it/s, loss=1.26, v_num=xf5c]
# Validating:  50%|█████     | 10/20 [00:08<00:07,  1.39it/s]
# Epoch 0:  99%|█████████▉| 1012/1020 [04:17<00:02,  3.93it/s, loss=1.26, v_num=xf5c]
# Validating:  60%|██████    | 12/20 [00:09<00:06,  1.32it/s]
# Epoch 0:  99%|█████████▉| 1014/1020 [04:19<00:01,  3.91it/s, loss=1.26, v_num=xf5c]
# Validating:  70%|███████   | 14/20 [00:11<00:05,  1.13it/s]
# Epoch 0: 100%|█████████▉| 1016/1020 [04:21<00:01,  3.89it/s, loss=1.26, v_num=xf5c]
# Validating:  80%|████████  | 16/20 [00:13<00:03,  1.05it/s]
# Epoch 0: 100%|█████████▉| 1018/1020 [04:23<00:00,  3.86it/s, loss=1.26, v_num=xf5c]
# Validating:  90%|█████████ | 18/20 [00:16<00:02,  1.01s/it]
# Epoch 0: 100%|██████████| 1020/1020 [04:25<00:00,  3.84it/s, loss=1.26, v_num=xf5c]
# Epoch 0: 100%|██████████| 1020/1020 [04:27<00:00,  3.81it/s, loss=1.26, v_num=xf5c]
# Epoch 1:  98%|█████████▊| 1000/1020 [04:06<00:04,  4.05it/s, loss=1.27, v_num=xf5c]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/20 [00:00<?, ?it/s]
# Epoch 1:  98%|█████████▊| 1002/1020 [04:08<00:04,  4.03it/s, loss=1.27, v_num=xf5c]
# Validating:  10%|█         | 2/20 [00:02<00:22,  1.27s/it]
# Epoch 1:  98%|█████████▊| 1004/1020 [04:10<00:03,  4.01it/s, loss=1.27, v_num=xf5c]
# Validating:  20%|██        | 4/20 [00:04<00:14,  1.13it/s]
# Epoch 1:  99%|█████████▊| 1006/1020 [04:11<00:03,  4.00it/s, loss=1.27, v_num=xf5c]
# Validating:  30%|███       | 6/20 [00:05<00:10,  1.37it/s]
# Epoch 1:  99%|█████████▉| 1008/1020 [04:12<00:03,  3.99it/s, loss=1.27, v_num=xf5c]
# Validating:  40%|████      | 8/20 [00:06<00:08,  1.48it/s]
# Epoch 1:  99%|█████████▉| 1010/1020 [04:14<00:02,  3.97it/s, loss=1.27, v_num=xf5c]
# Validating:  50%|█████     | 10/20 [00:07<00:06,  1.47it/s]
# Epoch 1:  99%|█████████▉| 1012/1020 [04:15<00:02,  3.96it/s, loss=1.27, v_num=xf5c]
# Validating:  60%|██████    | 12/20 [00:09<00:05,  1.39it/s]
# Epoch 1:  99%|█████████▉| 1014/1020 [04:16<00:01,  3.95it/s, loss=1.27, v_num=xf5c]
# Validating:  70%|███████   | 14/20 [00:10<00:04,  1.42it/s]
# Epoch 1: 100%|█████████▉| 1016/1020 [04:18<00:01,  3.92it/s, loss=1.27, v_num=xf5c]
# Validating:  80%|████████  | 16/20 [00:13<00:03,  1.02it/s]
# Epoch 1: 100%|█████████▉| 1018/1020 [04:21<00:00,  3.90it/s, loss=1.27, v_num=xf5c]
# Validating:  90%|█████████ | 18/20 [00:15<00:02,  1.18s/it]
# Epoch 1: 100%|██████████| 1020/1020 [04:24<00:00,  3.86it/s, loss=1.27, v_num=xf5c]
# Epoch 1: 100%|██████████| 1020/1020 [04:26<00:00,  3.83it/s, loss=1.27, v_num=xf5c]
# Epoch 2:  98%|█████████▊| 1000/1020 [04:04<00:04,  4.10it/s, loss=1.09, v_num=xf5c]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/20 [00:00<?, ?it/s]
# Epoch 2:  98%|█████████▊| 1002/1020 [04:06<00:04,  4.07it/s, loss=1.09, v_num=xf5c]
# Validating:  10%|█         | 2/20 [00:02<00:24,  1.37s/it]
# Epoch 2:  98%|█████████▊| 1004/1020 [04:07<00:03,  4.06it/s, loss=1.09, v_num=xf5c]
# Validating:  20%|██        | 4/20 [00:04<00:15,  1.04it/s]
# Epoch 2:  99%|█████████▊| 1006/1020 [04:09<00:03,  4.04it/s, loss=1.09, v_num=xf5c]
# Validating:  30%|███       | 6/20 [00:05<00:11,  1.25it/s]
# Epoch 2:  99%|█████████▉| 1008/1020 [04:10<00:02,  4.02it/s, loss=1.09, v_num=xf5c]
# Validating:  40%|████      | 8/20 [00:07<00:08,  1.35it/s]
# Epoch 2:  99%|█████████▉| 1010/1020 [04:12<00:02,  4.01it/s, loss=1.09, v_num=xf5c]
# Validating:  50%|█████     | 10/20 [00:08<00:07,  1.33it/s]
# Epoch 2:  99%|█████████▉| 1012/1020 [04:13<00:02,  3.99it/s, loss=1.09, v_num=xf5c]
# Validating:  60%|██████    | 12/20 [00:10<00:06,  1.26it/s]
# Epoch 2:  99%|█████████▉| 1014/1020 [04:15<00:01,  3.97it/s, loss=1.09, v_num=xf5c]
# Validating:  70%|███████   | 14/20 [00:11<00:04,  1.29it/s]
# Epoch 2: 100%|█████████▉| 1016/1020 [04:16<00:01,  3.96it/s, loss=1.09, v_num=xf5c]
# Validating:  80%|████████  | 16/20 [00:13<00:03,  1.20it/s]
# Epoch 2: 100%|█████████▉| 1018/1020 [04:18<00:00,  3.93it/s, loss=1.09, v_num=xf5c]
# Validating:  90%|█████████ | 18/20 [00:15<00:01,  1.02it/s]
# Epoch 2: 100%|██████████| 1020/1020 [04:20<00:00,  3.91it/s, loss=1.09, v_num=xf5c]
# Epoch 2: 100%|██████████| 1020/1020 [04:23<00:00,  3.88it/s, loss=1.09, v_num=xf5c]
# Epoch 3:  98%|█████████▊| 1000/1020 [03:56<00:04,  4.23it/s, loss=1.08, v_num=xf5c]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/20 [00:00<?, ?it/s]
# Epoch 3:  98%|█████████▊| 1002/1020 [03:58<00:04,  4.21it/s, loss=1.08, v_num=xf5c]
# Validating:  10%|█         | 2/20 [00:02<00:24,  1.35s/it]
# Epoch 3:  98%|█████████▊| 1004/1020 [03:59<00:03,  4.19it/s, loss=1.08, v_num=xf5c]
# Validating:  20%|██        | 4/20 [00:04<00:15,  1.04it/s]
# Epoch 3:  99%|█████████▊| 1006/1020 [04:01<00:03,  4.17it/s, loss=1.08, v_num=xf5c]
# Validating:  30%|███       | 6/20 [00:05<00:11,  1.25it/s]
# Epoch 3:  99%|█████████▉| 1008/1020 [04:02<00:02,  4.15it/s, loss=1.08, v_num=xf5c]
# Validating:  40%|████      | 8/20 [00:07<00:08,  1.34it/s]
# Epoch 3:  99%|█████████▉| 1010/1020 [04:04<00:02,  4.13it/s, loss=1.08, v_num=xf5c]
# Validating:  50%|█████     | 10/20 [00:09<00:08,  1.12it/s]
# Epoch 3:  99%|█████████▉| 1012/1020 [04:06<00:01,  4.11it/s, loss=1.08, v_num=xf5c]
# Validating:  60%|██████    | 12/20 [00:10<00:06,  1.15it/s]
# Epoch 3:  99%|█████████▉| 1014/1020 [04:07<00:01,  4.09it/s, loss=1.08, v_num=xf5c]
# Validating:  70%|███████   | 14/20 [00:12<00:04,  1.23it/s]
# Epoch 3: 100%|█████████▉| 1016/1020 [04:09<00:00,  4.07it/s, loss=1.08, v_num=xf5c]
# Validating:  80%|████████  | 16/20 [00:14<00:03,  1.17it/s]
# Epoch 3: 100%|█████████▉| 1018/1020 [04:11<00:00,  4.05it/s, loss=1.08, v_num=xf5c]
# Validating:  90%|█████████ | 18/20 [00:16<00:01,  1.01it/s]
# Epoch 3: 100%|██████████| 1020/1020 [04:13<00:00,  4.02it/s, loss=1.08, v_num=xf5c]
# Epoch 3: 100%|██████████| 1020/1020 [04:15<00:00,  3.99it/s, loss=1.08, v_num=xf5c]
# Epoch 4:  98%|█████████▊| 1000/1020 [03:59<00:04,  4.17it/s, loss=1.11, v_num=xf5c]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/20 [00:00<?, ?it/s]
# Epoch 4:  98%|█████████▊| 1002/1020 [04:01<00:04,  4.14it/s, loss=1.11, v_num=xf5c]
# Validating:  10%|█         | 2/20 [00:02<00:24,  1.35s/it]
# Epoch 4:  98%|█████████▊| 1004/1020 [04:03<00:03,  4.12it/s, loss=1.11, v_num=xf5c]
# Validating:  20%|██        | 4/20 [00:04<00:15,  1.05it/s]
# Epoch 4:  99%|█████████▊| 1006/1020 [04:04<00:03,  4.11it/s, loss=1.11, v_num=xf5c]
# Validating:  30%|███       | 6/20 [00:05<00:11,  1.25it/s]
# Epoch 4:  99%|█████████▉| 1008/1020 [04:06<00:02,  4.09it/s, loss=1.11, v_num=xf5c]
# Validating:  40%|████      | 8/20 [00:07<00:08,  1.34it/s]
# Epoch 4:  99%|█████████▉| 1010/1020 [04:07<00:02,  4.07it/s, loss=1.11, v_num=xf5c]
# Validating:  50%|█████     | 10/20 [00:08<00:07,  1.32it/s]
# Epoch 4:  99%|█████████▉| 1012/1020 [04:09<00:01,  4.06it/s, loss=1.11, v_num=xf5c]
# Validating:  60%|██████    | 12/20 [00:10<00:06,  1.23it/s]
# Epoch 4:  99%|█████████▉| 1014/1020 [04:11<00:01,  4.04it/s, loss=1.11, v_num=xf5c]
# Validating:  70%|███████   | 14/20 [00:11<00:04,  1.25it/s]
# Epoch 4: 100%|█████████▉| 1016/1020 [04:12<00:00,  4.02it/s, loss=1.11, v_num=xf5c]
# Validating:  80%|████████  | 16/20 [00:13<00:03,  1.16it/s]
# Epoch 4: 100%|█████████▉| 1018/1020 [04:14<00:00,  3.99it/s, loss=1.11, v_num=xf5c]
# Validating:  90%|█████████ | 18/20 [00:16<00:01,  1.00it/s]
# Epoch 4: 100%|██████████| 1020/1020 [04:16<00:00,  3.97it/s, loss=1.11, v_num=xf5c]
# Epoch 4: 100%|██████████| 1020/1020 [04:19<00:00,  3.93it/s, loss=1.11, v_num=xf5c]
# Epoch 5:  98%|█████████▊| 1000/1020 [03:58<00:04,  4.20it/s, loss=1.07, v_num=xf5c]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/20 [00:00<?, ?it/s]
# Epoch 5:  98%|█████████▊| 1002/1020 [04:00<00:04,  4.17it/s, loss=1.07, v_num=xf5c]
# Validating:  10%|█         | 2/20 [00:02<00:24,  1.34s/it]
# Epoch 5:  98%|█████████▊| 1004/1020 [04:01<00:03,  4.15it/s, loss=1.07, v_num=xf5c]
# Validating:  20%|██        | 4/20 [00:04<00:15,  1.05it/s]
# Epoch 5:  99%|█████████▊| 1006/1020 [04:03<00:03,  4.14it/s, loss=1.07, v_num=xf5c]
# Validating:  30%|███       | 6/20 [00:05<00:11,  1.25it/s]
# Epoch 5:  99%|█████████▉| 1008/1020 [04:04<00:02,  4.12it/s, loss=1.07, v_num=xf5c]
# Validating:  40%|████      | 8/20 [00:07<00:08,  1.35it/s]
# Epoch 5:  99%|█████████▉| 1010/1020 [04:06<00:02,  4.10it/s, loss=1.07, v_num=xf5c]
# Validating:  50%|█████     | 10/20 [00:09<00:09,  1.07it/s]
# Epoch 5:  99%|█████████▉| 1012/1020 [04:08<00:01,  4.07it/s, loss=1.07, v_num=xf5c]
# Validating:  60%|██████    | 12/20 [00:11<00:07,  1.07it/s]
# Epoch 5:  99%|█████████▉| 1014/1020 [04:10<00:01,  4.05it/s, loss=1.07, v_num=xf5c]
# Validating:  70%|███████   | 14/20 [00:12<00:05,  1.18it/s]
# Epoch 5: 100%|█████████▉| 1016/1020 [04:11<00:00,  4.04it/s, loss=1.07, v_num=xf5c]
# Validating:  80%|████████  | 16/20 [00:14<00:03,  1.15it/s]
# Epoch 5: 100%|█████████▉| 1018/1020 [04:13<00:00,  4.01it/s, loss=1.07, v_num=xf5c]
# Validating:  90%|█████████ | 18/20 [00:16<00:01,  1.01it/s]
# Epoch 5: 100%|██████████| 1020/1020 [04:15<00:00,  3.99it/s, loss=1.07, v_num=xf5c]
# Epoch 5: 100%|██████████| 1020/1020 [04:18<00:00,  3.95it/s, loss=1.07, v_num=xf5c]
# Epoch 6:  98%|█████████▊| 1000/1020 [03:59<00:04,  4.18it/s, loss=1.11, v_num=xf5c]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/20 [00:00<?, ?it/s]
# Epoch 6:  98%|█████████▊| 1002/1020 [04:01<00:04,  4.15it/s, loss=1.11, v_num=xf5c]
# Validating:  10%|█         | 2/20 [00:02<00:24,  1.35s/it]
# Epoch 6:  98%|█████████▊| 1004/1020 [04:02<00:03,  4.13it/s, loss=1.11, v_num=xf5c]
# Validating:  20%|██        | 4/20 [00:04<00:15,  1.03it/s]
# Epoch 6:  99%|█████████▊| 1006/1020 [04:04<00:03,  4.12it/s, loss=1.11, v_num=xf5c]
# Validating:  30%|███       | 6/20 [00:05<00:11,  1.24it/s]
# Epoch 6:  99%|█████████▉| 1008/1020 [04:05<00:02,  4.10it/s, loss=1.11, v_num=xf5c]
# Validating:  40%|████      | 8/20 [00:07<00:08,  1.34it/s]
# Epoch 6:  99%|█████████▉| 1010/1020 [04:07<00:02,  4.08it/s, loss=1.11, v_num=xf5c]
# Validating:  50%|█████     | 10/20 [00:08<00:07,  1.32it/s]
# Epoch 6:  99%|█████████▉| 1012/1020 [04:08<00:01,  4.07it/s, loss=1.11, v_num=xf5c]
# Validating:  60%|██████    | 12/20 [00:10<00:06,  1.25it/s]
# Epoch 6:  99%|█████████▉| 1014/1020 [04:10<00:01,  4.05it/s, loss=1.11, v_num=xf5c]
# Validating:  70%|███████   | 14/20 [00:11<00:04,  1.27it/s]
# Epoch 6: 100%|█████████▉| 1016/1020 [04:12<00:00,  4.03it/s, loss=1.11, v_num=xf5c]
# Validating:  80%|████████  | 16/20 [00:13<00:03,  1.19it/s]
# Epoch 6: 100%|█████████▉| 1018/1020 [04:14<00:00,  4.00it/s, loss=1.11, v_num=xf5c]
# Validating:  90%|█████████ | 18/20 [00:15<00:01,  1.02it/s]
# Epoch 6: 100%|██████████| 1020/1020 [04:16<00:00,  3.98it/s, loss=1.11, v_num=xf5c]
# Epoch 6: 100%|██████████| 1020/1020 [04:18<00:00,  3.94it/s, loss=1.11, v_num=xf5c]
# Epoch 7:  98%|█████████▊| 1000/1020 [03:57<00:04,  4.21it/s, loss=1.08, v_num=xf5c]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/20 [00:00<?, ?it/s]
# Epoch 7:  98%|█████████▊| 1002/1020 [03:59<00:04,  4.18it/s, loss=1.08, v_num=xf5c]
# Validating:  10%|█         | 2/20 [00:02<00:24,  1.35s/it]
# Epoch 7:  98%|█████████▊| 1004/1020 [04:01<00:03,  4.16it/s, loss=1.08, v_num=xf5c]
# Validating:  20%|██        | 4/20 [00:04<00:15,  1.04it/s]
# Epoch 7:  99%|█████████▊| 1006/1020 [04:02<00:03,  4.14it/s, loss=1.08, v_num=xf5c]
# Validating:  30%|███       | 6/20 [00:05<00:11,  1.25it/s]
# Epoch 7:  99%|█████████▉| 1008/1020 [04:04<00:02,  4.13it/s, loss=1.08, v_num=xf5c]
# Validating:  40%|████      | 8/20 [00:07<00:08,  1.34it/s]
# Epoch 7:  99%|█████████▉| 1010/1020 [04:05<00:02,  4.11it/s, loss=1.08, v_num=xf5c]
# Validating:  50%|█████     | 10/20 [00:08<00:07,  1.33it/s]
# Epoch 7:  99%|█████████▉| 1012/1020 [04:07<00:01,  4.09it/s, loss=1.08, v_num=xf5c]
# Validating:  60%|██████    | 12/20 [00:10<00:06,  1.24it/s]
# Epoch 7:  99%|█████████▉| 1014/1020 [04:08<00:01,  4.07it/s, loss=1.08, v_num=xf5c]
# Validating:  70%|███████   | 14/20 [00:11<00:04,  1.28it/s]
# Epoch 7: 100%|█████████▉| 1016/1020 [04:10<00:00,  4.06it/s, loss=1.08, v_num=xf5c]
# Validating:  80%|████████  | 16/20 [00:13<00:03,  1.19it/s]
# Epoch 7: 100%|█████████▉| 1018/1020 [04:12<00:00,  4.03it/s, loss=1.08, v_num=xf5c]
# Validating:  90%|█████████ | 18/20 [00:15<00:01,  1.02it/s]
# Epoch 7: 100%|██████████| 1020/1020 [04:14<00:00,  4.00it/s, loss=1.08, v_num=xf5c]
# Epoch 7: 100%|██████████| 1020/1020 [04:17<00:00,  3.97it/s, loss=1.08, v_num=xf5c]
# Epoch 8:  98%|█████████▊| 1000/1020 [04:01<00:04,  4.15it/s, loss=1.07, v_num=xf5c]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/20 [00:00<?, ?it/s]
# Epoch 8:  98%|█████████▊| 1002/1020 [04:02<00:04,  4.12it/s, loss=1.07, v_num=xf5c]
# Validating:  10%|█         | 2/20 [00:02<00:24,  1.33s/it]
# Epoch 8:  98%|█████████▊| 1004/1020 [04:04<00:03,  4.11it/s, loss=1.07, v_num=xf5c]
# Validating:  20%|██        | 4/20 [00:04<00:15,  1.06it/s]
# Epoch 8:  99%|█████████▊| 1006/1020 [04:05<00:03,  4.09it/s, loss=1.07, v_num=xf5c]
# Validating:  30%|███       | 6/20 [00:05<00:10,  1.27it/s]
# Epoch 8:  99%|█████████▉| 1008/1020 [04:07<00:02,  4.07it/s, loss=1.07, v_num=xf5c]
# Validating:  40%|████      | 8/20 [00:07<00:08,  1.37it/s]
# Epoch 8:  99%|█████████▉| 1010/1020 [04:08<00:02,  4.06it/s, loss=1.07, v_num=xf5c]
# Validating:  50%|█████     | 10/20 [00:08<00:07,  1.35it/s]
# Epoch 8:  99%|█████████▉| 1012/1020 [04:10<00:01,  4.04it/s, loss=1.07, v_num=xf5c]
# Validating:  60%|██████    | 12/20 [00:10<00:06,  1.28it/s]
# Epoch 8:  99%|█████████▉| 1014/1020 [04:11<00:01,  4.03it/s, loss=1.07, v_num=xf5c]
# Validating:  70%|███████   | 14/20 [00:11<00:04,  1.31it/s]
# Epoch 8: 100%|█████████▉| 1016/1020 [04:13<00:00,  4.01it/s, loss=1.07, v_num=xf5c]
# Validating:  80%|████████  | 16/20 [00:13<00:03,  1.22it/s]
# Epoch 8: 100%|█████████▉| 1018/1020 [04:15<00:00,  3.98it/s, loss=1.07, v_num=xf5c]
# Validating:  90%|█████████ | 18/20 [00:15<00:01,  1.04it/s]
# Epoch 8: 100%|██████████| 1020/1020 [04:17<00:00,  3.96it/s, loss=1.07, v_num=xf5c]
# Epoch 8: 100%|██████████| 1020/1020 [04:19<00:00,  3.93it/s, loss=1.07, v_num=xf5c]
# Epoch 9:  98%|█████████▊| 1000/1020 [03:57<00:04,  4.21it/s, loss=1.06, v_num=xf5c]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/20 [00:00<?, ?it/s]
# Epoch 9:  98%|█████████▊| 1002/1020 [03:59<00:04,  4.19it/s, loss=1.06, v_num=xf5c]
# Validating:  10%|█         | 2/20 [00:02<00:24,  1.35s/it]
# Epoch 9:  98%|█████████▊| 1004/1020 [04:00<00:03,  4.17it/s, loss=1.06, v_num=xf5c]
# Validating:  20%|██        | 4/20 [00:04<00:15,  1.05it/s]
# Epoch 9:  99%|█████████▊| 1006/1020 [04:02<00:03,  4.15it/s, loss=1.06, v_num=xf5c]
# Validating:  30%|███       | 6/20 [00:05<00:11,  1.25it/s]
# Epoch 9:  99%|█████████▉| 1008/1020 [04:03<00:02,  4.13it/s, loss=1.06, v_num=xf5c]
# Validating:  40%|████      | 8/20 [00:07<00:08,  1.36it/s]
# Epoch 9:  99%|█████████▉| 1010/1020 [04:05<00:02,  4.11it/s, loss=1.06, v_num=xf5c]
# Validating:  50%|█████     | 10/20 [00:09<00:09,  1.03it/s]
# Epoch 9:  99%|█████████▉| 1012/1020 [04:07<00:01,  4.08it/s, loss=1.06, v_num=xf5c]
# Validating:  60%|██████    | 12/20 [00:11<00:07,  1.06it/s]
# Epoch 9:  99%|█████████▉| 1014/1020 [04:09<00:01,  4.06it/s, loss=1.06, v_num=xf5c]
# Validating:  70%|███████   | 14/20 [00:12<00:05,  1.16it/s]
# Epoch 9: 100%|█████████▉| 1016/1020 [04:11<00:00,  4.05it/s, loss=1.06, v_num=xf5c]
# Validating:  80%|████████  | 16/20 [00:14<00:03,  1.12it/s]
# Epoch 9: 100%|█████████▉| 1018/1020 [04:13<00:00,  4.02it/s, loss=1.06, v_num=xf5c]
# Validating:  90%|█████████ | 18/20 [00:17<00:02,  1.02s/it]
# Epoch 9: 100%|██████████| 1020/1020 [04:15<00:00,  3.99it/s, loss=1.06, v_num=xf5c]
# Epoch 9: 100%|██████████| 1020/1020 [04:17<00:00,  3.96it/s, loss=1.06, v_num=xf5c]
# Epoch 10:  98%|█████████▊| 1000/1020 [03:51<00:04,  4.31it/s, loss=1.06, v_num=xf5c]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/20 [00:00<?, ?it/s]
# Epoch 10:  98%|█████████▊| 1002/1020 [03:53<00:04,  4.29it/s, loss=1.06, v_num=xf5c]
# Validating:  10%|█         | 2/20 [00:02<00:24,  1.35s/it]
# Epoch 10:  98%|█████████▊| 1004/1020 [03:55<00:03,  4.27it/s, loss=1.06, v_num=xf5c]
# Validating:  20%|██        | 4/20 [00:04<00:15,  1.04it/s]
# Epoch 10:  99%|█████████▊| 1006/1020 [03:56<00:03,  4.25it/s, loss=1.06, v_num=xf5c]
# Validating:  30%|███       | 6/20 [00:05<00:11,  1.25it/s]
# Epoch 10:  99%|█████████▉| 1008/1020 [03:58<00:02,  4.23it/s, loss=1.06, v_num=xf5c]
# Validating:  40%|████      | 8/20 [00:07<00:09,  1.33it/s]
# Epoch 10:  99%|█████████▉| 1010/1020 [03:59<00:02,  4.21it/s, loss=1.06, v_num=xf5c]
# Validating:  50%|█████     | 10/20 [00:08<00:07,  1.32it/s]
# Epoch 10:  99%|█████████▉| 1012/1020 [04:01<00:01,  4.19it/s, loss=1.06, v_num=xf5c]
# Validating:  60%|██████    | 12/20 [00:10<00:06,  1.26it/s]
# Epoch 10:  99%|█████████▉| 1014/1020 [04:02<00:01,  4.17it/s, loss=1.06, v_num=xf5c]
# Validating:  70%|███████   | 14/20 [00:11<00:04,  1.29it/s]
# Epoch 10: 100%|█████████▉| 1016/1020 [04:04<00:00,  4.15it/s, loss=1.06, v_num=xf5c]
# Validating:  80%|████████  | 16/20 [00:13<00:03,  1.17it/s]
# Epoch 10: 100%|█████████▉| 1018/1020 [04:06<00:00,  4.13it/s, loss=1.06, v_num=xf5c]
# Validating:  90%|█████████ | 18/20 [00:15<00:01,  1.01it/s]
# Epoch 10: 100%|██████████| 1020/1020 [04:08<00:00,  4.10it/s, loss=1.06, v_num=xf5c]
# Epoch 10: 100%|██████████| 1020/1020 [04:11<00:00,  4.06it/s, loss=1.06, v_num=xf5c]
# Epoch 11:  98%|█████████▊| 1000/1020 [03:53<00:04,  4.28it/s, loss=1.05, v_num=xf5c]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/20 [00:00<?, ?it/s]
# Epoch 11:  98%|█████████▊| 1002/1020 [03:55<00:04,  4.26it/s, loss=1.05, v_num=xf5c]
# Validating:  10%|█         | 2/20 [00:02<00:23,  1.32s/it]
# Epoch 11:  98%|█████████▊| 1004/1020 [03:57<00:03,  4.23it/s, loss=1.05, v_num=xf5c]
# Validating:  20%|██        | 4/20 [00:04<00:15,  1.04it/s]
# Epoch 11:  99%|█████████▊| 1006/1020 [03:58<00:03,  4.22it/s, loss=1.05, v_num=xf5c]
# Validating:  30%|███       | 6/20 [00:05<00:11,  1.25it/s]
# Epoch 11:  99%|█████████▉| 1008/1020 [04:00<00:02,  4.20it/s, loss=1.05, v_num=xf5c]
# Validating:  40%|████      | 8/20 [00:07<00:08,  1.34it/s]
# Epoch 11:  99%|█████████▉| 1010/1020 [04:01<00:02,  4.18it/s, loss=1.05, v_num=xf5c]
# Validating:  50%|█████     | 10/20 [00:08<00:07,  1.32it/s]
# Epoch 11:  99%|█████████▉| 1012/1020 [04:03<00:01,  4.16it/s, loss=1.05, v_num=xf5c]
# Validating:  60%|██████    | 12/20 [00:10<00:06,  1.25it/s]
# Epoch 11:  99%|█████████▉| 1014/1020 [04:04<00:01,  4.14it/s, loss=1.05, v_num=xf5c]
# Validating:  70%|███████   | 14/20 [00:11<00:04,  1.27it/s]
# Epoch 11: 100%|█████████▉| 1016/1020 [04:06<00:00,  4.12it/s, loss=1.05, v_num=xf5c]
# Validating:  80%|████████  | 16/20 [00:13<00:03,  1.18it/s]
# Epoch 11: 100%|█████████▉| 1018/1020 [04:08<00:00,  4.10it/s, loss=1.05, v_num=xf5c]
# Validating:  90%|█████████ | 18/20 [00:16<00:02,  1.09s/it]
# Epoch 11: 100%|██████████| 1020/1020 [04:11<00:00,  4.05it/s, loss=1.05, v_num=xf5c]
# Epoch 11: 100%|██████████| 1020/1020 [04:13<00:00,  4.02it/s, loss=1.05, v_num=xf5c]
# Epoch 12:  98%|█████████▊| 1000/1020 [04:00<00:04,  4.16it/s, loss=1.04, v_num=xf5c]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/20 [00:00<?, ?it/s]
# Epoch 12:  98%|█████████▊| 1002/1020 [04:02<00:04,  4.13it/s, loss=1.04, v_num=xf5c]
# Validating:  10%|█         | 2/20 [00:02<00:24,  1.36s/it]
# Epoch 12:  98%|█████████▊| 1004/1020 [04:03<00:03,  4.12it/s, loss=1.04, v_num=xf5c]
# Validating:  20%|██        | 4/20 [00:04<00:15,  1.04it/s]
# Epoch 12:  99%|█████████▊| 1006/1020 [04:05<00:03,  4.10it/s, loss=1.04, v_num=xf5c]
# Validating:  30%|███       | 6/20 [00:05<00:11,  1.24it/s]
# Epoch 12:  99%|█████████▉| 1008/1020 [04:07<00:02,  4.08it/s, loss=1.04, v_num=xf5c]
# Validating:  40%|████      | 8/20 [00:07<00:09,  1.33it/s]
# Epoch 12:  99%|█████████▉| 1010/1020 [04:08<00:02,  4.07it/s, loss=1.04, v_num=xf5c]
# Validating:  50%|█████     | 10/20 [00:08<00:07,  1.31it/s]
# Epoch 12:  99%|█████████▉| 1012/1020 [04:10<00:01,  4.05it/s, loss=1.04, v_num=xf5c]
# Validating:  60%|██████    | 12/20 [00:11<00:08,  1.00s/it]
# Epoch 12:  99%|█████████▉| 1014/1020 [04:12<00:01,  4.02it/s, loss=1.04, v_num=xf5c]
# Validating:  70%|███████   | 14/20 [00:12<00:05,  1.09it/s]
# Epoch 12: 100%|█████████▉| 1016/1020 [04:14<00:01,  4.00it/s, loss=1.04, v_num=xf5c]
# Validating:  80%|████████  | 16/20 [00:14<00:03,  1.10it/s]
# Epoch 12: 100%|█████████▉| 1018/1020 [04:16<00:00,  3.97it/s, loss=1.04, v_num=xf5c]
# Validating:  90%|█████████ | 18/20 [00:16<00:02,  1.01s/it]
# Epoch 12: 100%|██████████| 1020/1020 [04:18<00:00,  3.95it/s, loss=1.04, v_num=xf5c]
# Epoch 12: 100%|██████████| 1020/1020 [04:20<00:00,  3.91it/s, loss=1.04, v_num=xf5c]
# Epoch 13:  98%|█████████▊| 1000/1020 [03:55<00:04,  4.24it/s, loss=1.03, v_num=xf5c]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/20 [00:00<?, ?it/s]
# Epoch 13:  98%|█████████▊| 1002/1020 [03:57<00:04,  4.21it/s, loss=1.03, v_num=xf5c]
# Validating:  10%|█         | 2/20 [00:02<00:24,  1.36s/it]
# Epoch 13:  98%|█████████▊| 1004/1020 [03:59<00:03,  4.19it/s, loss=1.03, v_num=xf5c]
# Validating:  20%|██        | 4/20 [00:04<00:15,  1.03it/s]
# Epoch 13:  99%|█████████▊| 1006/1020 [04:00<00:03,  4.18it/s, loss=1.03, v_num=xf5c]
# Validating:  30%|███       | 6/20 [00:05<00:11,  1.23it/s]
# Epoch 13:  99%|█████████▉| 1008/1020 [04:02<00:02,  4.16it/s, loss=1.03, v_num=xf5c]
# Validating:  40%|████      | 8/20 [00:07<00:09,  1.32it/s]
# Epoch 13:  99%|█████████▉| 1010/1020 [04:03<00:02,  4.14it/s, loss=1.03, v_num=xf5c]
# Validating:  50%|█████     | 10/20 [00:08<00:07,  1.29it/s]
# Epoch 13:  99%|█████████▉| 1012/1020 [04:05<00:01,  4.12it/s, loss=1.03, v_num=xf5c]
# Validating:  60%|██████    | 12/20 [00:10<00:06,  1.22it/s]
# Epoch 13:  99%|█████████▉| 1014/1020 [04:07<00:01,  4.10it/s, loss=1.03, v_num=xf5c]
# Validating:  70%|███████   | 14/20 [00:12<00:04,  1.25it/s]
# Epoch 13: 100%|█████████▉| 1016/1020 [04:08<00:00,  4.08it/s, loss=1.03, v_num=xf5c]
# Validating:  80%|████████  | 16/20 [00:13<00:03,  1.17it/s]
# Epoch 13: 100%|█████████▉| 1018/1020 [04:10<00:00,  4.06it/s, loss=1.03, v_num=xf5c]
# Validating:  90%|█████████ | 18/20 [00:16<00:01,  1.00it/s]
# Epoch 13: 100%|██████████| 1020/1020 [04:13<00:00,  4.03it/s, loss=1.03, v_num=xf5c]
# Epoch 13: 100%|██████████| 1020/1020 [04:15<00:00,  3.99it/s, loss=1.03, v_num=xf5c]
# Epoch 14:  98%|█████████▊| 1000/1020 [03:57<00:04,  4.22it/s, loss=1.09, v_num=xf5c]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/20 [00:00<?, ?it/s]
# Epoch 14:  98%|█████████▊| 1002/1020 [03:59<00:04,  4.19it/s, loss=1.09, v_num=xf5c]
# Validating:  10%|█         | 2/20 [00:02<00:24,  1.36s/it]
# Epoch 14:  98%|█████████▊| 1004/1020 [04:00<00:03,  4.17it/s, loss=1.09, v_num=xf5c]
# Validating:  20%|██        | 4/20 [00:04<00:15,  1.03it/s]
# Epoch 14:  99%|█████████▊| 1006/1020 [04:02<00:03,  4.15it/s, loss=1.09, v_num=xf5c]
# Validating:  30%|███       | 6/20 [00:05<00:11,  1.23it/s]
# Epoch 14:  99%|█████████▉| 1008/1020 [04:03<00:02,  4.13it/s, loss=1.09, v_num=xf5c]
# Validating:  40%|████      | 8/20 [00:07<00:09,  1.32it/s]
# Epoch 14:  99%|█████████▉| 1010/1020 [04:05<00:02,  4.12it/s, loss=1.09, v_num=xf5c]
# Validating:  50%|█████     | 10/20 [00:08<00:07,  1.30it/s]
# Epoch 14:  99%|█████████▉| 1012/1020 [04:06<00:01,  4.10it/s, loss=1.09, v_num=xf5c]
# Validating:  60%|██████    | 12/20 [00:10<00:06,  1.23it/s]
# Epoch 14:  99%|█████████▉| 1014/1020 [04:08<00:01,  4.08it/s, loss=1.09, v_num=xf5c]
# Validating:  70%|███████   | 14/20 [00:12<00:04,  1.26it/s]
# Epoch 14: 100%|█████████▉| 1016/1020 [04:10<00:00,  4.06it/s, loss=1.09, v_num=xf5c]
# Validating:  80%|████████  | 16/20 [00:13<00:03,  1.18it/s]
# Epoch 14: 100%|█████████▉| 1018/1020 [04:13<00:00,  4.02it/s, loss=1.09, v_num=xf5c]
# Validating:  90%|█████████ | 18/20 [00:17<00:02,  1.18s/it]
# Epoch 14: 100%|██████████| 1020/1020 [04:15<00:00,  4.00it/s, loss=1.09, v_num=xf5c]
# Epoch 14: 100%|██████████| 1020/1020 [04:17<00:00,  3.96it/s, loss=1.09, v_num=xf5c]
# Epoch 15:  98%|█████████▊| 1000/1020 [03:53<00:04,  4.29it/s, loss=1.03, v_num=xf5c]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/20 [00:00<?, ?it/s]
# Epoch 15:  98%|█████████▊| 1002/1020 [03:54<00:04,  4.26it/s, loss=1.03, v_num=xf5c]
# Validating:  10%|█         | 2/20 [00:02<00:24,  1.35s/it]
# Epoch 15:  98%|█████████▊| 1004/1020 [03:56<00:03,  4.24it/s, loss=1.03, v_num=xf5c]
# Validating:  20%|██        | 4/20 [00:04<00:15,  1.04it/s]
# Epoch 15:  99%|█████████▊| 1006/1020 [03:58<00:03,  4.23it/s, loss=1.03, v_num=xf5c]
# Validating:  30%|███       | 6/20 [00:05<00:11,  1.24it/s]
# Epoch 15:  99%|█████████▉| 1008/1020 [03:59<00:02,  4.21it/s, loss=1.03, v_num=xf5c]
# Validating:  40%|████      | 8/20 [00:07<00:09,  1.33it/s]
# Epoch 15:  99%|█████████▉| 1010/1020 [04:01<00:02,  4.19it/s, loss=1.03, v_num=xf5c]
# Validating:  50%|█████     | 10/20 [00:08<00:07,  1.30it/s]
# Epoch 15:  99%|█████████▉| 1012/1020 [04:02<00:01,  4.17it/s, loss=1.03, v_num=xf5c]
# Validating:  60%|██████    | 12/20 [00:10<00:06,  1.23it/s]
# Epoch 15:  99%|█████████▉| 1014/1020 [04:04<00:01,  4.15it/s, loss=1.03, v_num=xf5c]
# Validating:  70%|███████   | 14/20 [00:12<00:04,  1.26it/s]
# Epoch 15: 100%|█████████▉| 1016/1020 [04:05<00:00,  4.13it/s, loss=1.03, v_num=xf5c]
# Validating:  80%|████████  | 16/20 [00:13<00:03,  1.16it/s]
# Epoch 15: 100%|█████████▉| 1018/1020 [04:08<00:00,  4.10it/s, loss=1.03, v_num=xf5c]
# Validating:  90%|█████████ | 18/20 [00:16<00:01,  1.01it/s]
# Epoch 15: 100%|██████████| 1020/1020 [04:10<00:00,  4.08it/s, loss=1.03, v_num=xf5c]
# Epoch 15: 100%|██████████| 1020/1020 [04:12<00:00,  4.04it/s, loss=1.03, v_num=xf5c]
# Epoch 16:  98%|█████████▊| 1000/1020 [03:57<00:04,  4.22it/s, loss=1.03, v_num=xf5c]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/20 [00:00<?, ?it/s]
# Epoch 16:  98%|█████████▊| 1002/1020 [03:59<00:04,  4.19it/s, loss=1.03, v_num=xf5c]
# Validating:  10%|█         | 2/20 [00:03<00:26,  1.50s/it]
# Epoch 16:  98%|█████████▊| 1004/1020 [04:00<00:03,  4.17it/s, loss=1.03, v_num=xf5c]
# Validating:  20%|██        | 4/20 [00:04<00:16,  1.02s/it]
# Epoch 16:  99%|█████████▊| 1006/1020 [04:02<00:03,  4.14it/s, loss=1.03, v_num=xf5c]
# Validating:  30%|███       | 6/20 [00:06<00:14,  1.06s/it]
# Epoch 16:  99%|█████████▉| 1008/1020 [04:04<00:02,  4.12it/s, loss=1.03, v_num=xf5c]
# Validating:  40%|████      | 8/20 [00:08<00:10,  1.14it/s]
# Epoch 16:  99%|█████████▉| 1010/1020 [04:06<00:02,  4.10it/s, loss=1.03, v_num=xf5c]
# Validating:  50%|█████     | 10/20 [00:10<00:08,  1.20it/s]
# Epoch 16:  99%|█████████▉| 1012/1020 [04:07<00:01,  4.08it/s, loss=1.03, v_num=xf5c]
# Validating:  60%|██████    | 12/20 [00:11<00:06,  1.19it/s]
# Epoch 16:  99%|█████████▉| 1014/1020 [04:09<00:01,  4.06it/s, loss=1.03, v_num=xf5c]
# Validating:  70%|███████   | 14/20 [00:13<00:04,  1.24it/s]
# Epoch 16: 100%|█████████▉| 1016/1020 [04:11<00:00,  4.05it/s, loss=1.03, v_num=xf5c]
# Validating:  80%|████████  | 16/20 [00:15<00:03,  1.16it/s]
# Epoch 16: 100%|█████████▉| 1018/1020 [04:13<00:00,  4.02it/s, loss=1.03, v_num=xf5c]
# Validating:  90%|█████████ | 18/20 [00:17<00:01,  1.01it/s]
# Epoch 16: 100%|██████████| 1020/1020 [04:15<00:00,  3.99it/s, loss=1.03, v_num=xf5c]
# Epoch 16: 100%|██████████| 1020/1020 [04:18<00:00,  3.95it/s, loss=1.03, v_num=xf5c]
# Epoch 17:  98%|█████████▊| 1000/1020 [03:58<00:04,  4.20it/s, loss=1.01, v_num=xf5c]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/20 [00:00<?, ?it/s]
# Epoch 17:  98%|█████████▊| 1002/1020 [04:00<00:04,  4.17it/s, loss=1.01, v_num=xf5c]
# Validating:  10%|█         | 2/20 [00:02<00:24,  1.37s/it]
# Epoch 17:  98%|█████████▊| 1004/1020 [04:01<00:03,  4.15it/s, loss=1.01, v_num=xf5c]
# Validating:  20%|██        | 4/20 [00:04<00:15,  1.00it/s]
# Epoch 17:  99%|█████████▊| 1006/1020 [04:03<00:03,  4.14it/s, loss=1.01, v_num=xf5c]
# Validating:  30%|███       | 6/20 [00:05<00:11,  1.20it/s]
# Epoch 17:  99%|█████████▉| 1008/1020 [04:04<00:02,  4.12it/s, loss=1.01, v_num=xf5c]
# Validating:  40%|████      | 8/20 [00:07<00:09,  1.30it/s]
# Epoch 17:  99%|█████████▉| 1010/1020 [04:06<00:02,  4.10it/s, loss=1.01, v_num=xf5c]
# Validating:  50%|█████     | 10/20 [00:08<00:07,  1.30it/s]
# Epoch 17:  99%|█████████▉| 1012/1020 [04:07<00:01,  4.08it/s, loss=1.01, v_num=xf5c]
# Validating:  60%|██████    | 12/20 [00:10<00:06,  1.23it/s]
# Epoch 17:  99%|█████████▉| 1014/1020 [04:09<00:01,  4.07it/s, loss=1.01, v_num=xf5c]
# Validating:  70%|███████   | 14/20 [00:12<00:04,  1.26it/s]
# Epoch 17: 100%|█████████▉| 1016/1020 [04:11<00:00,  4.05it/s, loss=1.01, v_num=xf5c]
# Validating:  80%|████████  | 16/20 [00:14<00:03,  1.14it/s]
# Epoch 17: 100%|█████████▉| 1018/1020 [04:14<00:00,  4.01it/s, loss=1.01, v_num=xf5c]
# Validating:  90%|█████████ | 18/20 [00:17<00:02,  1.16s/it]
# Epoch 17: 100%|██████████| 1020/1020 [04:16<00:00,  3.98it/s, loss=1.01, v_num=xf5c]
# Epoch 17: 100%|██████████| 1020/1020 [04:18<00:00,  3.95it/s, loss=1.01, v_num=xf5c]
# Epoch 18:  98%|█████████▊| 1000/1020 [03:51<00:04,  4.32it/s, loss=1.02, v_num=xf5c]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/20 [00:00<?, ?it/s]
# Epoch 18:  98%|█████████▊| 1002/1020 [03:53<00:04,  4.30it/s, loss=1.02, v_num=xf5c]
# Validating:  10%|█         | 2/20 [00:02<00:24,  1.36s/it]
# Epoch 18:  98%|█████████▊| 1004/1020 [03:54<00:03,  4.28it/s, loss=1.02, v_num=xf5c]
# Validating:  20%|██        | 4/20 [00:04<00:15,  1.04it/s]
# Epoch 18:  99%|█████████▊| 1006/1020 [03:56<00:03,  4.26it/s, loss=1.02, v_num=xf5c]
# Validating:  30%|███       | 6/20 [00:05<00:11,  1.24it/s]
# Epoch 18:  99%|█████████▉| 1008/1020 [03:57<00:02,  4.24it/s, loss=1.02, v_num=xf5c]
# Validating:  40%|████      | 8/20 [00:07<00:09,  1.31it/s]
# Epoch 18:  99%|█████████▉| 1010/1020 [03:59<00:02,  4.22it/s, loss=1.02, v_num=xf5c]
# Validating:  50%|█████     | 10/20 [00:08<00:07,  1.29it/s]
# Epoch 18:  99%|█████████▉| 1012/1020 [04:01<00:01,  4.20it/s, loss=1.02, v_num=xf5c]
# Validating:  60%|██████    | 12/20 [00:10<00:06,  1.23it/s]
# Epoch 18:  99%|█████████▉| 1014/1020 [04:02<00:01,  4.18it/s, loss=1.02, v_num=xf5c]
# Validating:  70%|███████   | 14/20 [00:12<00:04,  1.26it/s]
# Epoch 18: 100%|█████████▉| 1016/1020 [04:04<00:00,  4.16it/s, loss=1.02, v_num=xf5c]
# Validating:  80%|████████  | 16/20 [00:13<00:03,  1.17it/s]
# Epoch 18: 100%|█████████▉| 1018/1020 [04:06<00:00,  4.13it/s, loss=1.02, v_num=xf5c]
# Validating:  90%|█████████ | 18/20 [00:16<00:01,  1.01it/s]
# Epoch 18: 100%|██████████| 1020/1020 [04:08<00:00,  4.10it/s, loss=1.02, v_num=xf5c]
# Epoch 18: 100%|██████████| 1020/1020 [04:10<00:00,  4.07it/s, loss=1.02, v_num=xf5c]
# Epoch 19:  98%|█████████▊| 1000/1020 [03:53<00:04,  4.29it/s, loss=1.01, v_num=xf5c]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/20 [00:00<?, ?it/s]
# Epoch 19:  98%|█████████▊| 1002/1020 [03:54<00:04,  4.26it/s, loss=1.01, v_num=xf5c]
# Validating:  10%|█         | 2/20 [00:02<00:24,  1.37s/it]
# Epoch 19:  98%|█████████▊| 1004/1020 [03:56<00:03,  4.24it/s, loss=1.01, v_num=xf5c]
# Validating:  20%|██        | 4/20 [00:04<00:15,  1.04it/s]
# Epoch 19:  99%|█████████▊| 1006/1020 [03:58<00:03,  4.23it/s, loss=1.01, v_num=xf5c]
# Validating:  30%|███       | 6/20 [00:05<00:11,  1.25it/s]
# Epoch 19:  99%|█████████▉| 1008/1020 [03:59<00:02,  4.21it/s, loss=1.01, v_num=xf5c]
# Validating:  40%|████      | 8/20 [00:07<00:08,  1.34it/s]
# Epoch 19:  99%|█████████▉| 1010/1020 [04:00<00:02,  4.19it/s, loss=1.01, v_num=xf5c]
# Validating:  50%|█████     | 10/20 [00:08<00:07,  1.32it/s]
# Epoch 19:  99%|█████████▉| 1012/1020 [04:02<00:01,  4.17it/s, loss=1.01, v_num=xf5c]
# Validating:  60%|██████    | 12/20 [00:10<00:06,  1.23it/s]
# Epoch 19:  99%|█████████▉| 1014/1020 [04:04<00:01,  4.15it/s, loss=1.01, v_num=xf5c]
# Validating:  70%|███████   | 14/20 [00:12<00:04,  1.25it/s]
# Epoch 19: 100%|█████████▉| 1016/1020 [04:05<00:00,  4.13it/s, loss=1.01, v_num=xf5c]
# Validating:  80%|████████  | 16/20 [00:13<00:03,  1.18it/s]
# Epoch 19: 100%|█████████▉| 1018/1020 [04:07<00:00,  4.10it/s, loss=1.01, v_num=xf5c]
# Validating:  90%|█████████ | 18/20 [00:16<00:01,  1.01it/s]
# Epoch 19: 100%|██████████| 1020/1020 [04:10<00:00,  4.08it/s, loss=1.01, v_num=xf5c]
# Epoch 19: 100%|██████████| 1020/1020 [04:12<00:00,  4.04it/s, loss=1.01, v_num=xf5c]
# Epoch 20:  98%|█████████▊| 1000/1020 [03:52<00:04,  4.30it/s, loss=1.03, v_num=xf5c]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/20 [00:00<?, ?it/s]
# Epoch 20:  98%|█████████▊| 1002/1020 [03:54<00:04,  4.27it/s, loss=1.03, v_num=xf5c]
# Validating:  10%|█         | 2/20 [00:02<00:24,  1.36s/it]
# Epoch 20:  98%|█████████▊| 1004/1020 [03:56<00:03,  4.25it/s, loss=1.03, v_num=xf5c]
# Validating:  20%|██        | 4/20 [00:04<00:15,  1.03it/s]
# Epoch 20:  99%|█████████▊| 1006/1020 [03:57<00:03,  4.23it/s, loss=1.03, v_num=xf5c]
# Validating:  30%|███       | 6/20 [00:05<00:11,  1.23it/s]
# Epoch 20:  99%|█████████▉| 1008/1020 [03:59<00:02,  4.21it/s, loss=1.03, v_num=xf5c]
# Validating:  40%|████      | 8/20 [00:07<00:09,  1.32it/s]
# Epoch 20:  99%|█████████▉| 1010/1020 [04:00<00:02,  4.19it/s, loss=1.03, v_num=xf5c]
# Validating:  50%|█████     | 10/20 [00:08<00:07,  1.29it/s]
# Epoch 20:  99%|█████████▉| 1012/1020 [04:02<00:01,  4.18it/s, loss=1.03, v_num=xf5c]
# Validating:  60%|██████    | 12/20 [00:10<00:06,  1.23it/s]
# Epoch 20:  99%|█████████▉| 1014/1020 [04:03<00:01,  4.16it/s, loss=1.03, v_num=xf5c]
# Validating:  70%|███████   | 14/20 [00:12<00:04,  1.25it/s]
# Epoch 20: 100%|█████████▉| 1016/1020 [04:05<00:00,  4.14it/s, loss=1.03, v_num=xf5c]
# Validating:  80%|████████  | 16/20 [00:13<00:03,  1.15it/s]
# Epoch 20: 100%|█████████▉| 1018/1020 [04:07<00:00,  4.11it/s, loss=1.03, v_num=xf5c]
# Validating:  90%|█████████ | 18/20 [00:16<00:02,  1.01s/it]
# Epoch 20: 100%|██████████| 1020/1020 [04:09<00:00,  4.08it/s, loss=1.03, v_num=xf5c]
# Epoch 20: 100%|██████████| 1020/1020 [04:12<00:00,  4.04it/s, loss=1.03, v_num=xf5c]
# Epoch 21:  98%|█████████▊| 1000/1020 [03:56<00:04,  4.22it/s, loss=1.02, v_num=xf5c]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/20 [00:00<?, ?it/s]
# Epoch 21:  98%|█████████▊| 1002/1020 [03:58<00:04,  4.20it/s, loss=1.02, v_num=xf5c]
# Validating:  10%|█         | 2/20 [00:02<00:24,  1.37s/it]
# Epoch 21:  98%|█████████▊| 1004/1020 [04:00<00:03,  4.18it/s, loss=1.02, v_num=xf5c]
# Validating:  20%|██        | 4/20 [00:04<00:15,  1.04it/s]
# Epoch 21:  99%|█████████▊| 1006/1020 [04:01<00:03,  4.16it/s, loss=1.02, v_num=xf5c]
# Validating:  30%|███       | 6/20 [00:05<00:11,  1.25it/s]
# Epoch 21:  99%|█████████▉| 1008/1020 [04:03<00:02,  4.14it/s, loss=1.02, v_num=xf5c]
# Validating:  40%|████      | 8/20 [00:07<00:08,  1.34it/s]
# Epoch 21:  99%|█████████▉| 1010/1020 [04:04<00:02,  4.12it/s, loss=1.02, v_num=xf5c]
# Validating:  50%|█████     | 10/20 [00:08<00:07,  1.32it/s]
# Epoch 21:  99%|█████████▉| 1012/1020 [04:06<00:01,  4.11it/s, loss=1.02, v_num=xf5c]
# Validating:  60%|██████    | 12/20 [00:10<00:06,  1.26it/s]
# Epoch 21:  99%|█████████▉| 1014/1020 [04:08<00:01,  4.09it/s, loss=1.02, v_num=xf5c]
# Validating:  70%|███████   | 14/20 [00:11<00:04,  1.27it/s]
# Epoch 21: 100%|█████████▉| 1016/1020 [04:09<00:00,  4.07it/s, loss=1.02, v_num=xf5c]
# Validating:  80%|████████  | 16/20 [00:13<00:03,  1.18it/s]
# Epoch 21: 100%|█████████▉| 1018/1020 [04:11<00:00,  4.04it/s, loss=1.02, v_num=xf5c]
# Validating:  90%|█████████ | 18/20 [00:16<00:01,  1.00it/s]
# Epoch 21: 100%|██████████| 1020/1020 [04:13<00:00,  4.02it/s, loss=1.02, v_num=xf5c]
# Epoch 21: 100%|██████████| 1020/1020 [04:16<00:00,  3.98it/s, loss=1.02, v_num=xf5c]
# Epoch 22:  98%|█████████▊| 1000/1020 [03:54<00:04,  4.26it/s, loss=1.05, v_num=xf5c]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/20 [00:00<?, ?it/s]
# Epoch 22:  98%|█████████▊| 1002/1020 [03:56<00:04,  4.24it/s, loss=1.05, v_num=xf5c]
# Validating:  10%|█         | 2/20 [00:02<00:24,  1.37s/it]
# Epoch 22:  98%|█████████▊| 1004/1020 [03:58<00:03,  4.22it/s, loss=1.05, v_num=xf5c]
# Validating:  20%|██        | 4/20 [00:04<00:15,  1.03it/s]
# Epoch 22:  99%|█████████▊| 1006/1020 [03:59<00:03,  4.20it/s, loss=1.05, v_num=xf5c]
# Validating:  30%|███       | 6/20 [00:05<00:11,  1.24it/s]
# Epoch 22:  99%|█████████▉| 1008/1020 [04:01<00:02,  4.18it/s, loss=1.05, v_num=xf5c]
# Validating:  40%|████      | 8/20 [00:07<00:09,  1.33it/s]
# Epoch 22:  99%|█████████▉| 1010/1020 [04:02<00:02,  4.16it/s, loss=1.05, v_num=xf5c]
# Validating:  50%|█████     | 10/20 [00:08<00:07,  1.31it/s]
# Epoch 22:  99%|█████████▉| 1012/1020 [04:04<00:01,  4.15it/s, loss=1.05, v_num=xf5c]
# Validating:  60%|██████    | 12/20 [00:10<00:06,  1.24it/s]
# Epoch 22:  99%|█████████▉| 1014/1020 [04:05<00:01,  4.13it/s, loss=1.05, v_num=xf5c]
# Validating:  70%|███████   | 14/20 [00:12<00:04,  1.27it/s]
# Epoch 22: 100%|█████████▉| 1016/1020 [04:07<00:00,  4.11it/s, loss=1.05, v_num=xf5c]
# Validating:  80%|████████  | 16/20 [00:13<00:03,  1.17it/s]
# Epoch 22: 100%|█████████▉| 1018/1020 [04:09<00:00,  4.08it/s, loss=1.05, v_num=xf5c]
# Validating:  90%|█████████ | 18/20 [00:16<00:01,  1.01it/s]
# Epoch 22: 100%|██████████| 1020/1020 [04:11<00:00,  4.05it/s, loss=1.05, v_num=xf5c]
# Epoch 22: 100%|██████████| 1020/1020 [04:13<00:00,  4.02it/s, loss=1.05, v_num=xf5c]
# Epoch 23:  98%|█████████▊| 1000/1020 [03:55<00:04,  4.25it/s, loss=1.01, v_num=xf5c]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/20 [00:00<?, ?it/s]
# Epoch 23:  98%|█████████▊| 1002/1020 [03:57<00:04,  4.22it/s, loss=1.01, v_num=xf5c]
# Validating:  10%|█         | 2/20 [00:02<00:24,  1.37s/it]
# Epoch 23:  98%|█████████▊| 1004/1020 [03:59<00:03,  4.20it/s, loss=1.01, v_num=xf5c]
# Validating:  20%|██        | 4/20 [00:04<00:15,  1.03it/s]
# Epoch 23:  99%|█████████▊| 1006/1020 [04:00<00:03,  4.18it/s, loss=1.01, v_num=xf5c]
# Validating:  30%|███       | 6/20 [00:05<00:11,  1.24it/s]
# Epoch 23:  99%|█████████▉| 1008/1020 [04:02<00:02,  4.16it/s, loss=1.01, v_num=xf5c]
# Validating:  40%|████      | 8/20 [00:07<00:08,  1.33it/s]
# Epoch 23:  99%|█████████▉| 1010/1020 [04:03<00:02,  4.15it/s, loss=1.01, v_num=xf5c]
# Validating:  50%|█████     | 10/20 [00:08<00:07,  1.31it/s]
# Epoch 23:  99%|█████████▉| 1012/1020 [04:05<00:01,  4.13it/s, loss=1.01, v_num=xf5c]
# Validating:  60%|██████    | 12/20 [00:10<00:06,  1.25it/s]
# Epoch 23:  99%|█████████▉| 1014/1020 [04:06<00:01,  4.11it/s, loss=1.01, v_num=xf5c]
# Validating:  70%|███████   | 14/20 [00:11<00:04,  1.27it/s]
# Epoch 23: 100%|█████████▉| 1016/1020 [04:08<00:00,  4.09it/s, loss=1.01, v_num=xf5c]
# Validating:  80%|████████  | 16/20 [00:13<00:03,  1.18it/s]
# Epoch 23: 100%|█████████▉| 1018/1020 [04:10<00:00,  4.06it/s, loss=1.01, v_num=xf5c]
# Validating:  90%|█████████ | 18/20 [00:16<00:01,  1.00it/s]
# Epoch 23: 100%|██████████| 1020/1020 [04:12<00:00,  4.04it/s, loss=1.01, v_num=xf5c]
# Epoch 23: 100%|██████████| 1020/1020 [04:14<00:00,  4.00it/s, loss=1.01, v_num=xf5c]
# Epoch 24:  98%|█████████▊| 1000/1020 [03:55<00:04,  4.25it/s, loss=1.02, v_num=xf5c]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/20 [00:00<?, ?it/s]
# Epoch 24:  98%|█████████▊| 1002/1020 [03:57<00:04,  4.22it/s, loss=1.02, v_num=xf5c]
# Validating:  10%|█         | 2/20 [00:02<00:25,  1.40s/it]
# Epoch 24:  98%|█████████▊| 1004/1020 [03:58<00:03,  4.20it/s, loss=1.02, v_num=xf5c]
# Validating:  20%|██        | 4/20 [00:04<00:15,  1.02it/s]
# Epoch 24:  99%|█████████▊| 1006/1020 [04:00<00:03,  4.18it/s, loss=1.02, v_num=xf5c]
# Validating:  30%|███       | 6/20 [00:05<00:11,  1.22it/s]
# Epoch 24:  99%|█████████▉| 1008/1020 [04:02<00:02,  4.16it/s, loss=1.02, v_num=xf5c]
# Validating:  40%|████      | 8/20 [00:07<00:09,  1.31it/s]
# Epoch 24:  99%|█████████▉| 1010/1020 [04:03<00:02,  4.15it/s, loss=1.02, v_num=xf5c]
# Validating:  50%|█████     | 10/20 [00:08<00:07,  1.29it/s]
# Epoch 24:  99%|█████████▉| 1012/1020 [04:05<00:01,  4.13it/s, loss=1.02, v_num=xf5c]
# Validating:  60%|██████    | 12/20 [00:11<00:08,  1.01s/it]
# Epoch 24:  99%|█████████▉| 1014/1020 [04:07<00:01,  4.10it/s, loss=1.02, v_num=xf5c]
# Validating:  70%|███████   | 14/20 [00:13<00:05,  1.08it/s]
# Epoch 24: 100%|█████████▉| 1016/1020 [04:09<00:00,  4.08it/s, loss=1.02, v_num=xf5c]
# Validating:  80%|████████  | 16/20 [00:14<00:03,  1.06it/s]
# Epoch 24: 100%|█████████▉| 1018/1020 [04:11<00:00,  4.05it/s, loss=1.02, v_num=xf5c]
# Validating:  90%|█████████ | 18/20 [00:17<00:02,  1.08s/it]
# Epoch 24: 100%|██████████| 1020/1020 [04:14<00:00,  4.01it/s, loss=1.02, v_num=xf5c]
# Epoch 24: 100%|██████████| 1020/1020 [04:16<00:00,  3.98it/s, loss=1.02, v_num=xf5c]
# Epoch 25:  98%|█████████▊| 1000/1020 [03:52<00:04,  4.30it/s, loss=0.998, v_num=xf5c]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/20 [00:00<?, ?it/s]
# Epoch 25:  98%|█████████▊| 1002/1020 [03:54<00:04,  4.27it/s, loss=0.998, v_num=xf5c]
# Validating:  10%|█         | 2/20 [00:02<00:24,  1.36s/it]
# Epoch 25:  98%|█████████▊| 1004/1020 [03:55<00:03,  4.25it/s, loss=0.998, v_num=xf5c]
# Validating:  20%|██        | 4/20 [00:04<00:15,  1.04it/s]
# Epoch 25:  99%|█████████▊| 1006/1020 [03:57<00:03,  4.24it/s, loss=0.998, v_num=xf5c]
# Validating:  30%|███       | 6/20 [00:05<00:11,  1.25it/s]
# Epoch 25:  99%|█████████▉| 1008/1020 [03:59<00:02,  4.22it/s, loss=0.998, v_num=xf5c]
# Validating:  40%|████      | 8/20 [00:07<00:08,  1.35it/s]
# Epoch 25:  99%|█████████▉| 1010/1020 [04:00<00:02,  4.20it/s, loss=0.998, v_num=xf5c]
# Validating:  50%|█████     | 10/20 [00:08<00:07,  1.32it/s]
# Epoch 25:  99%|█████████▉| 1012/1020 [04:02<00:01,  4.18it/s, loss=0.998, v_num=xf5c]
# Validating:  60%|██████    | 12/20 [00:10<00:06,  1.25it/s]
# Epoch 25:  99%|█████████▉| 1014/1020 [04:03<00:01,  4.16it/s, loss=0.998, v_num=xf5c]
# Validating:  70%|███████   | 14/20 [00:11<00:04,  1.28it/s]
# Epoch 25: 100%|█████████▉| 1016/1020 [04:05<00:00,  4.14it/s, loss=0.998, v_num=xf5c]
# Validating:  80%|████████  | 16/20 [00:13<00:03,  1.20it/s]
# Epoch 25: 100%|█████████▉| 1018/1020 [04:07<00:00,  4.12it/s, loss=0.998, v_num=xf5c]
# Validating:  90%|█████████ | 18/20 [00:15<00:01,  1.01it/s]
# Epoch 25: 100%|██████████| 1020/1020 [04:09<00:00,  4.09it/s, loss=0.998, v_num=xf5c]
# Epoch 25: 100%|██████████| 1020/1020 [04:11<00:00,  4.05it/s, loss=0.998, v_num=xf5c]
# Epoch 26:  98%|█████████▊| 1000/1020 [03:55<00:04,  4.25it/s, loss=1.01, v_num=xf5c]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/20 [00:00<?, ?it/s]
# Epoch 26:  98%|█████████▊| 1002/1020 [03:57<00:04,  4.22it/s, loss=1.01, v_num=xf5c]
# Validating:  10%|█         | 2/20 [00:02<00:24,  1.37s/it]
# Epoch 26:  98%|█████████▊| 1004/1020 [03:58<00:03,  4.20it/s, loss=1.01, v_num=xf5c]
# Validating:  20%|██        | 4/20 [00:04<00:15,  1.03it/s]
# Epoch 26:  99%|█████████▊| 1006/1020 [04:00<00:03,  4.19it/s, loss=1.01, v_num=xf5c]
# Validating:  30%|███       | 6/20 [00:05<00:11,  1.23it/s]
# Epoch 26:  99%|█████████▉| 1008/1020 [04:01<00:02,  4.17it/s, loss=1.01, v_num=xf5c]
# Validating:  40%|████      | 8/20 [00:07<00:09,  1.32it/s]
# Epoch 26:  99%|█████████▉| 1010/1020 [04:03<00:02,  4.15it/s, loss=1.01, v_num=xf5c]
# Validating:  50%|█████     | 10/20 [00:08<00:07,  1.30it/s]
# Epoch 26:  99%|█████████▉| 1012/1020 [04:04<00:01,  4.13it/s, loss=1.01, v_num=xf5c]
# Validating:  60%|██████    | 12/20 [00:10<00:06,  1.24it/s]
# Epoch 26:  99%|█████████▉| 1014/1020 [04:06<00:01,  4.11it/s, loss=1.01, v_num=xf5c]
# Validating:  70%|███████   | 14/20 [00:12<00:04,  1.26it/s]
# Epoch 26: 100%|█████████▉| 1016/1020 [04:08<00:00,  4.09it/s, loss=1.01, v_num=xf5c]
# Validating:  80%|████████  | 16/20 [00:13<00:03,  1.17it/s]
# Epoch 26: 100%|█████████▉| 1018/1020 [04:10<00:00,  4.07it/s, loss=1.01, v_num=xf5c]
# Validating:  90%|█████████ | 18/20 [00:16<00:02,  1.01s/it]
# Epoch 26: 100%|██████████| 1020/1020 [04:12<00:00,  4.04it/s, loss=1.01, v_num=xf5c]
# Epoch 26: 100%|██████████| 1020/1020 [04:14<00:00,  4.00it/s, loss=1.01, v_num=xf5c]
# Epoch 27:  98%|█████████▊| 1000/1020 [03:54<00:04,  4.26it/s, loss=1.04, v_num=xf5c]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/20 [00:00<?, ?it/s]
# Epoch 27:  98%|█████████▊| 1002/1020 [03:56<00:04,  4.24it/s, loss=1.04, v_num=xf5c]
# Validating:  10%|█         | 2/20 [00:02<00:24,  1.35s/it]
# Epoch 27:  98%|█████████▊| 1004/1020 [03:58<00:03,  4.22it/s, loss=1.04, v_num=xf5c]
# Validating:  20%|██        | 4/20 [00:04<00:15,  1.02it/s]
# Epoch 27:  99%|█████████▊| 1006/1020 [03:59<00:03,  4.20it/s, loss=1.04, v_num=xf5c]
# Validating:  30%|███       | 6/20 [00:05<00:11,  1.23it/s]
# Epoch 27:  99%|█████████▉| 1008/1020 [04:01<00:02,  4.18it/s, loss=1.04, v_num=xf5c]
# Validating:  40%|████      | 8/20 [00:07<00:09,  1.32it/s]
# Epoch 27:  99%|█████████▉| 1010/1020 [04:02<00:02,  4.16it/s, loss=1.04, v_num=xf5c]
# Validating:  50%|█████     | 10/20 [00:08<00:07,  1.31it/s]
# Epoch 27:  99%|█████████▉| 1012/1020 [04:04<00:01,  4.14it/s, loss=1.04, v_num=xf5c]
# Validating:  60%|██████    | 12/20 [00:10<00:06,  1.24it/s]
# Epoch 27:  99%|█████████▉| 1014/1020 [04:05<00:01,  4.13it/s, loss=1.04, v_num=xf5c]
# Validating:  70%|███████   | 14/20 [00:12<00:04,  1.27it/s]
# Epoch 27: 100%|█████████▉| 1016/1020 [04:07<00:00,  4.11it/s, loss=1.04, v_num=xf5c]
# Validating:  80%|████████  | 16/20 [00:13<00:03,  1.18it/s]
# Epoch 27: 100%|█████████▉| 1018/1020 [04:09<00:00,  4.08it/s, loss=1.04, v_num=xf5c]
# Validating:  90%|█████████ | 18/20 [00:16<00:01,  1.01it/s]
# Epoch 27: 100%|██████████| 1020/1020 [04:11<00:00,  4.05it/s, loss=1.04, v_num=xf5c]
# Epoch 27: 100%|██████████| 1020/1020 [04:13<00:00,  4.02it/s, loss=1.04, v_num=xf5c]
# Epoch 28:  98%|█████████▊| 1000/1020 [03:54<00:04,  4.26it/s, loss=1, v_num=xf5c]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/20 [00:00<?, ?it/s]
# Epoch 28:  98%|█████████▊| 1002/1020 [03:56<00:04,  4.24it/s, loss=1, v_num=xf5c]
# Validating:  10%|█         | 2/20 [00:02<00:24,  1.37s/it]
# Epoch 28:  98%|█████████▊| 1004/1020 [03:58<00:03,  4.22it/s, loss=1, v_num=xf5c]
# Validating:  20%|██        | 4/20 [00:04<00:15,  1.03it/s]
# Epoch 28:  99%|█████████▊| 1006/1020 [03:59<00:03,  4.20it/s, loss=1, v_num=xf5c]
# Validating:  30%|███       | 6/20 [00:05<00:11,  1.23it/s]
# Epoch 28:  99%|█████████▉| 1008/1020 [04:01<00:02,  4.18it/s, loss=1, v_num=xf5c]
# Validating:  40%|████      | 8/20 [00:07<00:09,  1.33it/s]
# Epoch 28:  99%|█████████▉| 1010/1020 [04:02<00:02,  4.16it/s, loss=1, v_num=xf5c]
# Validating:  50%|█████     | 10/20 [00:08<00:07,  1.31it/s]
# Epoch 28:  99%|█████████▉| 1012/1020 [04:04<00:01,  4.14it/s, loss=1, v_num=xf5c]
# Validating:  60%|██████    | 12/20 [00:10<00:06,  1.23it/s]
# Epoch 28:  99%|█████████▉| 1014/1020 [04:05<00:01,  4.13it/s, loss=1, v_num=xf5c]
# Validating:  70%|███████   | 14/20 [00:12<00:04,  1.26it/s]
# Epoch 28: 100%|█████████▉| 1016/1020 [04:07<00:00,  4.11it/s, loss=1, v_num=xf5c]
# Validating:  80%|████████  | 16/20 [00:13<00:03,  1.18it/s]
# Epoch 28: 100%|█████████▉| 1018/1020 [04:09<00:00,  4.08it/s, loss=1, v_num=xf5c]
# Validating:  90%|█████████ | 18/20 [00:16<00:01,  1.01it/s]
# Epoch 28: 100%|██████████| 1020/1020 [04:11<00:00,  4.05it/s, loss=1, v_num=xf5c]
# Epoch 28: 100%|██████████| 1020/1020 [04:13<00:00,  4.02it/s, loss=1, v_num=xf5c]
# Epoch 29:  98%|█████████▊| 1000/1020 [03:55<00:04,  4.25it/s, loss=1.07, v_num=xf5c]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/20 [00:00<?, ?it/s]
# Epoch 29:  98%|█████████▊| 1002/1020 [03:57<00:04,  4.23it/s, loss=1.07, v_num=xf5c]
# Validating:  10%|█         | 2/20 [00:02<00:24,  1.38s/it]
# Epoch 29:  98%|█████████▊| 1004/1020 [03:58<00:03,  4.21it/s, loss=1.07, v_num=xf5c]
# Validating:  20%|██        | 4/20 [00:04<00:15,  1.01it/s]
# Epoch 29:  99%|█████████▊| 1006/1020 [04:00<00:03,  4.19it/s, loss=1.07, v_num=xf5c]
# Validating:  30%|███       | 6/20 [00:06<00:12,  1.10it/s]
# Epoch 29:  99%|█████████▉| 1008/1020 [04:02<00:02,  4.16it/s, loss=1.07, v_num=xf5c]
# Validating:  40%|████      | 8/20 [00:08<00:11,  1.07it/s]
# Epoch 29:  99%|█████████▉| 1010/1020 [04:04<00:02,  4.14it/s, loss=1.07, v_num=xf5c]
# Validating:  50%|█████     | 10/20 [00:09<00:08,  1.17it/s]
# Epoch 29:  99%|█████████▉| 1012/1020 [04:05<00:01,  4.12it/s, loss=1.07, v_num=xf5c]
# Validating:  60%|██████    | 12/20 [00:11<00:06,  1.17it/s]
# Epoch 29:  99%|█████████▉| 1014/1020 [04:07<00:01,  4.10it/s, loss=1.07, v_num=xf5c]
# Validating:  70%|███████   | 14/20 [00:12<00:04,  1.23it/s]
# Epoch 29: 100%|█████████▉| 1016/1020 [04:08<00:00,  4.08it/s, loss=1.07, v_num=xf5c]
# Validating:  80%|████████  | 16/20 [00:14<00:03,  1.17it/s]
# Epoch 29: 100%|█████████▉| 1018/1020 [04:11<00:00,  4.06it/s, loss=1.07, v_num=xf5c]
# Validating:  90%|█████████ | 18/20 [00:16<00:01,  1.01it/s]
# Epoch 29: 100%|██████████| 1020/1020 [04:13<00:00,  4.03it/s, loss=1.07, v_num=xf5c]
# Epoch 29: 100%|██████████| 1020/1020 [04:15<00:00,  3.99it/s, loss=1.07, v_num=xf5c]
# Epoch 30:  98%|█████████▊| 1000/1020 [03:48<00:04,  4.37it/s, loss=1.01, v_num=xf5c]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/20 [00:00<?, ?it/s]
# Epoch 30:  98%|█████████▊| 1002/1020 [03:50<00:04,  4.34it/s, loss=1.01, v_num=xf5c]
# Validating:  10%|█         | 2/20 [00:02<00:23,  1.33s/it]
# Epoch 30:  98%|█████████▊| 1004/1020 [03:52<00:03,  4.32it/s, loss=1.01, v_num=xf5c]
# Validating:  20%|██        | 4/20 [00:04<00:15,  1.05it/s]
# Epoch 30:  99%|█████████▊| 1006/1020 [03:53<00:03,  4.30it/s, loss=1.01, v_num=xf5c]
# Validating:  30%|███       | 6/20 [00:05<00:11,  1.25it/s]
# Epoch 30:  99%|█████████▉| 1008/1020 [03:55<00:02,  4.28it/s, loss=1.01, v_num=xf5c]
# Validating:  40%|████      | 8/20 [00:07<00:08,  1.34it/s]
# Epoch 30:  99%|█████████▉| 1010/1020 [03:56<00:02,  4.26it/s, loss=1.01, v_num=xf5c]
# Validating:  50%|█████     | 10/20 [00:09<00:09,  1.04it/s]
# Epoch 30:  99%|█████████▉| 1012/1020 [03:59<00:01,  4.23it/s, loss=1.01, v_num=xf5c]
# Validating:  60%|██████    | 12/20 [00:11<00:07,  1.04it/s]
# Epoch 30:  99%|█████████▉| 1014/1020 [04:00<00:01,  4.21it/s, loss=1.01, v_num=xf5c]
# Validating:  70%|███████   | 14/20 [00:12<00:05,  1.13it/s]
# Epoch 30: 100%|█████████▉| 1016/1020 [04:02<00:00,  4.19it/s, loss=1.01, v_num=xf5c]
# Validating:  80%|████████  | 16/20 [00:14<00:03,  1.09it/s]
# Epoch 30: 100%|█████████▉| 1018/1020 [04:04<00:00,  4.16it/s, loss=1.01, v_num=xf5c]
# Validating:  90%|█████████ | 18/20 [00:17<00:02,  1.05s/it]
# Epoch 30: 100%|██████████| 1020/1020 [04:07<00:00,  4.13it/s, loss=1.01, v_num=xf5c]
# Epoch 30: 100%|██████████| 1020/1020 [04:09<00:00,  4.09it/s, loss=1.01, v_num=xf5c]
# Epoch 31:   7%|▋         | 69/1020 [00:15<03:33,  4.45it/s, loss=1, v_num=xf5c]

# %% [markdown]
# ### Test filter

# %% [markdown]
# A Pytorch Lightning Trainer has two main methods: `fit` and `test`. They represent the two main steps of any ML engingeering or research: Train a model, then make sure it can infer accurately on test (i.e. **hidden**) data.

# %% [markdown]
# Note that `ckpt_path` just tells the trainer to use the latest "checkpoint" of the model, rather than *best* checkpoint. A checkpoint is a saved version of the model, a snapshot at a particular stage of the training process. Pytorch Lightning automatically saves a checkpoint of your model in case something crashes and we need to resume.

# %%
test_results = trainer.test(ckpt_path=None)
# Out:
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Testing', layout=Layout(flex='2'), max=…
# --------------------------------------------------------------------------------
# DATALOADER:0 TEST RESULTS
# {'current_lr': 0.0005999999702908099,
#  'eff': 0.9709646701812744,
#  'pur': 0.055771585553884506,
#  'val_loss': 0.9984596371650696}
# --------------------------------------------------------------------------------

# %% [markdown]
# ## Performance

# %%
checkpoint_path = "/global/cfs/cdirs/m3443/data/lightning_models/lightning_checkpoints/ITk_0.5GeV_Barrel_Filter/h1ilzfy9/checkpoints/last.ckpt"
checkpoint = torch.load(checkpoint_path)

model = PyramidFilter.load_from_checkpoint(checkpoint_path).to(device)

# %%
model.eval();

# %%
model.hparams["datatype_split"] = [1, 1, 1]
model.hparams[
    "input_dir"
] = "/global/cfs/cdirs/m3443/data/ITk-upgrade/processed/embedding_processed/0.5GeV_barrel"
model.setup(stage="fit")

# %%
test_results = model.to(device).shared_evaluation(model.valset[0].to(device), 0)
cut = 0.2

# %%
(test_results["preds"] > cut).sum()
# Out:
# tensor(229455, device='cuda:0')

# %%
(test_results["truth"] & (test_results["preds"] > cut)).sum()
# Out:
# tensor(16498, device='cuda:0')

# %%
(test_results["truth"] & (test_results["preds"] > cut)).sum() / (
    test_results["preds"] > cut
).sum()
# Out:
# tensor(0.0719, device='cuda:0')

# %%
(test_results["truth"] & (test_results["preds"] > cut)).sum() / test_results[
    "truth"
].int().sum()
# Out:
# tensor(0.9927, device='cuda:0')

# %%
(test_results["truth"] & (test_results["preds"] > cut)).sum() / model.valset[
    0
].signal_true_edges.shape[1]
# Out:
# tensor(0.9851, device='cuda:0')

# %%
subset_mask = np.isin(
    batch.edge_index.cpu(), batch.modulewise_true_edges.unique().cpu()
).any(0)

# %%
test_results["preds"].cpu()[::100].shape
# Out:
# torch.Size([17586])

# %%
true_preds.shape
# Out:
# torch.Size([12035])

# %%
false_preds.shape
# Out:
# torch.Size([1746521])

# %%
true_preds = test_results["preds"][test_results["trues"].cpu() & subset_mask]
false_preds = test_results["preds"][~test_results["trues"].cpu() & subset_mask]
# Out:
# /global/homes/d/danieltm/.local/lib/python3.7/site-packages/ipykernel_launcher.py:1: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead. (Triggered internally at  /pytorch/aten/src/ATen/native/IndexingUtils.h:30.)
#   """Entry point for launching an IPython kernel.
# /global/homes/d/danieltm/.local/lib/python3.7/site-packages/ipykernel_launcher.py:2: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead. (Triggered internally at  /pytorch/aten/src/ATen/native/IndexingUtils.h:30.)

# %% [markdown]
# ## Build Edges

# %%
class FilterInferenceBuilder:
    def __init__(self, model, output_dir, overwrite=False):
        self.output_dir = output_dir
        self.model = model
        self.overwrite = overwrite

        # Prep the directory to produce inference data to
        self.datatypes = ["train", "val", "test"]
        os.makedirs(self.output_dir, exist_ok=True)
        [
            os.makedirs(os.path.join(self.output_dir, datatype), exist_ok=True)
            for datatype in self.datatypes
        ]

        # Get [train, val, test] lists of files
        self.dataset_list = []
        for dataname in model.hparams["datatype_names"]:
            dataset = os.listdir(os.path.join(model.hparams["input_dir"], dataname))
            dataset = sorted(
                [
                    os.path.join(model.hparams["input_dir"], dataname, event)
                    for event in dataset
                ]
            )
            self.dataset_list.append(dataset)

    def build(self):
        print("Training finished, running inference to build graphs...")

        # By default, the set of examples propagated through the pipeline will be train+val+test set
        datasets = {
            "train": self.dataset_list[0],
            "val": self.dataset_list[1],
            "test": self.dataset_list[2],
        }
        total_length = sum([len(dataset) for dataset in datasets.values()])
        batch_incr = 0
        self.model.eval()
        with torch.no_grad():
            for set_idx, (datatype, dataset) in enumerate(datasets.items()):
                for event_idx, event_file in enumerate(dataset):
                    percent = (batch_incr / total_length) * 100
                    sys.stdout.flush()
                    sys.stdout.write(f"{percent:.01f}% inference complete \r")
                    batch = torch.load(event_file).to(device)
                    if (
                        not os.path.exists(
                            os.path.join(
                                self.output_dir, datatype, batch.event_file[-4:]
                            )
                        )
                    ) or self.overwrite:
                        batch_to_save = copy.deepcopy(batch)
                        batch_to_save = batch_to_save.to(
                            self.model.device
                        )  # Is this step necessary??
                        self.construct_downstream(batch_to_save, datatype)

                    batch_incr += 1

    def construct_downstream(self, batch, datatype):

        emb = (
            None if (self.model.hparams["emb_channels"] == 0) else batch.embedding
        )  # Does this work??

        cut_list = []
        for j in range(self.model.hparams["n_chunks"]):
            subset_ind = torch.chunk(
                torch.arange(batch.edge_index.shape[1]), self.model.hparams["n_chunks"]
            )[j]
            output = (
                self.model(
                    torch.cat(
                        [
                            batch.cell_data[:, : self.model.hparams["cell_channels"]],
                            batch.x,
                        ],
                        axis=-1,
                    ),
                    batch.edge_index[:, subset_ind],
                    emb,
                ).squeeze()
                if ("ci" in self.model.hparams["regime"])
                else self.model(batch.x, batch.edge_index[:, subset_ind], emb).squeeze()
            )
            cut = torch.sigmoid(output) > self.model.hparams["filter_cut"]
            cut_list.append(cut)

        cut_list = torch.cat(cut_list)

        if "pid" not in self.model.hparams["regime"]:
            batch.y = batch.y[cut_list]

        y_pid = batch.pid[batch.edge_index[0]] == batch.pid[batch.edge_index[1]]
        batch.y_pid = y_pid[cut_list]
        batch.edge_index = batch.edge_index[:, cut_list]
        if "weighting" in self.model.hparams["regime"]:
            batch.weights = batch.weights[cut_list]

        self.save_downstream(batch, datatype)

    def save_downstream(self, batch, datatype):

        with open(
            os.path.join(self.output_dir, datatype, batch.event_file[-4:]), "wb"
        ) as pickle_file:
            torch.save(batch, pickle_file)

# %%
output_dir = (
    "/global/cfs/cdirs/m3443/data/ITk-upgrade/processed/filter_processed/0.5GeV_barrel"
)
model.hparams["train_split"] = [10, 1, 1]
model.hparams["filter_cut"] = 0.2

# %%
edge_builder = FilterInferenceBuilder(model, output_dir, overwrite=True)

edge_builder.build()
# Out:
# Training finished, running inference to build graphs...
# 100.0% inference complete

# %% [markdown]
# ## Debug Dataloader

# %%
from torch.utils.data import Dataset, DataLoader

# %%
from LightningModules.Filter.utils import load_dataset

# %%
class filter_dataset(Dataset):
    def __init__(self, dataset, hparams):

        # Setup here
        self.dataset = dataset
        self.hparams = hparams

    def __len__(self):

        return len(self.dataset)

    def __getitem__(self, idx):

        batch = self.dataset[idx]
        print(batch)

        print(batch.edge_index.device)

        if "subset" in self.hparams["regime"]:
            subset_mask = np.isin(
                batch.edge_index, batch.modulewise_true_edges.unique()
            ).any(0)
            batch.edge_index = batch.edge_index[:, subset_mask]
            batch.y = batch.y[subset_mask]

        if self.hparams["ratio"] != 0:
            num_true, num_false = batch.y.bool().sum(), (~batch.y.bool()).sum()

            fake_indices = torch.where(~batch.y.bool())[0]

            fake_indices = fake_indices[
                torch.randint(
                    len(fake_indices), (num_true.item() * self.hparams["ratio"],)
                )
            ]

            true_indices = torch.where(batch.y.bool())[0]
            combined_indices = torch.cat([true_indices, fake_indices])

            # Shuffle indices:
            combined_indices = combined_indices[torch.randperm(len(combined_indices))]

        else:
            combined_indices = torch.range(batch.edge_index.shape[1])

        return {
            "x": batch.x,
            "cell_data": batch.cell_data,
            "edge_index": batch.edge_index[:, combined_indices],
            "y": batch.y[combined_indices],
        }

# %%
input_dirs = [None, None, None]
input_dirs[: len(hparams["datatype_names"])] = [
    os.path.join(hparams["input_dir"], datatype)
    for datatype in hparams["datatype_names"]
]
trainset, valset, testset = [
    load_dataset(input_dir, hparams["datatype_split"][i])
    for i, input_dir in enumerate(input_dirs)
]

# %%
train_dataset = filter_dataset(trainset, hparams)

# %%
trainloader = DataLoader(train_dataset)
